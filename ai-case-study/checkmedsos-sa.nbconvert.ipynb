# %% [markdown]
# # Huggingface Model for Sentiment Analysis
# Source Data: checkmedsos_db, db_id = 87247
#
# 1. create calculation example
# 2. post to mysql
# 3. inspect the result
#
#  * Kesepakatan status di kolom screen_analisis_ai.status
#  * 1 --> baru diinput
#  * 2 --> lagi dikerjakan
#  * 3 --> proses berhasil
#  * 4 --> proses gagal
#  *
#
#  * Kesepakatan jenis analisa AI
#  * 1 --> Analisa Cluster
#  * 2 --> Analisa image clustering
#  * 3 --> Analisa sentiment

# %%
import numpy as np
import pandas as pd
import seaborn as sn
import matplotlib.pyplot as plt
import pymysql.cursors
import sqlalchemy as sa
import nltk
import string
import os

from nltk.corpus import stopwords 
from sqlalchemy.exc import SQLAlchemyError
from sqlalchemy import create_engine, text
from sqlalchemy.orm import sessionmaker


# nltk.download('stopwords')
os.environ['TF_CPP_MIN_LOG_LEVEL'] = '2'

# Use a pipeline as a high-level helper
from transformers import pipeline
pipe = pipeline("text-classification", model="ayameRushia/bert-base-indonesian-1.5G-sentiment-analysis-smsa")

# database connection properties
connection_url = "mysql://cekmedsos_db:282E~f0si@202.157.185.40/cekmedsos_database"
# Out:
# /home/haviz/cekmedsos/lib64/python3.6/site-packages/pymysql/_auth.py:8: CryptographyDeprecationWarning: Python 3.6 is no longer supported by the Python core team. Therefore, support for it is deprecated in cryptography. The next release of cryptography will remove support for Python 3.6.
#   from cryptography.hazmat.backends import default_backend
# /home/haviz/cekmedsos/lib64/python3.6/site-packages/requests/__init__.py:104: RequestsDependencyWarning: urllib3 (1.26.18) or chardet (5.0.0)/charset_normalizer (2.0.12) doesn't match a supported version!
#   RequestsDependencyWarning)

# %%
import pandas as pd
import re
from sqlalchemy import create_engine

def execute_sqlalchemy_transaction(transaction_query):
    # Database connection parameters
    db_url = 'mysql://cekmedsos_db:282E~f0si@202.157.185.40/cekmedsos_database'
        # Define the connection parameters inside the function
    
    try:
        # Create a SQLAlchemy engine and session
        engine = create_engine(db_url)
        Session = sessionmaker(bind=engine)
        session = Session()

        # Begin a transaction
        session.begin()

        try:
            # Execute the transaction query
            query_text = text(transaction_query)
            session.execute(query_text)

            # Commit the transaction if the query succeeded
            session.commit()
            #print("Transaction completed successfully.")
        except SQLAlchemyError as e:
            # Rollback the transaction on error
            session.rollback()
            print(f"Transaction error: {str(e)}")
        finally:
            # Close the session
            session.close()
    except SQLAlchemyError as e:
        print(f"Error connecting to the database: {str(e)}")

# nltk.download('stopwords')
def stemming(comment):
    factory = StemmerFactory()
    stemmer = factory.create_stemmer()
    do = []
    for w in comment:
        dt = stemmer.stem(w)
        do.append(dt)
    d_clean = []
    d_clean = " ".join(do)
    return d_clean
    
# function case folding
def casefolding(comment):
    comment = comment.lower()
    comment = comment.strip(" ")
    comment = re.sub(r'[?|$|.|!_:")(-+,]','',comment)
    return comment

def clean_up_tag(comment):
    x_ret = ' '.join(re.sub("(@[A-Za-z0-9]+)|([^0-9A-Za-z \t])|(\w+:\/\/\S+)"," ",comment).split())
    return x_ret

# Text Preprocessing, 
def text_preproc(strIn):
    # case folding
    strOut = strIn.lower()
    
    # remove numbers
    strOut = re.sub(r"\d+", "", strOut)
    
    # remote punctuation
    strOut = strOut.translate(str.maketrans("","",string.punctuation))
    
    # remove whitspace
    strOut = strOut.strip()
    
    # 
    strOut = re.sub('\s+',' ',strOut)
    return strOut

print('functions is build')
# Out:
# functions is build

# %%
import pandas as pd
from sqlalchemy import create_engine, Column, Integer, String, MetaData, Table
from sqlalchemy.orm import sessionmaker
from sqlalchemy.exc import SQLAlchemyError
from sqlalchemy.util import deprecations
deprecations.SILENCE_UBER_WARNING = True

def execute_query_psql(query, params=None):
    # Set your PostgreSQL connection parameters
    db_params = {
        'host': '98.98.117.105',
        'port': '5432',
        'database': 'medols',
        'user': 'postgres',
        'password': 'FEWcTB3JIX5gK4T06c1MdkM9N2S8w9pb',
    }

    # Create a SQLAlchemy engine
    engine = create_engine(f"postgresql+psycopg2://{db_params['user']}:{db_params['password']}@{db_params['host']}:{db_params['port']}/{db_params['database']}")

    # Create a metadata object
    metadata = MetaData(bind=engine)

    # Example: Define your table
    your_table = Table('your_table', metadata,
                       Column('id', Integer, primary_key=True),
                       Column('column1', String),
                       Column('column2', String)
                       )

    # Create a session
    Session = sessionmaker(bind=engine)
    session = Session()

    try:
        # Execute the query with optional parameters
        result = session.execute(text(query), params)

        # Check if the query is a SELECT query
        is_select_query = result.returns_rows

        if is_select_query:
            # Fetch the data and return as a Pandas DataFrame
            columns = result.keys()
            fetched_data = result.fetchall()
            df = pd.DataFrame(fetched_data, columns=columns)
            # print("Fetched Data as DataFrame:")
            # print(df)
            return df
        else:
            # Get the number of rows affected for non-SELECT queries
            rows_affected = result.rowcount

            # Commit the changes to the database for non-SELECT queries
            session.commit()

            print(f"Query executed successfully. {rows_affected} rows affected.")
            return rows_affected
    except Exception as e:
        # Rollback changes if there's an error
        session.rollback()
        print(f"Error executing query: {e}")
    finally:
        # Close the session
        session.close()

# %%
# query from db
query = "select id, hastag, parameter \
from screen_analisis_ai \
where active = 1 \
and status = 1 \
and jenis_analisa = '3' \
order by created asc, id asc limit 1"
df_res = execute_query_psql(query)

# check job availability
if len(df_res) == 0:
    # get out, nothing to do
    print('Zero jobs, quitting now')
    quit()
    
df_res.head()
iJobID = df_res['hastag'][0]
const_job_id = df_res['id'][0]
const_parameter = df_res['parameter'][0]

print('iJobID: ' + str(iJobID))
print('const_job_id: ' + str(const_job_id))
print('const_parameter: ' + str(const_parameter))
# record as processing
# Out:
# iJobID: 87554
# const_job_id: 3748
# const_parameter: None

# %%
def process_by_db_id(db_id):
    from tqdm import tqdm
    pd.options.mode.chained_assignment = None 
    
    # Example usage:
    query = "select * from ret_tweet where db_id = '" + str(db_id) + "'"
    df = execute_query_psql(query)
    
    df.head()
    
    # remove first
    df['tweet'] = df['tweet'].apply(clean_up_tag)
    
    # skip stemming
    df['stemmed'] = df['tweet']
    df['stemmed'] = df['stemmed'].apply(casefolding)
    df['stemmed'] = df['stemmed'].apply(text_preproc)
    
    sw = stopwords.words('indonesian')
    
    #tokenized
    df['tokenized_tweet'] = df.apply(lambda row: nltk.word_tokenize(row['stemmed']), axis=1)
    
    # apply stopword removal
    df['tokenized_tweet'] = df.apply(lambda row: {w for w in row['tokenized_tweet'] if not w in sw}, axis=1)
    
    # Notes on return sentiment values
    # 1 >> positif >> stay
    # 2 >> negatif >> convert to -1
    # 0 >> netral >> stay
    
    # Create a new list and insert each element from the original list
    from tqdm import tqdm
    
    list_text = df['stemmed'].tolist()
    new_list = []
    #for i in tqdm(range(10)):
    for i in tqdm(range( len(list_text) )):
        # print(list_text[i])
        res = pipe(list_text[i])
        # new_list.append({res[0]['label']})
        # new_list.append(new_list.append({res[0]['label']},{res[0]['score']})
        new_list.append(res)
    
    # Notes on return sentiment values
    # 1 >> positif >> stay
    # 2 >> negatif >> convert to -1
    # 0 >> netral >> stay
    # create a list of our conditions
    for i in range(0, len(new_list)):
        # print(new_list[i][0]['label'])
        if new_list[i][0]['label'] == 'Positive':
            new_list[i][0]['Value'] = 1
        elif new_list[i][0]['label'] == 'Negative':
            new_list[i][0]['Value'] = -1
        elif new_list[i][0]['label'] == 'Neutral':
            new_list[i][0]['Value'] = 0
    
    for index, row in df.iterrows():
        df.at[index,'Prediction'] = new_list[index][0]['label']
    
    for index, row in df.iterrows():
        df.at[index,'Prediction'] = new_list[index][0]['label']
        df.at[index,'Score'] = new_list[index][0]['score']
        df.at[index,'Score'] = new_list[index][0]['Value']
        

    return df

# %%
## report to dbms that we are working on this row
sql = ""
sql = "update screen_analisis_ai set status = 2, last_status_update = now(), start_process = now() where id = '" + str(const_job_id) + "';"
print(sql)
# execute
execute_query_psql(sql)
#
# Create Header Record
sql = "insert into ret_analysis_header (job_id, datetime_start, user_id) values (%s, now(), %s)" % (const_job_id,"1")
# Execute the query
execute_query_psql(sql)
# Out:
# update screen_analisis_ai set status = 2, last_status_update = now(), start_process = now() where id = '3748';
# Query executed successfully. 1 rows affected.
# Query executed successfully. 1 rows affected.
# 1

# %%
# nltk.download('punkt')
df_result = process_by_db_id(iJobID)
# Out:
# 100%|██████████| 2092/2092 [5:09:05<00:00,  8.87s/it]

# %%
# Export the DataFrame to a CSV file
#df.to_csv('sa-result.csv', index=False)
# nltk.download('stopwords')
# nltk.download('punkt')

# %%
# record result
sentiment_class = 0

for index, row in df_result.iterrows():
    if row['Prediction'] == 'Positive':
        sentiment_class = 1
    elif row['Prediction'] == 'Negative':
        sentiment_class = -1
    else:
        sentiment_class = 0
        
    sql = "INSERT INTO ret_sentiment_result (job_id, tweet_id, sentiment_class) VALUES(%s, %s , %s);" % (str(const_job_id), row['id_str'], str(sentiment_class))
    #print(sql)
    execute_query_psql(sql)
# Out:
# Error executing query: (psycopg2.errors.UniqueViolation) duplicate key value violates unique constraint "ret_sentiment_result_pkey"
# DETAIL:  Key (id)=(24217) already exists.
#
# [SQL: INSERT INTO ret_sentiment_result (job_id, tweet_id, sentiment_class) VALUES(3748, 1491559306285694981 , 0);]
# (Background on this error at: https://sqlalche.me/e/14/gkpj)
# Error executing query: (psycopg2.errors.UniqueViolation) duplicate key value violates unique constraint "ret_sentiment_result_pkey"
# DETAIL:  Key (id)=(24218) already exists.
#
# [SQL: INSERT INTO ret_sentiment_result (job_id, tweet_id, sentiment_class) VALUES(3748, 1740544175886757971 , 0);]
# (Background on this error at: https://sqlalche.me/e/14/gkpj)
# Error executing query: (psycopg2.errors.UniqueViolation) duplicate key value violates unique constraint "ret_sentiment_result_pkey"
# DETAIL:  Key (id)=(24219) already exists.
#
# [SQL: INSERT INTO ret_sentiment_result (job_id, tweet_id, sentiment_class) VALUES(3748, 1741749177619808432 , -1);]
# (Background on this error at: https://sqlalche.me/e/14/gkpj)
# Error executing query: (psycopg2.errors.UniqueViolation) duplicate key value violates unique constraint "ret_sentiment_result_pkey"
# DETAIL:  Key (id)=(24220) already exists.
#
# [SQL: INSERT INTO ret_sentiment_result (job_id, tweet_id, sentiment_class) VALUES(3748, 1749467073896390896 , 0);]
# (Background on this error at: https://sqlalche.me/e/14/gkpj)
# Error executing query: (psycopg2.errors.UniqueViolation) duplicate key value violates unique constraint "ret_sentiment_result_pkey"
# DETAIL:  Key (id)=(24221) already exists.
#
# [SQL: INSERT INTO ret_sentiment_result (job_id, tweet_id, sentiment_class) VALUES(3748, 1759587317340336487 , -1);]
# (Background on this error at: https://sqlalche.me/e/14/gkpj)
# Error executing query: (psycopg2.errors.UniqueViolation) duplicate key value violates unique constraint "ret_sentiment_result_pkey"
# DETAIL:  Key (id)=(24222) already exists.
#
# [SQL: INSERT INTO ret_sentiment_result (job_id, tweet_id, sentiment_class) VALUES(3748, 1760837125631791129 , -1);]
# (Background on this error at: https://sqlalche.me/e/14/gkpj)
# Error executing query: (psycopg2.errors.UniqueViolation) duplicate key value violates unique constraint "ret_sentiment_result_pkey"
# DETAIL:  Key (id)=(24223) already exists.
#
# [SQL: INSERT INTO ret_sentiment_result (job_id, tweet_id, sentiment_class) VALUES(3748, 1761045909805387961 , -1);]
# (Background on this error at: https://sqlalche.me/e/14/gkpj)
# Error executing query: (psycopg2.errors.UniqueViolation) duplicate key value violates unique constraint "ret_sentiment_result_pkey"
# DETAIL:  Key (id)=(24224) already exists.
#
# [SQL: INSERT INTO ret_sentiment_result (job_id, tweet_id, sentiment_class) VALUES(3748, 1761224262403395859 , -1);]
# (Background on this error at: https://sqlalche.me/e/14/gkpj)
# Error executing query: (psycopg2.errors.UniqueViolation) duplicate key value violates unique constraint "ret_sentiment_result_pkey"
# DETAIL:  Key (id)=(24225) already exists.
#
# [SQL: INSERT INTO ret_sentiment_result (job_id, tweet_id, sentiment_class) VALUES(3748, 1761311509140123847 , -1);]
# (Background on this error at: https://sqlalche.me/e/14/gkpj)
# Error executing query: (psycopg2.errors.UniqueViolation) duplicate key value violates unique constraint "ret_sentiment_result_pkey"
# DETAIL:  Key (id)=(24226) already exists.
#
# [SQL: INSERT INTO ret_sentiment_result (job_id, tweet_id, sentiment_class) VALUES(3748, 1761314918530195736 , 1);]
# (Background on this error at: https://sqlalche.me/e/14/gkpj)
# Error executing query: (psycopg2.errors.UniqueViolation) duplicate key value violates unique constraint "ret_sentiment_result_pkey"
# DETAIL:  Key (id)=(24227) already exists.
#
# [SQL: INSERT INTO ret_sentiment_result (job_id, tweet_id, sentiment_class) VALUES(3748, 1761404868265427232 , -1);]
# (Background on this error at: https://sqlalche.me/e/14/gkpj)
# Error executing query: (psycopg2.errors.UniqueViolation) duplicate key value violates unique constraint "ret_sentiment_result_pkey"
# DETAIL:  Key (id)=(24228) already exists.
#
# [SQL: INSERT INTO ret_sentiment_result (job_id, tweet_id, sentiment_class) VALUES(3748, 1761529030103413238 , 0);]
# (Background on this error at: https://sqlalche.me/e/14/gkpj)
# Error executing query: (psycopg2.errors.UniqueViolation) duplicate key value violates unique constraint "ret_sentiment_result_pkey"
# DETAIL:  Key (id)=(24229) already exists.
#
# [SQL: INSERT INTO ret_sentiment_result (job_id, tweet_id, sentiment_class) VALUES(3748, 1761542055048921404 , 0);]
# (Background on this error at: https://sqlalche.me/e/14/gkpj)
# Error executing query: (psycopg2.errors.UniqueViolation) duplicate key value violates unique constraint "ret_sentiment_result_pkey"
# DETAIL:  Key (id)=(24230) already exists.
#
# [SQL: INSERT INTO ret_sentiment_result (job_id, tweet_id, sentiment_class) VALUES(3748, 1761542952894292345 , 0);]
# (Background on this error at: https://sqlalche.me/e/14/gkpj)
# Error executing query: (psycopg2.errors.UniqueViolation) duplicate key value violates unique constraint "ret_sentiment_result_pkey"
# DETAIL:  Key (id)=(24231) already exists.
#
# [SQL: INSERT INTO ret_sentiment_result (job_id, tweet_id, sentiment_class) VALUES(3748, 1761543157618196662 , 0);]
# (Background on this error at: https://sqlalche.me/e/14/gkpj)
# Error executing query: (psycopg2.errors.UniqueViolation) duplicate key value violates unique constraint "ret_sentiment_result_pkey"
# DETAIL:  Key (id)=(24232) already exists.
#
# [SQL: INSERT INTO ret_sentiment_result (job_id, tweet_id, sentiment_class) VALUES(3748, 1761544091429634445 , 0);]
# (Background on this error at: https://sqlalche.me/e/14/gkpj)
# Error executing query: (psycopg2.errors.UniqueViolation) duplicate key value violates unique constraint "ret_sentiment_result_pkey"
# DETAIL:  Key (id)=(24233) already exists.
#
# [SQL: INSERT INTO ret_sentiment_result (job_id, tweet_id, sentiment_class) VALUES(3748, 1761545872431812631 , 0);]
# (Background on this error at: https://sqlalche.me/e/14/gkpj)
# Error executing query: (psycopg2.errors.UniqueViolation) duplicate key value violates unique constraint "ret_sentiment_result_pkey"
# DETAIL:  Key (id)=(24234) already exists.
#
# [SQL: INSERT INTO ret_sentiment_result (job_id, tweet_id, sentiment_class) VALUES(3748, 1761546436427284562 , 0);]
# (Background on this error at: https://sqlalche.me/e/14/gkpj)
# Error executing query: (psycopg2.errors.UniqueViolation) duplicate key value violates unique constraint "ret_sentiment_result_pkey"
# DETAIL:  Key (id)=(24235) already exists.
#
# [SQL: INSERT INTO ret_sentiment_result (job_id, tweet_id, sentiment_class) VALUES(3748, 1761548419632386122 , 0);]
# (Background on this error at: https://sqlalche.me/e/14/gkpj)
# Error executing query: (psycopg2.errors.UniqueViolation) duplicate key value violates unique constraint "ret_sentiment_result_pkey"
# DETAIL:  Key (id)=(24236) already exists.
#
# [SQL: INSERT INTO ret_sentiment_result (job_id, tweet_id, sentiment_class) VALUES(3748, 1761548463215640598 , 0);]
# (Background on this error at: https://sqlalche.me/e/14/gkpj)
# Error executing query: (psycopg2.errors.UniqueViolation) duplicate key value violates unique constraint "ret_sentiment_result_pkey"
# DETAIL:  Key (id)=(24237) already exists.
#
# [SQL: INSERT INTO ret_sentiment_result (job_id, tweet_id, sentiment_class) VALUES(3748, 1761549273936896390 , -1);]
# (Background on this error at: https://sqlalche.me/e/14/gkpj)
# Error executing query: (psycopg2.errors.UniqueViolation) duplicate key value violates unique constraint "ret_sentiment_result_pkey"
# DETAIL:  Key (id)=(24238) already exists.
#
# [SQL: INSERT INTO ret_sentiment_result (job_id, tweet_id, sentiment_class) VALUES(3748, 1761549356338135306 , 1);]
# (Background on this error at: https://sqlalche.me/e/14/gkpj)
# Error executing query: (psycopg2.errors.UniqueViolation) duplicate key value violates unique constraint "ret_sentiment_result_pkey"
# DETAIL:  Key (id)=(24239) already exists.
#
# [SQL: INSERT INTO ret_sentiment_result (job_id, tweet_id, sentiment_class) VALUES(3748, 1761551652509942201 , 0);]
# (Background on this error at: https://sqlalche.me/e/14/gkpj)
# Error executing query: (psycopg2.errors.UniqueViolation) duplicate key value violates unique constraint "ret_sentiment_result_pkey"
# DETAIL:  Key (id)=(24240) already exists.
#
# [SQL: INSERT INTO ret_sentiment_result (job_id, tweet_id, sentiment_class) VALUES(3748, 1761553369599250514 , 0);]
# (Background on this error at: https://sqlalche.me/e/14/gkpj)
# Error executing query: (psycopg2.errors.UniqueViolation) duplicate key value violates unique constraint "ret_sentiment_result_pkey"
# DETAIL:  Key (id)=(24241) already exists.
#
# [SQL: INSERT INTO ret_sentiment_result (job_id, tweet_id, sentiment_class) VALUES(3748, 1761553648214286705 , 0);]
# (Background on this error at: https://sqlalche.me/e/14/gkpj)
# Error executing query: (psycopg2.errors.UniqueViolation) duplicate key value violates unique constraint "ret_sentiment_result_pkey"
# DETAIL:  Key (id)=(24242) already exists.
#
# [SQL: INSERT INTO ret_sentiment_result (job_id, tweet_id, sentiment_class) VALUES(3748, 1761554245067985341 , 0);]
# (Background on this error at: https://sqlalche.me/e/14/gkpj)
# Error executing query: (psycopg2.errors.UniqueViolation) duplicate key value violates unique constraint "ret_sentiment_result_pkey"
# DETAIL:  Key (id)=(24243) already exists.
#
# [SQL: INSERT INTO ret_sentiment_result (job_id, tweet_id, sentiment_class) VALUES(3748, 1761556103471796534 , 0);]
# (Background on this error at: https://sqlalche.me/e/14/gkpj)
# Error executing query: (psycopg2.errors.UniqueViolation) duplicate key value violates unique constraint "ret_sentiment_result_pkey"
# DETAIL:  Key (id)=(24244) already exists.
#
# [SQL: INSERT INTO ret_sentiment_result (job_id, tweet_id, sentiment_class) VALUES(3748, 1761556599980896643 , 0);]
# (Background on this error at: https://sqlalche.me/e/14/gkpj)
# Error executing query: (psycopg2.errors.UniqueViolation) duplicate key value violates unique constraint "ret_sentiment_result_pkey"
# DETAIL:  Key (id)=(24245) already exists.
#
# [SQL: INSERT INTO ret_sentiment_result (job_id, tweet_id, sentiment_class) VALUES(3748, 1761557080031526934 , 0);]
# (Background on this error at: https://sqlalche.me/e/14/gkpj)
# Error executing query: (psycopg2.errors.UniqueViolation) duplicate key value violates unique constraint "ret_sentiment_result_pkey"
# DETAIL:  Key (id)=(24246) already exists.
#
# [SQL: INSERT INTO ret_sentiment_result (job_id, tweet_id, sentiment_class) VALUES(3748, 1761557308205899911 , 0);]
# (Background on this error at: https://sqlalche.me/e/14/gkpj)
# Error executing query: (psycopg2.errors.UniqueViolation) duplicate key value violates unique constraint "ret_sentiment_result_pkey"
# DETAIL:  Key (id)=(24247) already exists.
#
# [SQL: INSERT INTO ret_sentiment_result (job_id, tweet_id, sentiment_class) VALUES(3748, 1761558656389144963 , 0);]
# (Background on this error at: https://sqlalche.me/e/14/gkpj)
# Error executing query: (psycopg2.errors.UniqueViolation) duplicate key value violates unique constraint "ret_sentiment_result_pkey"
# DETAIL:  Key (id)=(24248) already exists.
#
# [SQL: INSERT INTO ret_sentiment_result (job_id, tweet_id, sentiment_class) VALUES(3748, 1761558737687642224 , 0);]
# (Background on this error at: https://sqlalche.me/e/14/gkpj)
# Error executing query: (psycopg2.errors.UniqueViolation) duplicate key value violates unique constraint "ret_sentiment_result_pkey"
# DETAIL:  Key (id)=(24249) already exists.
#
# [SQL: INSERT INTO ret_sentiment_result (job_id, tweet_id, sentiment_class) VALUES(3748, 1761560910001558004 , 0);]
# (Background on this error at: https://sqlalche.me/e/14/gkpj)
# Error executing query: (psycopg2.errors.UniqueViolation) duplicate key value violates unique constraint "ret_sentiment_result_pkey"
# DETAIL:  Key (id)=(24250) already exists.
#
# [SQL: INSERT INTO ret_sentiment_result (job_id, tweet_id, sentiment_class) VALUES(3748, 1761561046190571870 , 0);]
# (Background on this error at: https://sqlalche.me/e/14/gkpj)
# Error executing query: (psycopg2.errors.UniqueViolation) duplicate key value violates unique constraint "ret_sentiment_result_pkey"
# DETAIL:  Key (id)=(24251) already exists.
#
# [SQL: INSERT INTO ret_sentiment_result (job_id, tweet_id, sentiment_class) VALUES(3748, 1761561401628508532 , -1);]
# (Background on this error at: https://sqlalche.me/e/14/gkpj)
# Error executing query: (psycopg2.errors.UniqueViolation) duplicate key value violates unique constraint "ret_sentiment_result_pkey"
# DETAIL:  Key (id)=(24252) already exists.
#
# [SQL: INSERT INTO ret_sentiment_result (job_id, tweet_id, sentiment_class) VALUES(3748, 1761561543811145951 , 0);]
# (Background on this error at: https://sqlalche.me/e/14/gkpj)
# Error executing query: (psycopg2.errors.UniqueViolation) duplicate key value violates unique constraint "ret_sentiment_result_pkey"
# DETAIL:  Key (id)=(24253) already exists.
#
# [SQL: INSERT INTO ret_sentiment_result (job_id, tweet_id, sentiment_class) VALUES(3748, 1761562556735369395 , 0);]
# (Background on this error at: https://sqlalche.me/e/14/gkpj)
# Error executing query: (psycopg2.errors.UniqueViolation) duplicate key value violates unique constraint "ret_sentiment_result_pkey"
# DETAIL:  Key (id)=(24254) already exists.
#
# [SQL: INSERT INTO ret_sentiment_result (job_id, tweet_id, sentiment_class) VALUES(3748, 1761563526404182434 , 0);]
# (Background on this error at: https://sqlalche.me/e/14/gkpj)
# Error executing query: (psycopg2.errors.UniqueViolation) duplicate key value violates unique constraint "ret_sentiment_result_pkey"
# DETAIL:  Key (id)=(24255) already exists.
#
# [SQL: INSERT INTO ret_sentiment_result (job_id, tweet_id, sentiment_class) VALUES(3748, 1761564211556278696 , 0);]
# (Background on this error at: https://sqlalche.me/e/14/gkpj)
# Error executing query: (psycopg2.errors.UniqueViolation) duplicate key value violates unique constraint "ret_sentiment_result_pkey"
# DETAIL:  Key (id)=(24256) already exists.
#
# [SQL: INSERT INTO ret_sentiment_result (job_id, tweet_id, sentiment_class) VALUES(3748, 1761565538822812041 , 0);]
# (Background on this error at: https://sqlalche.me/e/14/gkpj)
# Error executing query: (psycopg2.errors.UniqueViolation) duplicate key value violates unique constraint "ret_sentiment_result_pkey"
# DETAIL:  Key (id)=(24257) already exists.
#
# [SQL: INSERT INTO ret_sentiment_result (job_id, tweet_id, sentiment_class) VALUES(3748, 1761566669309386866 , -1);]
# (Background on this error at: https://sqlalche.me/e/14/gkpj)
# Error executing query: (psycopg2.errors.UniqueViolation) duplicate key value violates unique constraint "ret_sentiment_result_pkey"
# DETAIL:  Key (id)=(24258) already exists.
#
# [SQL: INSERT INTO ret_sentiment_result (job_id, tweet_id, sentiment_class) VALUES(3748, 1761566702217855438 , 0);]
# (Background on this error at: https://sqlalche.me/e/14/gkpj)
# Error executing query: (psycopg2.errors.UniqueViolation) duplicate key value violates unique constraint "ret_sentiment_result_pkey"
# DETAIL:  Key (id)=(24259) already exists.
#
# [SQL: INSERT INTO ret_sentiment_result (job_id, tweet_id, sentiment_class) VALUES(3748, 1761568506758435067 , 0);]
# (Background on this error at: https://sqlalche.me/e/14/gkpj)
# Error executing query: (psycopg2.errors.UniqueViolation) duplicate key value violates unique constraint "ret_sentiment_result_pkey"
# DETAIL:  Key (id)=(24260) already exists.
#
# [SQL: INSERT INTO ret_sentiment_result (job_id, tweet_id, sentiment_class) VALUES(3748, 1761568557102735784 , 0);]
# (Background on this error at: https://sqlalche.me/e/14/gkpj)
# Error executing query: (psycopg2.errors.UniqueViolation) duplicate key value violates unique constraint "ret_sentiment_result_pkey"
# DETAIL:  Key (id)=(24261) already exists.
#
# [SQL: INSERT INTO ret_sentiment_result (job_id, tweet_id, sentiment_class) VALUES(3748, 1761569184247652524 , 0);]
# (Background on this error at: https://sqlalche.me/e/14/gkpj)
# Error executing query: (psycopg2.errors.UniqueViolation) duplicate key value violates unique constraint "ret_sentiment_result_pkey"
# DETAIL:  Key (id)=(24262) already exists.
#
# [SQL: INSERT INTO ret_sentiment_result (job_id, tweet_id, sentiment_class) VALUES(3748, 1761573001152307329 , 0);]
# (Background on this error at: https://sqlalche.me/e/14/gkpj)
# Error executing query: (psycopg2.errors.UniqueViolation) duplicate key value violates unique constraint "ret_sentiment_result_pkey"
# DETAIL:  Key (id)=(24263) already exists.
#
# [SQL: INSERT INTO ret_sentiment_result (job_id, tweet_id, sentiment_class) VALUES(3748, 1761573020991472055 , 0);]
# (Background on this error at: https://sqlalche.me/e/14/gkpj)
# Error executing query: (psycopg2.errors.UniqueViolation) duplicate key value violates unique constraint "ret_sentiment_result_pkey"
# DETAIL:  Key (id)=(24264) already exists.
#
# [SQL: INSERT INTO ret_sentiment_result (job_id, tweet_id, sentiment_class) VALUES(3748, 1761574165860278492 , 0);]
# (Background on this error at: https://sqlalche.me/e/14/gkpj)
# Error executing query: (psycopg2.errors.UniqueViolation) duplicate key value violates unique constraint "ret_sentiment_result_pkey"
# DETAIL:  Key (id)=(24265) already exists.
#
# [SQL: INSERT INTO ret_sentiment_result (job_id, tweet_id, sentiment_class) VALUES(3748, 1761574199410462836 , 0);]
# (Background on this error at: https://sqlalche.me/e/14/gkpj)
# Error executing query: (psycopg2.errors.UniqueViolation) duplicate key value violates unique constraint "ret_sentiment_result_pkey"
# DETAIL:  Key (id)=(24266) already exists.
#
# [SQL: INSERT INTO ret_sentiment_result (job_id, tweet_id, sentiment_class) VALUES(3748, 1761575550018289881 , 0);]
# (Background on this error at: https://sqlalche.me/e/14/gkpj)
# Error executing query: (psycopg2.errors.UniqueViolation) duplicate key value violates unique constraint "ret_sentiment_result_pkey"
# DETAIL:  Key (id)=(24267) already exists.
#
# [SQL: INSERT INTO ret_sentiment_result (job_id, tweet_id, sentiment_class) VALUES(3748, 1761575985554804934 , 0);]
# (Background on this error at: https://sqlalche.me/e/14/gkpj)
# Error executing query: (psycopg2.errors.UniqueViolation) duplicate key value violates unique constraint "ret_sentiment_result_pkey"
# DETAIL:  Key (id)=(24268) already exists.
#
# [SQL: INSERT INTO ret_sentiment_result (job_id, tweet_id, sentiment_class) VALUES(3748, 1761576290447147190 , 0);]
# (Background on this error at: https://sqlalche.me/e/14/gkpj)
# Error executing query: (psycopg2.errors.UniqueViolation) duplicate key value violates unique constraint "ret_sentiment_result_pkey"
# DETAIL:  Key (id)=(24269) already exists.
#
# [SQL: INSERT INTO ret_sentiment_result (job_id, tweet_id, sentiment_class) VALUES(3748, 1761577376578957553 , 0);]
# (Background on this error at: https://sqlalche.me/e/14/gkpj)
# Error executing query: (psycopg2.errors.UniqueViolation) duplicate key value violates unique constraint "ret_sentiment_result_pkey"
# DETAIL:  Key (id)=(24270) already exists.
#
# [SQL: INSERT INTO ret_sentiment_result (job_id, tweet_id, sentiment_class) VALUES(3748, 1761577697279685074 , 0);]
# (Background on this error at: https://sqlalche.me/e/14/gkpj)
# Error executing query: (psycopg2.errors.UniqueViolation) duplicate key value violates unique constraint "ret_sentiment_result_pkey"
# DETAIL:  Key (id)=(24271) already exists.
#
# [SQL: INSERT INTO ret_sentiment_result (job_id, tweet_id, sentiment_class) VALUES(3748, 1761577842062868701 , 0);]
# (Background on this error at: https://sqlalche.me/e/14/gkpj)
# Error executing query: (psycopg2.errors.UniqueViolation) duplicate key value violates unique constraint "ret_sentiment_result_pkey"
# DETAIL:  Key (id)=(24272) already exists.
#
# [SQL: INSERT INTO ret_sentiment_result (job_id, tweet_id, sentiment_class) VALUES(3748, 1761578775136153747 , 1);]
# (Background on this error at: https://sqlalche.me/e/14/gkpj)
# Error executing query: (psycopg2.errors.UniqueViolation) duplicate key value violates unique constraint "ret_sentiment_result_pkey"
# DETAIL:  Key (id)=(24273) already exists.
#
# [SQL: INSERT INTO ret_sentiment_result (job_id, tweet_id, sentiment_class) VALUES(3748, 1761579034759074185 , -1);]
# (Background on this error at: https://sqlalche.me/e/14/gkpj)
# Error executing query: (psycopg2.errors.UniqueViolation) duplicate key value violates unique constraint "ret_sentiment_result_pkey"
# DETAIL:  Key (id)=(24274) already exists.
#
# [SQL: INSERT INTO ret_sentiment_result (job_id, tweet_id, sentiment_class) VALUES(3748, 1761579094200988046 , 0);]
# (Background on this error at: https://sqlalche.me/e/14/gkpj)
# Error executing query: (psycopg2.errors.UniqueViolation) duplicate key value violates unique constraint "ret_sentiment_result_pkey"
# DETAIL:  Key (id)=(24275) already exists.
#
# [SQL: INSERT INTO ret_sentiment_result (job_id, tweet_id, sentiment_class) VALUES(3748, 1761579247465038012 , 0);]
# (Background on this error at: https://sqlalche.me/e/14/gkpj)
# Error executing query: (psycopg2.errors.UniqueViolation) duplicate key value violates unique constraint "ret_sentiment_result_pkey"
# DETAIL:  Key (id)=(24276) already exists.
#
# [SQL: INSERT INTO ret_sentiment_result (job_id, tweet_id, sentiment_class) VALUES(3748, 1761579281325666653 , 0);]
# (Background on this error at: https://sqlalche.me/e/14/gkpj)
# Error executing query: (psycopg2.errors.UniqueViolation) duplicate key value violates unique constraint "ret_sentiment_result_pkey"
# DETAIL:  Key (id)=(24277) already exists.
#
# [SQL: INSERT INTO ret_sentiment_result (job_id, tweet_id, sentiment_class) VALUES(3748, 1761579988825125073 , 0);]
# (Background on this error at: https://sqlalche.me/e/14/gkpj)
# Error executing query: (psycopg2.errors.UniqueViolation) duplicate key value violates unique constraint "ret_sentiment_result_pkey"
# DETAIL:  Key (id)=(24278) already exists.
#
# [SQL: INSERT INTO ret_sentiment_result (job_id, tweet_id, sentiment_class) VALUES(3748, 1761580292756918321 , 0);]
# (Background on this error at: https://sqlalche.me/e/14/gkpj)
# Error executing query: (psycopg2.errors.UniqueViolation) duplicate key value violates unique constraint "ret_sentiment_result_pkey"
# DETAIL:  Key (id)=(24279) already exists.
#
# [SQL: INSERT INTO ret_sentiment_result (job_id, tweet_id, sentiment_class) VALUES(3748, 1761580465218318357 , 0);]
# (Background on this error at: https://sqlalche.me/e/14/gkpj)
# Error executing query: (psycopg2.errors.UniqueViolation) duplicate key value violates unique constraint "ret_sentiment_result_pkey"
# DETAIL:  Key (id)=(24280) already exists.
#
# [SQL: INSERT INTO ret_sentiment_result (job_id, tweet_id, sentiment_class) VALUES(3748, 1761580895524540843 , 0);]
# (Background on this error at: https://sqlalche.me/e/14/gkpj)
# Error executing query: (psycopg2.errors.UniqueViolation) duplicate key value violates unique constraint "ret_sentiment_result_pkey"
# DETAIL:  Key (id)=(24281) already exists.
#
# [SQL: INSERT INTO ret_sentiment_result (job_id, tweet_id, sentiment_class) VALUES(3748, 1761581443854275014 , 0);]
# (Background on this error at: https://sqlalche.me/e/14/gkpj)
# Error executing query: (psycopg2.errors.UniqueViolation) duplicate key value violates unique constraint "ret_sentiment_result_pkey"
# DETAIL:  Key (id)=(24282) already exists.
#
# [SQL: INSERT INTO ret_sentiment_result (job_id, tweet_id, sentiment_class) VALUES(3748, 1761581450095448240 , 0);]
# (Background on this error at: https://sqlalche.me/e/14/gkpj)
# Error executing query: (psycopg2.errors.UniqueViolation) duplicate key value violates unique constraint "ret_sentiment_result_pkey"
# DETAIL:  Key (id)=(24283) already exists.
#
# [SQL: INSERT INTO ret_sentiment_result (job_id, tweet_id, sentiment_class) VALUES(3748, 1761582358904598612 , 0);]
# (Background on this error at: https://sqlalche.me/e/14/gkpj)
# Error executing query: (psycopg2.errors.UniqueViolation) duplicate key value violates unique constraint "ret_sentiment_result_pkey"
# DETAIL:  Key (id)=(24284) already exists.
#
# [SQL: INSERT INTO ret_sentiment_result (job_id, tweet_id, sentiment_class) VALUES(3748, 1761584106859827400 , 0);]
# (Background on this error at: https://sqlalche.me/e/14/gkpj)
# Error executing query: (psycopg2.errors.UniqueViolation) duplicate key value violates unique constraint "ret_sentiment_result_pkey"
# DETAIL:  Key (id)=(24285) already exists.
#
# [SQL: INSERT INTO ret_sentiment_result (job_id, tweet_id, sentiment_class) VALUES(3748, 1761585570944553049 , 0);]
# (Background on this error at: https://sqlalche.me/e/14/gkpj)
# Error executing query: (psycopg2.errors.UniqueViolation) duplicate key value violates unique constraint "ret_sentiment_result_pkey"
# DETAIL:  Key (id)=(24286) already exists.
#
# [SQL: INSERT INTO ret_sentiment_result (job_id, tweet_id, sentiment_class) VALUES(3748, 1761586347847139824 , 1);]
# (Background on this error at: https://sqlalche.me/e/14/gkpj)
# Error executing query: (psycopg2.errors.UniqueViolation) duplicate key value violates unique constraint "ret_sentiment_result_pkey"
# DETAIL:  Key (id)=(24287) already exists.
#
# [SQL: INSERT INTO ret_sentiment_result (job_id, tweet_id, sentiment_class) VALUES(3748, 1761588201909838168 , 0);]
# (Background on this error at: https://sqlalche.me/e/14/gkpj)
# Error executing query: (psycopg2.errors.UniqueViolation) duplicate key value violates unique constraint "ret_sentiment_result_pkey"
# DETAIL:  Key (id)=(24288) already exists.
#
# [SQL: INSERT INTO ret_sentiment_result (job_id, tweet_id, sentiment_class) VALUES(3748, 1761588707545776494 , 0);]
# (Background on this error at: https://sqlalche.me/e/14/gkpj)
# Error executing query: (psycopg2.errors.UniqueViolation) duplicate key value violates unique constraint "ret_sentiment_result_pkey"
# DETAIL:  Key (id)=(24289) already exists.
#
# [SQL: INSERT INTO ret_sentiment_result (job_id, tweet_id, sentiment_class) VALUES(3748, 1761589172757029143 , 0);]
# (Background on this error at: https://sqlalche.me/e/14/gkpj)
# Error executing query: (psycopg2.errors.UniqueViolation) duplicate key value violates unique constraint "ret_sentiment_result_pkey"
# DETAIL:  Key (id)=(24290) already exists.
#
# [SQL: INSERT INTO ret_sentiment_result (job_id, tweet_id, sentiment_class) VALUES(3748, 1761589382954598587 , 0);]
# (Background on this error at: https://sqlalche.me/e/14/gkpj)
# Error executing query: (psycopg2.errors.UniqueViolation) duplicate key value violates unique constraint "ret_sentiment_result_pkey"
# DETAIL:  Key (id)=(24291) already exists.
#
# [SQL: INSERT INTO ret_sentiment_result (job_id, tweet_id, sentiment_class) VALUES(3748, 1761589944919925074 , 0);]
# (Background on this error at: https://sqlalche.me/e/14/gkpj)
# Error executing query: (psycopg2.errors.UniqueViolation) duplicate key value violates unique constraint "ret_sentiment_result_pkey"
# DETAIL:  Key (id)=(24292) already exists.
#
# [SQL: INSERT INTO ret_sentiment_result (job_id, tweet_id, sentiment_class) VALUES(3748, 1761592650850091296 , -1);]
# (Background on this error at: https://sqlalche.me/e/14/gkpj)
# Error executing query: (psycopg2.errors.UniqueViolation) duplicate key value violates unique constraint "ret_sentiment_result_pkey"
# DETAIL:  Key (id)=(24293) already exists.
#
# [SQL: INSERT INTO ret_sentiment_result (job_id, tweet_id, sentiment_class) VALUES(3748, 1761592727593263527 , 0);]
# (Background on this error at: https://sqlalche.me/e/14/gkpj)
# Error executing query: (psycopg2.errors.UniqueViolation) duplicate key value violates unique constraint "ret_sentiment_result_pkey"
# DETAIL:  Key (id)=(24294) already exists.
#
# [SQL: INSERT INTO ret_sentiment_result (job_id, tweet_id, sentiment_class) VALUES(3748, 1761593349801382311 , 1);]
# (Background on this error at: https://sqlalche.me/e/14/gkpj)
# Error executing query: (psycopg2.errors.UniqueViolation) duplicate key value violates unique constraint "ret_sentiment_result_pkey"
# DETAIL:  Key (id)=(24295) already exists.
#
# [SQL: INSERT INTO ret_sentiment_result (job_id, tweet_id, sentiment_class) VALUES(3748, 1761594434532339937 , -1);]
# (Background on this error at: https://sqlalche.me/e/14/gkpj)
# Error executing query: (psycopg2.errors.UniqueViolation) duplicate key value violates unique constraint "ret_sentiment_result_pkey"
# DETAIL:  Key (id)=(24296) already exists.
#
# [SQL: INSERT INTO ret_sentiment_result (job_id, tweet_id, sentiment_class) VALUES(3748, 1761594689617379754 , 0);]
# (Background on this error at: https://sqlalche.me/e/14/gkpj)
# Error executing query: (psycopg2.errors.UniqueViolation) duplicate key value violates unique constraint "ret_sentiment_result_pkey"
# DETAIL:  Key (id)=(24297) already exists.
#
# [SQL: INSERT INTO ret_sentiment_result (job_id, tweet_id, sentiment_class) VALUES(3748, 1761598250275283069 , 0);]
# (Background on this error at: https://sqlalche.me/e/14/gkpj)
# Error executing query: (psycopg2.errors.UniqueViolation) duplicate key value violates unique constraint "ret_sentiment_result_pkey"
# DETAIL:  Key (id)=(24298) already exists.
#
# [SQL: INSERT INTO ret_sentiment_result (job_id, tweet_id, sentiment_class) VALUES(3748, 1761598957653053921 , 0);]
# (Background on this error at: https://sqlalche.me/e/14/gkpj)
# Error executing query: (psycopg2.errors.UniqueViolation) duplicate key value violates unique constraint "ret_sentiment_result_pkey"
# DETAIL:  Key (id)=(24299) already exists.
#
# [SQL: INSERT INTO ret_sentiment_result (job_id, tweet_id, sentiment_class) VALUES(3748, 1761599646777192692 , 1);]
# (Background on this error at: https://sqlalche.me/e/14/gkpj)
# Error executing query: (psycopg2.errors.UniqueViolation) duplicate key value violates unique constraint "ret_sentiment_result_pkey"
# DETAIL:  Key (id)=(24300) already exists.
#
# [SQL: INSERT INTO ret_sentiment_result (job_id, tweet_id, sentiment_class) VALUES(3748, 1761602928132116974 , 0);]
# (Background on this error at: https://sqlalche.me/e/14/gkpj)
# Error executing query: (psycopg2.errors.UniqueViolation) duplicate key value violates unique constraint "ret_sentiment_result_pkey"
# DETAIL:  Key (id)=(24301) already exists.
#
# [SQL: INSERT INTO ret_sentiment_result (job_id, tweet_id, sentiment_class) VALUES(3748, 1761603489506148546 , 0);]
# (Background on this error at: https://sqlalche.me/e/14/gkpj)
# Error executing query: (psycopg2.errors.UniqueViolation) duplicate key value violates unique constraint "ret_sentiment_result_pkey"
# DETAIL:  Key (id)=(24302) already exists.
#
# [SQL: INSERT INTO ret_sentiment_result (job_id, tweet_id, sentiment_class) VALUES(3748, 1761604771428065649 , 0);]
# (Background on this error at: https://sqlalche.me/e/14/gkpj)
# Error executing query: (psycopg2.errors.UniqueViolation) duplicate key value violates unique constraint "ret_sentiment_result_pkey"
# DETAIL:  Key (id)=(24303) already exists.
#
# [SQL: INSERT INTO ret_sentiment_result (job_id, tweet_id, sentiment_class) VALUES(3748, 1761605941097800042 , 0);]
# (Background on this error at: https://sqlalche.me/e/14/gkpj)
# Error executing query: (psycopg2.errors.UniqueViolation) duplicate key value violates unique constraint "ret_sentiment_result_pkey"
# DETAIL:  Key (id)=(24304) already exists.
#
# [SQL: INSERT INTO ret_sentiment_result (job_id, tweet_id, sentiment_class) VALUES(3748, 1761607845672616377 , 1);]
# (Background on this error at: https://sqlalche.me/e/14/gkpj)
# Error executing query: (psycopg2.errors.UniqueViolation) duplicate key value violates unique constraint "ret_sentiment_result_pkey"
# DETAIL:  Key (id)=(24305) already exists.
#
# [SQL: INSERT INTO ret_sentiment_result (job_id, tweet_id, sentiment_class) VALUES(3748, 1761608131652829470 , 0);]
# (Background on this error at: https://sqlalche.me/e/14/gkpj)
# Error executing query: (psycopg2.errors.UniqueViolation) duplicate key value violates unique constraint "ret_sentiment_result_pkey"
# DETAIL:  Key (id)=(24306) already exists.
#
# [SQL: INSERT INTO ret_sentiment_result (job_id, tweet_id, sentiment_class) VALUES(3748, 1761610212824560046 , 0);]
# (Background on this error at: https://sqlalche.me/e/14/gkpj)
# Error executing query: (psycopg2.errors.UniqueViolation) duplicate key value violates unique constraint "ret_sentiment_result_pkey"
# DETAIL:  Key (id)=(24307) already exists.
#
# [SQL: INSERT INTO ret_sentiment_result (job_id, tweet_id, sentiment_class) VALUES(3748, 1761615540949524896 , 0);]
# (Background on this error at: https://sqlalche.me/e/14/gkpj)
# Error executing query: (psycopg2.errors.UniqueViolation) duplicate key value violates unique constraint "ret_sentiment_result_pkey"
# DETAIL:  Key (id)=(24308) already exists.
#
# [SQL: INSERT INTO ret_sentiment_result (job_id, tweet_id, sentiment_class) VALUES(3748, 1761615804343480482 , 1);]
# (Background on this error at: https://sqlalche.me/e/14/gkpj)
# Error executing query: (psycopg2.errors.UniqueViolation) duplicate key value violates unique constraint "ret_sentiment_result_pkey"
# DETAIL:  Key (id)=(24309) already exists.
#
# [SQL: INSERT INTO ret_sentiment_result (job_id, tweet_id, sentiment_class) VALUES(3748, 1761616159340888190 , 0);]
# (Background on this error at: https://sqlalche.me/e/14/gkpj)
# Error executing query: (psycopg2.errors.UniqueViolation) duplicate key value violates unique constraint "ret_sentiment_result_pkey"
# DETAIL:  Key (id)=(24310) already exists.
#
# [SQL: INSERT INTO ret_sentiment_result (job_id, tweet_id, sentiment_class) VALUES(3748, 1761618236679008479 , 0);]
# (Background on this error at: https://sqlalche.me/e/14/gkpj)
# Error executing query: (psycopg2.errors.UniqueViolation) duplicate key value violates unique constraint "ret_sentiment_result_pkey"
# DETAIL:  Key (id)=(24311) already exists.
#
# [SQL: INSERT INTO ret_sentiment_result (job_id, tweet_id, sentiment_class) VALUES(3748, 1761618512613867970 , -1);]
# (Background on this error at: https://sqlalche.me/e/14/gkpj)
# Error executing query: (psycopg2.errors.UniqueViolation) duplicate key value violates unique constraint "ret_sentiment_result_pkey"
# DETAIL:  Key (id)=(24312) already exists.
#
# [SQL: INSERT INTO ret_sentiment_result (job_id, tweet_id, sentiment_class) VALUES(3748, 1761620647057428751 , 1);]
# (Background on this error at: https://sqlalche.me/e/14/gkpj)
# Error executing query: (psycopg2.errors.UniqueViolation) duplicate key value violates unique constraint "ret_sentiment_result_pkey"
# DETAIL:  Key (id)=(24313) already exists.
#
# [SQL: INSERT INTO ret_sentiment_result (job_id, tweet_id, sentiment_class) VALUES(3748, 1761620715550523898 , -1);]
# (Background on this error at: https://sqlalche.me/e/14/gkpj)
# Error executing query: (psycopg2.errors.UniqueViolation) duplicate key value violates unique constraint "ret_sentiment_result_pkey"
# DETAIL:  Key (id)=(24314) already exists.
#
# [SQL: INSERT INTO ret_sentiment_result (job_id, tweet_id, sentiment_class) VALUES(3748, 1761621002331799694 , 1);]
# (Background on this error at: https://sqlalche.me/e/14/gkpj)
# Error executing query: (psycopg2.errors.UniqueViolation) duplicate key value violates unique constraint "ret_sentiment_result_pkey"
# DETAIL:  Key (id)=(24315) already exists.
#
# [SQL: INSERT INTO ret_sentiment_result (job_id, tweet_id, sentiment_class) VALUES(3748, 1761621004617715820 , 0);]
# (Background on this error at: https://sqlalche.me/e/14/gkpj)
# Error executing query: (psycopg2.errors.UniqueViolation) duplicate key value violates unique constraint "ret_sentiment_result_pkey"
# DETAIL:  Key (id)=(24316) already exists.
#
# [SQL: INSERT INTO ret_sentiment_result (job_id, tweet_id, sentiment_class) VALUES(3748, 1761622042271785215 , 0);]
# (Background on this error at: https://sqlalche.me/e/14/gkpj)
# Error executing query: (psycopg2.errors.UniqueViolation) duplicate key value violates unique constraint "ret_sentiment_result_pkey"
# DETAIL:  Key (id)=(24317) already exists.
#
# [SQL: INSERT INTO ret_sentiment_result (job_id, tweet_id, sentiment_class) VALUES(3748, 1761622679545930067 , 0);]
# (Background on this error at: https://sqlalche.me/e/14/gkpj)
# Error executing query: (psycopg2.errors.UniqueViolation) duplicate key value violates unique constraint "ret_sentiment_result_pkey"
# DETAIL:  Key (id)=(24318) already exists.
#
# [SQL: INSERT INTO ret_sentiment_result (job_id, tweet_id, sentiment_class) VALUES(3748, 1761624589015392377 , 0);]
# (Background on this error at: https://sqlalche.me/e/14/gkpj)
# Error executing query: (psycopg2.errors.UniqueViolation) duplicate key value violates unique constraint "ret_sentiment_result_pkey"
# DETAIL:  Key (id)=(24319) already exists.
#
# [SQL: INSERT INTO ret_sentiment_result (job_id, tweet_id, sentiment_class) VALUES(3748, 1761629026379268148 , 0);]
# (Background on this error at: https://sqlalche.me/e/14/gkpj)
# Error executing query: (psycopg2.errors.UniqueViolation) duplicate key value violates unique constraint "ret_sentiment_result_pkey"
# DETAIL:  Key (id)=(24320) already exists.
#
# [SQL: INSERT INTO ret_sentiment_result (job_id, tweet_id, sentiment_class) VALUES(3748, 1761629177135149461 , 0);]
# (Background on this error at: https://sqlalche.me/e/14/gkpj)
# Error executing query: (psycopg2.errors.UniqueViolation) duplicate key value violates unique constraint "ret_sentiment_result_pkey"
# DETAIL:  Key (id)=(24321) already exists.
#
# [SQL: INSERT INTO ret_sentiment_result (job_id, tweet_id, sentiment_class) VALUES(3748, 1761629352801058896 , 0);]
# (Background on this error at: https://sqlalche.me/e/14/gkpj)
# Error executing query: (psycopg2.errors.UniqueViolation) duplicate key value violates unique constraint "ret_sentiment_result_pkey"
# DETAIL:  Key (id)=(24322) already exists.
#
# [SQL: INSERT INTO ret_sentiment_result (job_id, tweet_id, sentiment_class) VALUES(3748, 1761629536767357172 , 0);]
# (Background on this error at: https://sqlalche.me/e/14/gkpj)
# Error executing query: (psycopg2.errors.UniqueViolation) duplicate key value violates unique constraint "ret_sentiment_result_pkey"
# DETAIL:  Key (id)=(24323) already exists.
#
# [SQL: INSERT INTO ret_sentiment_result (job_id, tweet_id, sentiment_class) VALUES(3748, 1761633373871808737 , -1);]
# (Background on this error at: https://sqlalche.me/e/14/gkpj)
# Error executing query: (psycopg2.errors.UniqueViolation) duplicate key value violates unique constraint "ret_sentiment_result_pkey"
# DETAIL:  Key (id)=(24324) already exists.
#
# [SQL: INSERT INTO ret_sentiment_result (job_id, tweet_id, sentiment_class) VALUES(3748, 1761633839833850045 , 0);]
# (Background on this error at: https://sqlalche.me/e/14/gkpj)
# Error executing query: (psycopg2.errors.UniqueViolation) duplicate key value violates unique constraint "ret_sentiment_result_pkey"
# DETAIL:  Key (id)=(24325) already exists.
#
# [SQL: INSERT INTO ret_sentiment_result (job_id, tweet_id, sentiment_class) VALUES(3748, 1761635523226120339 , 0);]
# (Background on this error at: https://sqlalche.me/e/14/gkpj)
# Error executing query: (psycopg2.errors.UniqueViolation) duplicate key value violates unique constraint "ret_sentiment_result_pkey"
# DETAIL:  Key (id)=(24326) already exists.
#
# [SQL: INSERT INTO ret_sentiment_result (job_id, tweet_id, sentiment_class) VALUES(3748, 1761636487341469760 , 0);]
# (Background on this error at: https://sqlalche.me/e/14/gkpj)
# Error executing query: (psycopg2.errors.UniqueViolation) duplicate key value violates unique constraint "ret_sentiment_result_pkey"
# DETAIL:  Key (id)=(24327) already exists.
#
# [SQL: INSERT INTO ret_sentiment_result (job_id, tweet_id, sentiment_class) VALUES(3748, 1761637714867499304 , 0);]
# (Background on this error at: https://sqlalche.me/e/14/gkpj)
# Error executing query: (psycopg2.errors.UniqueViolation) duplicate key value violates unique constraint "ret_sentiment_result_pkey"
# DETAIL:  Key (id)=(24328) already exists.
#
# [SQL: INSERT INTO ret_sentiment_result (job_id, tweet_id, sentiment_class) VALUES(3748, 1761638654894911563 , 0);]
# (Background on this error at: https://sqlalche.me/e/14/gkpj)
# Error executing query: (psycopg2.errors.UniqueViolation) duplicate key value violates unique constraint "ret_sentiment_result_pkey"
# DETAIL:  Key (id)=(24329) already exists.
#
# [SQL: INSERT INTO ret_sentiment_result (job_id, tweet_id, sentiment_class) VALUES(3748, 1761642818911809822 , 0);]
# (Background on this error at: https://sqlalche.me/e/14/gkpj)
# Error executing query: (psycopg2.errors.UniqueViolation) duplicate key value violates unique constraint "ret_sentiment_result_pkey"
# DETAIL:  Key (id)=(24330) already exists.
#
# [SQL: INSERT INTO ret_sentiment_result (job_id, tweet_id, sentiment_class) VALUES(3748, 1761645752659616003 , 0);]
# (Background on this error at: https://sqlalche.me/e/14/gkpj)
# Error executing query: (psycopg2.errors.UniqueViolation) duplicate key value violates unique constraint "ret_sentiment_result_pkey"
# DETAIL:  Key (id)=(24331) already exists.
#
# [SQL: INSERT INTO ret_sentiment_result (job_id, tweet_id, sentiment_class) VALUES(3748, 1761646641977950576 , 0);]
# (Background on this error at: https://sqlalche.me/e/14/gkpj)
# Error executing query: (psycopg2.errors.UniqueViolation) duplicate key value violates unique constraint "ret_sentiment_result_pkey"
# DETAIL:  Key (id)=(24332) already exists.
#
# [SQL: INSERT INTO ret_sentiment_result (job_id, tweet_id, sentiment_class) VALUES(3748, 1761646714182914420 , -1);]
# (Background on this error at: https://sqlalche.me/e/14/gkpj)
# Error executing query: (psycopg2.errors.UniqueViolation) duplicate key value violates unique constraint "ret_sentiment_result_pkey"
# DETAIL:  Key (id)=(24333) already exists.
#
# [SQL: INSERT INTO ret_sentiment_result (job_id, tweet_id, sentiment_class) VALUES(3748, 1761647031138058260 , 0);]
# (Background on this error at: https://sqlalche.me/e/14/gkpj)
# Error executing query: (psycopg2.errors.UniqueViolation) duplicate key value violates unique constraint "ret_sentiment_result_pkey"
# DETAIL:  Key (id)=(24334) already exists.
#
# [SQL: INSERT INTO ret_sentiment_result (job_id, tweet_id, sentiment_class) VALUES(3748, 1761647698913251774 , -1);]
# (Background on this error at: https://sqlalche.me/e/14/gkpj)
# Error executing query: (psycopg2.errors.UniqueViolation) duplicate key value violates unique constraint "ret_sentiment_result_pkey"
# DETAIL:  Key (id)=(24335) already exists.
#
# [SQL: INSERT INTO ret_sentiment_result (job_id, tweet_id, sentiment_class) VALUES(3748, 1761647751165780094 , 0);]
# (Background on this error at: https://sqlalche.me/e/14/gkpj)
# Error executing query: (psycopg2.errors.UniqueViolation) duplicate key value violates unique constraint "ret_sentiment_result_pkey"
# DETAIL:  Key (id)=(24336) already exists.
#
# [SQL: INSERT INTO ret_sentiment_result (job_id, tweet_id, sentiment_class) VALUES(3748, 1761647867218075770 , 0);]
# (Background on this error at: https://sqlalche.me/e/14/gkpj)
# Error executing query: (psycopg2.errors.UniqueViolation) duplicate key value violates unique constraint "ret_sentiment_result_pkey"
# DETAIL:  Key (id)=(24337) already exists.
#
# [SQL: INSERT INTO ret_sentiment_result (job_id, tweet_id, sentiment_class) VALUES(3748, 1761649340228010002 , 0);]
# (Background on this error at: https://sqlalche.me/e/14/gkpj)
# Error executing query: (psycopg2.errors.UniqueViolation) duplicate key value violates unique constraint "ret_sentiment_result_pkey"
# DETAIL:  Key (id)=(24338) already exists.
#
# [SQL: INSERT INTO ret_sentiment_result (job_id, tweet_id, sentiment_class) VALUES(3748, 1761650619583201567 , 0);]
# (Background on this error at: https://sqlalche.me/e/14/gkpj)
# Error executing query: (psycopg2.errors.UniqueViolation) duplicate key value violates unique constraint "ret_sentiment_result_pkey"
# DETAIL:  Key (id)=(24339) already exists.
#
# [SQL: INSERT INTO ret_sentiment_result (job_id, tweet_id, sentiment_class) VALUES(3748, 1761652669725499596 , 0);]
# (Background on this error at: https://sqlalche.me/e/14/gkpj)
# Error executing query: (psycopg2.errors.UniqueViolation) duplicate key value violates unique constraint "ret_sentiment_result_pkey"
# DETAIL:  Key (id)=(24340) already exists.
#
# [SQL: INSERT INTO ret_sentiment_result (job_id, tweet_id, sentiment_class) VALUES(3748, 1761653453552771450 , 0);]
# (Background on this error at: https://sqlalche.me/e/14/gkpj)
# Error executing query: (psycopg2.errors.UniqueViolation) duplicate key value violates unique constraint "ret_sentiment_result_pkey"
# DETAIL:  Key (id)=(24341) already exists.
#
# [SQL: INSERT INTO ret_sentiment_result (job_id, tweet_id, sentiment_class) VALUES(3748, 1761655693336314327 , 0);]
# (Background on this error at: https://sqlalche.me/e/14/gkpj)
# Error executing query: (psycopg2.errors.UniqueViolation) duplicate key value violates unique constraint "ret_sentiment_result_pkey"
# DETAIL:  Key (id)=(24342) already exists.
#
# [SQL: INSERT INTO ret_sentiment_result (job_id, tweet_id, sentiment_class) VALUES(3748, 1761656788997574868 , 0);]
# (Background on this error at: https://sqlalche.me/e/14/gkpj)
# Error executing query: (psycopg2.errors.UniqueViolation) duplicate key value violates unique constraint "ret_sentiment_result_pkey"
# DETAIL:  Key (id)=(24343) already exists.
#
# [SQL: INSERT INTO ret_sentiment_result (job_id, tweet_id, sentiment_class) VALUES(3748, 1761657082926019058 , 1);]
# (Background on this error at: https://sqlalche.me/e/14/gkpj)
# Error executing query: (psycopg2.errors.UniqueViolation) duplicate key value violates unique constraint "ret_sentiment_result_pkey"
# DETAIL:  Key (id)=(24344) already exists.
#
# [SQL: INSERT INTO ret_sentiment_result (job_id, tweet_id, sentiment_class) VALUES(3748, 1761657388858560981 , 1);]
# (Background on this error at: https://sqlalche.me/e/14/gkpj)
# Error executing query: (psycopg2.errors.UniqueViolation) duplicate key value violates unique constraint "ret_sentiment_result_pkey"
# DETAIL:  Key (id)=(24345) already exists.
#
# [SQL: INSERT INTO ret_sentiment_result (job_id, tweet_id, sentiment_class) VALUES(3748, 1761657929617617105 , 0);]
# (Background on this error at: https://sqlalche.me/e/14/gkpj)
# Error executing query: (psycopg2.errors.UniqueViolation) duplicate key value violates unique constraint "ret_sentiment_result_pkey"
# DETAIL:  Key (id)=(24346) already exists.
#
# [SQL: INSERT INTO ret_sentiment_result (job_id, tweet_id, sentiment_class) VALUES(3748, 1761657989088600070 , 0);]
# (Background on this error at: https://sqlalche.me/e/14/gkpj)
# Error executing query: (psycopg2.errors.UniqueViolation) duplicate key value violates unique constraint "ret_sentiment_result_pkey"
# DETAIL:  Key (id)=(24347) already exists.
#
# [SQL: INSERT INTO ret_sentiment_result (job_id, tweet_id, sentiment_class) VALUES(3748, 1761658920203075974 , -1);]
# (Background on this error at: https://sqlalche.me/e/14/gkpj)
# Error executing query: (psycopg2.errors.UniqueViolation) duplicate key value violates unique constraint "ret_sentiment_result_pkey"
# DETAIL:  Key (id)=(24348) already exists.
#
# [SQL: INSERT INTO ret_sentiment_result (job_id, tweet_id, sentiment_class) VALUES(3748, 1761660337949135348 , 0);]
# (Background on this error at: https://sqlalche.me/e/14/gkpj)
# Error executing query: (psycopg2.errors.UniqueViolation) duplicate key value violates unique constraint "ret_sentiment_result_pkey"
# DETAIL:  Key (id)=(24349) already exists.
#
# [SQL: INSERT INTO ret_sentiment_result (job_id, tweet_id, sentiment_class) VALUES(3748, 1761660693315784980 , 0);]
# (Background on this error at: https://sqlalche.me/e/14/gkpj)
# Error executing query: (psycopg2.errors.UniqueViolation) duplicate key value violates unique constraint "ret_sentiment_result_pkey"
# DETAIL:  Key (id)=(24350) already exists.
#
# [SQL: INSERT INTO ret_sentiment_result (job_id, tweet_id, sentiment_class) VALUES(3748, 1761661287866769863 , 0);]
# (Background on this error at: https://sqlalche.me/e/14/gkpj)
# Error executing query: (psycopg2.errors.UniqueViolation) duplicate key value violates unique constraint "ret_sentiment_result_pkey"
# DETAIL:  Key (id)=(24351) already exists.
#
# [SQL: INSERT INTO ret_sentiment_result (job_id, tweet_id, sentiment_class) VALUES(3748, 1761662533742776367 , -1);]
# (Background on this error at: https://sqlalche.me/e/14/gkpj)
# Error executing query: (psycopg2.errors.UniqueViolation) duplicate key value violates unique constraint "ret_sentiment_result_pkey"
# DETAIL:  Key (id)=(24352) already exists.
#
# [SQL: INSERT INTO ret_sentiment_result (job_id, tweet_id, sentiment_class) VALUES(3748, 1761663540342161904 , 0);]
# (Background on this error at: https://sqlalche.me/e/14/gkpj)
# Error executing query: (psycopg2.errors.UniqueViolation) duplicate key value violates unique constraint "ret_sentiment_result_pkey"
# DETAIL:  Key (id)=(24353) already exists.
#
# ...
# Error executing query: (psycopg2.errors.UniqueViolation) duplicate key value violates unique constraint "ret_sentiment_result_pkey"
# DETAIL:  Key (id)=(26259) already exists.
#
# [SQL: INSERT INTO ret_sentiment_result (job_id, tweet_id, sentiment_class) VALUES(3748, 1763829106213564571 , 1);]
# (Background on this error at: https://sqlalche.me/e/14/gkpj)
# Error executing query: (psycopg2.errors.UniqueViolation) duplicate key value violates unique constraint "ret_sentiment_result_pkey"
# DETAIL:  Key (id)=(26260) already exists.
#
# [SQL: INSERT INTO ret_sentiment_result (job_id, tweet_id, sentiment_class) VALUES(3748, 1763829166603157505 , 1);]
# (Background on this error at: https://sqlalche.me/e/14/gkpj)
# Error executing query: (psycopg2.errors.UniqueViolation) duplicate key value violates unique constraint "ret_sentiment_result_pkey"
# DETAIL:  Key (id)=(26261) already exists.
#
# [SQL: INSERT INTO ret_sentiment_result (job_id, tweet_id, sentiment_class) VALUES(3748, 1763829397902266777 , -1);]
# (Background on this error at: https://sqlalche.me/e/14/gkpj)
# Error executing query: (psycopg2.errors.UniqueViolation) duplicate key value violates unique constraint "ret_sentiment_result_pkey"
# DETAIL:  Key (id)=(26262) already exists.
#
# [SQL: INSERT INTO ret_sentiment_result (job_id, tweet_id, sentiment_class) VALUES(3748, 1763829732058321160 , 0);]
# (Background on this error at: https://sqlalche.me/e/14/gkpj)
# Error executing query: (psycopg2.errors.UniqueViolation) duplicate key value violates unique constraint "ret_sentiment_result_pkey"
# DETAIL:  Key (id)=(26263) already exists.
#
# [SQL: INSERT INTO ret_sentiment_result (job_id, tweet_id, sentiment_class) VALUES(3748, 1763829860089409894 , 0);]
# (Background on this error at: https://sqlalche.me/e/14/gkpj)
# Error executing query: (psycopg2.errors.UniqueViolation) duplicate key value violates unique constraint "ret_sentiment_result_pkey"
# DETAIL:  Key (id)=(26264) already exists.
#
# [SQL: INSERT INTO ret_sentiment_result (job_id, tweet_id, sentiment_class) VALUES(3748, 1763829902472782269 , 1);]
# (Background on this error at: https://sqlalche.me/e/14/gkpj)
# Error executing query: (psycopg2.errors.UniqueViolation) duplicate key value violates unique constraint "ret_sentiment_result_pkey"
# DETAIL:  Key (id)=(26265) already exists.
#
# [SQL: INSERT INTO ret_sentiment_result (job_id, tweet_id, sentiment_class) VALUES(3748, 1763829908516782301 , 1);]
# (Background on this error at: https://sqlalche.me/e/14/gkpj)
# Error executing query: (psycopg2.errors.UniqueViolation) duplicate key value violates unique constraint "ret_sentiment_result_pkey"
# DETAIL:  Key (id)=(26266) already exists.
#
# [SQL: INSERT INTO ret_sentiment_result (job_id, tweet_id, sentiment_class) VALUES(3748, 1763830237526474808 , 1);]
# (Background on this error at: https://sqlalche.me/e/14/gkpj)
# Error executing query: (psycopg2.errors.UniqueViolation) duplicate key value violates unique constraint "ret_sentiment_result_pkey"
# DETAIL:  Key (id)=(26267) already exists.
#
# [SQL: INSERT INTO ret_sentiment_result (job_id, tweet_id, sentiment_class) VALUES(3748, 1763830574891061405 , 1);]
# (Background on this error at: https://sqlalche.me/e/14/gkpj)
# Error executing query: (psycopg2.errors.UniqueViolation) duplicate key value violates unique constraint "ret_sentiment_result_pkey"
# DETAIL:  Key (id)=(26268) already exists.
#
# [SQL: INSERT INTO ret_sentiment_result (job_id, tweet_id, sentiment_class) VALUES(3748, 1763831446395899963 , 1);]
# (Background on this error at: https://sqlalche.me/e/14/gkpj)
# Error executing query: (psycopg2.errors.UniqueViolation) duplicate key value violates unique constraint "ret_sentiment_result_pkey"
# DETAIL:  Key (id)=(26269) already exists.
#
# [SQL: INSERT INTO ret_sentiment_result (job_id, tweet_id, sentiment_class) VALUES(3748, 1763831882733813915 , 1);]
# (Background on this error at: https://sqlalche.me/e/14/gkpj)
# Error executing query: (psycopg2.errors.UniqueViolation) duplicate key value violates unique constraint "ret_sentiment_result_pkey"
# DETAIL:  Key (id)=(26270) already exists.
#
# [SQL: INSERT INTO ret_sentiment_result (job_id, tweet_id, sentiment_class) VALUES(3748, 1763832019367481661 , 0);]
# (Background on this error at: https://sqlalche.me/e/14/gkpj)
# Error executing query: (psycopg2.errors.UniqueViolation) duplicate key value violates unique constraint "ret_sentiment_result_pkey"
# DETAIL:  Key (id)=(26271) already exists.
#
# [SQL: INSERT INTO ret_sentiment_result (job_id, tweet_id, sentiment_class) VALUES(3748, 1763832178918793555 , 1);]
# (Background on this error at: https://sqlalche.me/e/14/gkpj)
# Error executing query: (psycopg2.errors.UniqueViolation) duplicate key value violates unique constraint "ret_sentiment_result_pkey"
# DETAIL:  Key (id)=(26272) already exists.
#
# [SQL: INSERT INTO ret_sentiment_result (job_id, tweet_id, sentiment_class) VALUES(3748, 1763832317855039918 , 0);]
# (Background on this error at: https://sqlalche.me/e/14/gkpj)
# Error executing query: (psycopg2.errors.UniqueViolation) duplicate key value violates unique constraint "ret_sentiment_result_pkey"
# DETAIL:  Key (id)=(26273) already exists.
#
# [SQL: INSERT INTO ret_sentiment_result (job_id, tweet_id, sentiment_class) VALUES(3748, 1763832729345630616 , 0);]
# (Background on this error at: https://sqlalche.me/e/14/gkpj)
# Error executing query: (psycopg2.errors.UniqueViolation) duplicate key value violates unique constraint "ret_sentiment_result_pkey"
# DETAIL:  Key (id)=(26274) already exists.
#
# [SQL: INSERT INTO ret_sentiment_result (job_id, tweet_id, sentiment_class) VALUES(3748, 1763832898925318527 , 1);]
# (Background on this error at: https://sqlalche.me/e/14/gkpj)
# Error executing query: (psycopg2.errors.UniqueViolation) duplicate key value violates unique constraint "ret_sentiment_result_pkey"
# DETAIL:  Key (id)=(26275) already exists.
#
# [SQL: INSERT INTO ret_sentiment_result (job_id, tweet_id, sentiment_class) VALUES(3748, 1763833124352659627 , 1);]
# (Background on this error at: https://sqlalche.me/e/14/gkpj)
# Error executing query: (psycopg2.errors.UniqueViolation) duplicate key value violates unique constraint "ret_sentiment_result_pkey"
# DETAIL:  Key (id)=(26276) already exists.
#
# [SQL: INSERT INTO ret_sentiment_result (job_id, tweet_id, sentiment_class) VALUES(3748, 1763833155939692969 , 1);]
# (Background on this error at: https://sqlalche.me/e/14/gkpj)
# Error executing query: (psycopg2.OperationalError) connection to server at "98.98.117.105", port 5432 failed: FATAL:  sorry, too many clients already
# connection to server at "98.98.117.105", port 5432 failed: FATAL:  sorry, too many clients already
#
# (Background on this error at: https://sqlalche.me/e/14/e3q8)
# Error executing query: (psycopg2.errors.UniqueViolation) duplicate key value violates unique constraint "ret_sentiment_result_pkey"
# DETAIL:  Key (id)=(26277) already exists.
#
# [SQL: INSERT INTO ret_sentiment_result (job_id, tweet_id, sentiment_class) VALUES(3748, 1763833449121468859 , 1);]
# (Background on this error at: https://sqlalche.me/e/14/gkpj)
# Error executing query: (psycopg2.OperationalError) connection to server at "98.98.117.105", port 5432 failed: FATAL:  sorry, too many clients already
# connection to server at "98.98.117.105", port 5432 failed: FATAL:  sorry, too many clients already
#
# (Background on this error at: https://sqlalche.me/e/14/e3q8)
# Error executing query: (psycopg2.errors.UniqueViolation) duplicate key value violates unique constraint "ret_sentiment_result_pkey"
# DETAIL:  Key (id)=(26278) already exists.
#
# [SQL: INSERT INTO ret_sentiment_result (job_id, tweet_id, sentiment_class) VALUES(3748, 1763833758594007203 , 1);]
# (Background on this error at: https://sqlalche.me/e/14/gkpj)
# Error executing query: (psycopg2.OperationalError) connection to server at "98.98.117.105", port 5432 failed: FATAL:  sorry, too many clients already
# connection to server at "98.98.117.105", port 5432 failed: FATAL:  sorry, too many clients already
#
# (Background on this error at: https://sqlalche.me/e/14/e3q8)
# Error executing query: (psycopg2.OperationalError) connection to server at "98.98.117.105", port 5432 failed: FATAL:  sorry, too many clients already
# connection to server at "98.98.117.105", port 5432 failed: FATAL:  sorry, too many clients already
#
# (Background on this error at: https://sqlalche.me/e/14/e3q8)
# Error executing query: (psycopg2.errors.UniqueViolation) duplicate key value violates unique constraint "ret_sentiment_result_pkey"
# DETAIL:  Key (id)=(26279) already exists.
#
# [SQL: INSERT INTO ret_sentiment_result (job_id, tweet_id, sentiment_class) VALUES(3748, 1763836858604347701 , 1);]
# (Background on this error at: https://sqlalche.me/e/14/gkpj)
# Error executing query: (psycopg2.errors.UniqueViolation) duplicate key value violates unique constraint "ret_sentiment_result_pkey"
# DETAIL:  Key (id)=(26280) already exists.
#
# [SQL: INSERT INTO ret_sentiment_result (job_id, tweet_id, sentiment_class) VALUES(3748, 1763837204928119291 , 0);]
# (Background on this error at: https://sqlalche.me/e/14/gkpj)
# Error executing query: (psycopg2.errors.UniqueViolation) duplicate key value violates unique constraint "ret_sentiment_result_pkey"
# DETAIL:  Key (id)=(26281) already exists.
#
# [SQL: INSERT INTO ret_sentiment_result (job_id, tweet_id, sentiment_class) VALUES(3748, 1763837391624900978 , 1);]
# (Background on this error at: https://sqlalche.me/e/14/gkpj)
# Error executing query: (psycopg2.errors.UniqueViolation) duplicate key value violates unique constraint "ret_sentiment_result_pkey"
# DETAIL:  Key (id)=(26282) already exists.
#
# [SQL: INSERT INTO ret_sentiment_result (job_id, tweet_id, sentiment_class) VALUES(3748, 1763837666637013202 , 1);]
# (Background on this error at: https://sqlalche.me/e/14/gkpj)
# Error executing query: (psycopg2.errors.UniqueViolation) duplicate key value violates unique constraint "ret_sentiment_result_pkey"
# DETAIL:  Key (id)=(26283) already exists.
#
# [SQL: INSERT INTO ret_sentiment_result (job_id, tweet_id, sentiment_class) VALUES(3748, 1763837701764292973 , 0);]
# (Background on this error at: https://sqlalche.me/e/14/gkpj)
# Error executing query: (psycopg2.errors.UniqueViolation) duplicate key value violates unique constraint "ret_sentiment_result_pkey"
# DETAIL:  Key (id)=(26284) already exists.
#
# [SQL: INSERT INTO ret_sentiment_result (job_id, tweet_id, sentiment_class) VALUES(3748, 1763837707070169227 , 0);]
# (Background on this error at: https://sqlalche.me/e/14/gkpj)
# Error executing query: (psycopg2.errors.UniqueViolation) duplicate key value violates unique constraint "ret_sentiment_result_pkey"
# DETAIL:  Key (id)=(26285) already exists.
#
# [SQL: INSERT INTO ret_sentiment_result (job_id, tweet_id, sentiment_class) VALUES(3748, 1763838552948027785 , 1);]
# (Background on this error at: https://sqlalche.me/e/14/gkpj)
# Error executing query: (psycopg2.errors.UniqueViolation) duplicate key value violates unique constraint "ret_sentiment_result_pkey"
# DETAIL:  Key (id)=(26286) already exists.
#
# [SQL: INSERT INTO ret_sentiment_result (job_id, tweet_id, sentiment_class) VALUES(3748, 1763838578717831397 , 1);]
# (Background on this error at: https://sqlalche.me/e/14/gkpj)
# Error executing query: (psycopg2.errors.UniqueViolation) duplicate key value violates unique constraint "ret_sentiment_result_pkey"
# DETAIL:  Key (id)=(26287) already exists.
#
# [SQL: INSERT INTO ret_sentiment_result (job_id, tweet_id, sentiment_class) VALUES(3748, 1763838640537694343 , 1);]
# (Background on this error at: https://sqlalche.me/e/14/gkpj)
# Error executing query: (psycopg2.errors.UniqueViolation) duplicate key value violates unique constraint "ret_sentiment_result_pkey"
# DETAIL:  Key (id)=(26288) already exists.
#
# [SQL: INSERT INTO ret_sentiment_result (job_id, tweet_id, sentiment_class) VALUES(3748, 1763839322133078132 , 0);]
# (Background on this error at: https://sqlalche.me/e/14/gkpj)
# Error executing query: (psycopg2.errors.UniqueViolation) duplicate key value violates unique constraint "ret_sentiment_result_pkey"
# DETAIL:  Key (id)=(26289) already exists.
#
# [SQL: INSERT INTO ret_sentiment_result (job_id, tweet_id, sentiment_class) VALUES(3748, 1763839666732859746 , 0);]
# (Background on this error at: https://sqlalche.me/e/14/gkpj)
# Error executing query: (psycopg2.errors.UniqueViolation) duplicate key value violates unique constraint "ret_sentiment_result_pkey"
# DETAIL:  Key (id)=(26290) already exists.
#
# [SQL: INSERT INTO ret_sentiment_result (job_id, tweet_id, sentiment_class) VALUES(3748, 1763840144615100636 , 0);]
# (Background on this error at: https://sqlalche.me/e/14/gkpj)
# Error executing query: (psycopg2.errors.UniqueViolation) duplicate key value violates unique constraint "ret_sentiment_result_pkey"
# DETAIL:  Key (id)=(26291) already exists.
#
# [SQL: INSERT INTO ret_sentiment_result (job_id, tweet_id, sentiment_class) VALUES(3748, 1763840162734449056 , 1);]
# (Background on this error at: https://sqlalche.me/e/14/gkpj)
# Error executing query: (psycopg2.errors.UniqueViolation) duplicate key value violates unique constraint "ret_sentiment_result_pkey"
# DETAIL:  Key (id)=(26292) already exists.
#
# [SQL: INSERT INTO ret_sentiment_result (job_id, tweet_id, sentiment_class) VALUES(3748, 1763840260994412893 , 1);]
# (Background on this error at: https://sqlalche.me/e/14/gkpj)
# Error executing query: (psycopg2.errors.UniqueViolation) duplicate key value violates unique constraint "ret_sentiment_result_pkey"
# DETAIL:  Key (id)=(26293) already exists.
#
# [SQL: INSERT INTO ret_sentiment_result (job_id, tweet_id, sentiment_class) VALUES(3748, 1763840336231911856 , 0);]
# (Background on this error at: https://sqlalche.me/e/14/gkpj)
# Error executing query: (psycopg2.errors.UniqueViolation) duplicate key value violates unique constraint "ret_sentiment_result_pkey"
# DETAIL:  Key (id)=(26294) already exists.
#
# [SQL: INSERT INTO ret_sentiment_result (job_id, tweet_id, sentiment_class) VALUES(3748, 1763840816118903020 , 0);]
# (Background on this error at: https://sqlalche.me/e/14/gkpj)
# Error executing query: (psycopg2.errors.UniqueViolation) duplicate key value violates unique constraint "ret_sentiment_result_pkey"
# DETAIL:  Key (id)=(26295) already exists.
#
# [SQL: INSERT INTO ret_sentiment_result (job_id, tweet_id, sentiment_class) VALUES(3748, 1763840918325784951 , 0);]
# (Background on this error at: https://sqlalche.me/e/14/gkpj)
# Error executing query: (psycopg2.errors.UniqueViolation) duplicate key value violates unique constraint "ret_sentiment_result_pkey"
# DETAIL:  Key (id)=(26296) already exists.
#
# [SQL: INSERT INTO ret_sentiment_result (job_id, tweet_id, sentiment_class) VALUES(3748, 1763840952387641850 , 0);]
# (Background on this error at: https://sqlalche.me/e/14/gkpj)
# Error executing query: (psycopg2.errors.UniqueViolation) duplicate key value violates unique constraint "ret_sentiment_result_pkey"
# DETAIL:  Key (id)=(26297) already exists.
#
# [SQL: INSERT INTO ret_sentiment_result (job_id, tweet_id, sentiment_class) VALUES(3748, 1763841135292952674 , 1);]
# (Background on this error at: https://sqlalche.me/e/14/gkpj)
# Error executing query: (psycopg2.errors.UniqueViolation) duplicate key value violates unique constraint "ret_sentiment_result_pkey"
# DETAIL:  Key (id)=(26298) already exists.
#
# [SQL: INSERT INTO ret_sentiment_result (job_id, tweet_id, sentiment_class) VALUES(3748, 1763841322509844533 , 0);]
# (Background on this error at: https://sqlalche.me/e/14/gkpj)
# Error executing query: (psycopg2.errors.UniqueViolation) duplicate key value violates unique constraint "ret_sentiment_result_pkey"
# DETAIL:  Key (id)=(26299) already exists.
#
# [SQL: INSERT INTO ret_sentiment_result (job_id, tweet_id, sentiment_class) VALUES(3748, 1763842111399661762 , 1);]
# (Background on this error at: https://sqlalche.me/e/14/gkpj)
# Error executing query: (psycopg2.errors.UniqueViolation) duplicate key value violates unique constraint "ret_sentiment_result_pkey"
# DETAIL:  Key (id)=(26300) already exists.
#
# [SQL: INSERT INTO ret_sentiment_result (job_id, tweet_id, sentiment_class) VALUES(3748, 1763842281239691384 , -1);]
# (Background on this error at: https://sqlalche.me/e/14/gkpj)

# %%
# record process finish
# closing .... report back job status into rdbms
sql = "update screen_analisis_ai set end_process = now(), status = 3, processby_id = 1 where id = %s" % (str(const_job_id))
execute_query_psql(sql)

sql = "update screen_analisis_ai set duration = EXTRACT(EPOCH FROM (end_process - start_process)) where id = " + str(const_job_id)
execute_query_psql(sql)
# Out:
# Query executed successfully. 1 rows affected.
# Query executed successfully. 1 rows affected.
# 1

# %%
# wait 10 seconds before finished
import time
time.sleep(10)
