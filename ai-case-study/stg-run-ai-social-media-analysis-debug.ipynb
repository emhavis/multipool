# %%
#
# code for text clustering process
#

import pandas as pd
import re
from sklearn.feature_extraction.text import TfidfVectorizer
from sklearn.cluster import MiniBatchKMeans
from sklearn.metrics import silhouette_score
import json
import numpy as np
import plotly.express as px
import zipfile
import os
from sklearn.metrics.pairwise import cosine_similarity
import matplotlib.pyplot as plt
from wordcloud import WordCloud
import numpy as np
from collections import Counter
from scipy.sparse import vstack
from scipy.sparse import csr_matrix
from sklearn.decomposition import PCA

## Internal Data Connector
import data_connector

# Data cleaning function
def clean_text(text):
    text = text.lower()
    text = re.sub(r'@\w+', '', text)  # Remove mentions
    text = re.sub(r'#\w+', '', text)  # Remove hashtags
    text = re.sub(r'http\S+', '', text)  # Remove URLs
    text = re.sub(r'[^a-z\s]', '', text)  # Remove punctuation and numbers
    text = re.sub(r'\s+', ' ', text).strip()  # Remove extra spaces
    return text

def cluster_and_return(df, max_clusters=15, batch_size=10000):
    # Clean the text data
    df['cleaned_text'] = df['text_content'].apply(clean_text)
    
    # Initialize the TF-IDF vectorizer
    vectorizer = TfidfVectorizer(stop_words='english', max_features=1000)
    
    # Fit the vectorizer on the entire dataset to establish the vocabulary
    vectorizer.fit(df['cleaned_text'])
    
    # Transform the data in batches
    n_batches = int(np.ceil(len(df) / batch_size))
    X = csr_matrix((0, len(vectorizer.vocabulary_)), dtype=np.float64)
    
    for i in range(n_batches):
        batch_texts = df['cleaned_text'][i * batch_size:(i + 1) * batch_size]
        X_batch = vectorizer.transform(batch_texts)
        X = vstack([X, X_batch])
    
    # Determine the optimal number of clusters using Elbow Method and Silhouette Score
    def determine_optimal_clusters(X, max_clusters):
        wcss = []
        silhouette_scores = []
        for i in range(2, max_clusters):  # start from 2 clusters
            kmeans = MiniBatchKMeans(n_clusters=i, random_state=42, batch_size=batch_size)
            kmeans.fit(X)
            wcss.append(kmeans.inertia_)
            if i > 1:
                silhouette_avg = silhouette_score(X, kmeans.labels_)
                silhouette_scores.append(silhouette_avg)

        # Determine optimal number of clusters based on highest silhouette score
        optimal_clusters = silhouette_scores.index(max(silhouette_scores)) + 2  # +2 because silhouette_scores starts from 2 clusters
        return optimal_clusters

    optimal_clusters = determine_optimal_clusters(X, max_clusters)
    print(f'Optimal number of clusters: {optimal_clusters}')

    # Perform clustering with the optimal number of clusters
    kmeans = MiniBatchKMeans(n_clusters=optimal_clusters, random_state=42, batch_size=batch_size)
    kmeans.fit(X)
    df['cluster_no'] = kmeans.labels_

    # Calculate average similarity score for each cluster using sparse matrix operations
    cluster_scores = []
    cluster_avg_similarities = []

    for cluster in range(optimal_clusters):
        indices = np.where(kmeans.labels_ == cluster)[0]
        if len(indices) > 1:
            cluster_sim = cosine_similarity(X[indices])
            avg_sim = cluster_sim[np.triu_indices(len(indices), k=1)].mean()
        else:
            avg_sim = 1.0  # If there's only one member in the cluster, similarity is 1
        cluster_scores.extend([avg_sim] * len(indices))
        cluster_avg_similarities.append(avg_sim)

    df['cluster_score'] = cluster_scores

    # calculate the PCA metric
    X = TfidfVectorizer(max_features=1000).fit_transform(df['text_content'])
    pca = PCA(n_components=2, random_state=42)
    pca_components = pca.fit_transform(X.toarray())
    df['pca1'] = pca_components[:, 0]
    df['pca2'] = pca_components[:, 1]

    # Drop the temporary cleaned_text column
    df = df.drop(columns=['cleaned_text'])

    # Return the updated DataFrame and cluster average similarities
    return df, cluster_avg_similarities

# %%
#
# preload the jobs
#
strSQL = """
insert 	into screen_analisis_ai (jenis_analisa, tanggal, created, 
createdby_id, active, status, monitoring_id )
select 	'100',now(), now(), 1, 1, 1, a.id 
from 	monitoring a
where 	status = 3 
		and cast(a.id as varchar) not in (select monitoring_id from 
			    screen_analisis_ai where jenis_analisa = '100')
		and extract(year from updated_date) = 2024
		and extract(month from updated_date) in (8,9,10,11,12)
order by updated_date desc 
limit 1
"""

# data_connector.execute_query_psql(strSQL)

strSQL = """
select 	a.id as jobsid,
        a.*,
		d.id as key_monitoring_media_social, 
		e.id as key_monitoring_media_online,
		c.*
from screen_analisis_ai a 
	inner join monitoring_search c 
		on cast(c.monitoring_id as varchar) = cast(a.monitoring_id as varchar) 
	left join monitoring_media_social d
		on d.monitoring_id = c.monitoring_id
	left outer join monitoring_media_online e
		on e.monitoring_id = c.monitoring_id 
where a.monitoring_id = '5b1e4773-2008-4e3a-a0a6-0e625302fa4e'
"""

df_job = data_connector.execute_query_psql(strSQL)
if len(df_job) == 0:
    # get out, nothing to do
    print('Zero jobs, quitting now')
    quit()
    
similarity_treshold = 0.9
i_process_id = df_job['jobsid'][0]
screen_name = ''
database_keyword_id = df_job['key_monitoring_media_social'][0]
social_media_monitoring_id = df_job['key_monitoring_media_social'][0]
media_online_monitoring_id = df_job['key_monitoring_media_online'][0]

# print(database_keyword_id)
print(similarity_treshold)
print(i_process_id)
print(social_media_monitoring_id)
print(media_online_monitoring_id)


# Prepare SQL Statement
print(i_process_id)
sql = "update screen_analisis_ai set status = 2, last_status_update = now(), start_process = now() where id = %s"
sql = sql.replace('%s', str(i_process_id))

print(sql)
row_count = data_connector.execute_query_psql(sql)
print('update ' + str(row_count) + ' rows')
# Out:
# 0.9
# 6708
# 67a4e45c-9eeb-49fd-a21e-59ddb2ef0865
# None
# 6708
# update screen_analisis_ai set status = 2, last_status_update = now(), start_process = now() where id = 6708
# update 1 rows

# %%
# prepare function to record result
def record_result(result_df, cluster_avg_similarities, i_platform_id):
    # result_df, cluster_avg_similarities
    for i in range(0, len(result_df)):
        ssql = """
        insert into ret_cluster_result_monitor (ref_id, cluster_no, platform_id,
        job_id, cluster_score,pca_1, pca_2) 
        values ('%s',%s, %s, %s, %s, '%s', '%s')
        """

        # builds str 
        ssql = ssql % (str(result_df['ref_id'][i]), str(result_df['cluster_no'][i]), str(i_platform_id), str(i_process_id), str(cluster_avg_similarities[result_df['cluster_no'][i]]), str(result_df['pca1'][i]), str(result_df['pca2'][i]))
        # print(ssql)
        data_connector.execute_query_psql(ssql)

# Processing jobs for each platform
import logging
import psycopg2
from psycopg2 import sql

# Configure logging
logging.basicConfig(level=logging.ERROR, format='%(asctime)s - %(levelname)s - %(message)s')

# Define a function to log errors to PostgreSQL
def log_error_to_postgresql(message):
    ssql = """
    insert into ret_analysis_parameter (job_id, param_id, param_name ,param_value)
    values (%s, %s, '%s', '%s')
    """ % (i_process_id, 99, 'ERR', message)
    
    # print(ssql)
    data_connector.execute_query_psql(ssql)

# Function to check the DataFrame size and throw an error if it contains less than 100 rows
def check_dataset_size(df):
    if len(df) < 100:
        raise ValueError("dataset population less than 100 (%s), stopping jobs" % str(len(df)))

# Processing jobs for each platform
# 10 = tiktok
# 20 = youtube
# 30 = instagram_post
# 40 = facebook_post
# 50 = google_result
# 60 = twitter_tweets

iRowCount = 0

try:
    if df_job['is_tiktok'][0]:
        sql_query = '''
        select id as ref_id, "desc" as text_content 
        from tiktok 
        where monitoring_id = '%s' -- 10
        '''
        i_platform_id = 10
        df = data_connector.execute_query_psql(sql_query % (social_media_monitoring_id))
        check_dataset_size(df)
        if len(df) != 0:
            result_df, cluster_avg_similarities = cluster_and_return(df)
            record_result(result_df, cluster_avg_similarities, i_platform_id)
            iRowCount = iRowCount + len(df)
except Exception as e:
    error_message = f"Error processing TikTok data: {str(e)}"
    logging.error(error_message)
    log_error_to_postgresql(error_message)

try:
    if df_job['is_youtube'][0]:
        sql_query = '''
        select id as ref_id, title as text_content
        from youtube 
        where monitoring_id = '%s' -- 20
        '''
        i_platform_id = 20
        df = data_connector.execute_query_psql(sql_query % (social_media_monitoring_id))
        check_dataset_size(df)
        if len(df) != 0:
            result_df, cluster_avg_similarities = cluster_and_return(df)
            record_result(result_df, cluster_avg_similarities, i_platform_id)
            iRowCount = iRowCount + len(df)
except Exception as e:
    error_message = f"Error processing YouTube data: {str(e)}"
    logging.error(error_message)
    log_error_to_postgresql(error_message)

try:
    if df_job['is_instagram'][0]:
        sql_query = '''
        select id as ref_id, content as text_content
        from instagram_post 
        where monitoring_id = '%s' -- 30
        '''
        i_platform_id = 30
        df = data_connector.execute_query_psql(sql_query % (social_media_monitoring_id))
        check_dataset_size(df)
        if len(df) != 0:
            result_df, cluster_avg_similarities = cluster_and_return(df)
            record_result(result_df, cluster_avg_similarities, i_platform_id)
            iRowCount = iRowCount + len(df)
except Exception as e:
    error_message = f"Error processing Instagram data: {str(e)}"
    logging.error(error_message)
    log_error_to_postgresql(error_message)

try:
    if df_job['is_facebook'][0]:
        sql_query = '''
        select id as ref_id, "description" as text_content
        from facebook_post 
        where monitoring_id = '%s' -- 40
        and length(trim("description")) > 0
        '''
        i_platform_id = 40
        df = data_connector.execute_query_psql(sql_query % (social_media_monitoring_id))
        check_dataset_size(df)
        if len(df) != 0:
            result_df, cluster_avg_similarities = cluster_and_return(df)
            record_result(result_df, cluster_avg_similarities, i_platform_id)
            iRowCount = iRowCount + len(df)
except Exception as e:
    error_message = f"Error processing Facebook data: {str(e)}"
    logging.error(error_message)
    log_error_to_postgresql(error_message)

try:
    if df_job['is_google'][0]:
        sql_query = '''
            select id as ref_id, "description" as text_content
            from google_result 
            where monitoring_id = '%s' -- 50
        '''
        i_platform_id = 50
        df = data_connector.execute_query_psql(sql_query % (media_online_monitoring_id))
        check_dataset_size(df)
        if len(df) != 0:
            result_df, cluster_avg_similarities = cluster_and_return(df)
            record_result(result_df, cluster_avg_similarities, i_platform_id)
            iRowCount = iRowCount + len(df)
except Exception as e:
    error_message = f"Error processing Google data: {str(e)}"
    logging.error(error_message)
    log_error_to_postgresql(error_message)

try:
    if df_job['is_twitter'][0]:
        sql_query = '''
        select id as ref_id, tweet as text_content
        from twitter_tweets 
        where monitoring_id = '%s' -- 60
        '''
        i_platform_id = 60
        df = data_connector.execute_query_psql(sql_query % (social_media_monitoring_id))
        check_dataset_size(df)
        if len(df) != 0:
            result_df, cluster_avg_similarities = cluster_and_return(df)
            record_result(result_df, cluster_avg_similarities, i_platform_id)
            iRowCount = iRowCount + len(df)
except Exception as e:
    error_message = f"Error processing Twitter data: {str(e)}"
    logging.error(error_message)
    log_error_to_postgresql(error_message)

print("Total Processed Data: " + str(iRowCount))
# Out:
# Optimal number of clusters: 14
# Error executing query: (psycopg2.OperationalError) connection to server at "128.1.227.35", port 5432 failed: FATAL:  sorry, too many clients already
# connection to server at "128.1.227.35", port 5432 failed: FATAL:  sorry, too many clients already
#
# (Background on this error at: https://sqlalche.me/e/20/e3q8)
# Error executing query: (psycopg2.OperationalError) connection to server at "128.1.227.35", port 5432 failed: FATAL:  sorry, too many clients already
# connection to server at "128.1.227.35", port 5432 failed: FATAL:  sorry, too many clients already
#
# (Background on this error at: https://sqlalche.me/e/20/e3q8)
# Error executing query: (psycopg2.OperationalError) connection to server at "128.1.227.35", port 5432 failed: FATAL:  sorry, too many clients already
# connection to server at "128.1.227.35", port 5432 failed: FATAL:  sorry, too many clients already
#
# (Background on this error at: https://sqlalche.me/e/20/e3q8)
# Error executing query: (psycopg2.OperationalError) connection to server at "128.1.227.35", port 5432 failed: FATAL:  sorry, too many clients already
# connection to server at "128.1.227.35", port 5432 failed: FATAL:  sorry, too many clients already
#
# (Background on this error at: https://sqlalche.me/e/20/e3q8)
# Error executing query: (psycopg2.OperationalError) connection to server at "128.1.227.35", port 5432 failed: FATAL:  sorry, too many clients already
# connection to server at "128.1.227.35", port 5432 failed: FATAL:  sorry, too many clients already
#
# (Background on this error at: https://sqlalche.me/e/20/e3q8)
# Error executing query: (psycopg2.OperationalError) connection to server at "128.1.227.35", port 5432 failed: FATAL:  sorry, too many clients already
# connection to server at "128.1.227.35", port 5432 failed: FATAL:  sorry, too many clients already
#
# (Background on this error at: https://sqlalche.me/e/20/e3q8)
# Error executing query: (psycopg2.OperationalError) connection to server at "128.1.227.35", port 5432 failed: FATAL:  sorry, too many clients already
# connection to server at "128.1.227.35", port 5432 failed: FATAL:  sorry, too many clients already
#
# (Background on this error at: https://sqlalche.me/e/20/e3q8)
# Error executing query: (psycopg2.OperationalError) connection to server at "128.1.227.35", port 5432 failed: FATAL:  sorry, too many clients already
# connection to server at "128.1.227.35", port 5432 failed: FATAL:  sorry, too many clients already
#
# (Background on this error at: https://sqlalche.me/e/20/e3q8)
# Error executing query: (psycopg2.OperationalError) connection to server at "128.1.227.35", port 5432 failed: FATAL:  sorry, too many clients already
# connection to server at "128.1.227.35", port 5432 failed: FATAL:  sorry, too many clients already
#
# (Background on this error at: https://sqlalche.me/e/20/e3q8)
# Error executing query: (psycopg2.OperationalError) connection to server at "128.1.227.35", port 5432 failed: FATAL:  sorry, too many clients already
# connection to server at "128.1.227.35", port 5432 failed: FATAL:  sorry, too many clients already
#
# (Background on this error at: https://sqlalche.me/e/20/e3q8)
# Error executing query: (psycopg2.OperationalError) connection to server at "128.1.227.35", port 5432 failed: FATAL:  sorry, too many clients already
# connection to server at "128.1.227.35", port 5432 failed: FATAL:  sorry, too many clients already
#
# (Background on this error at: https://sqlalche.me/e/20/e3q8)
# Error executing query: (psycopg2.OperationalError) connection to server at "128.1.227.35", port 5432 failed: FATAL:  sorry, too many clients already
# connection to server at "128.1.227.35", port 5432 failed: FATAL:  sorry, too many clients already
#
# (Background on this error at: https://sqlalche.me/e/20/e3q8)
# Error executing query: (psycopg2.OperationalError) connection to server at "128.1.227.35", port 5432 failed: FATAL:  sorry, too many clients already
# connection to server at "128.1.227.35", port 5432 failed: FATAL:  sorry, too many clients already
#
# (Background on this error at: https://sqlalche.me/e/20/e3q8)
# Error executing query: (psycopg2.OperationalError) connection to server at "128.1.227.35", port 5432 failed: FATAL:  sorry, too many clients already
# connection to server at "128.1.227.35", port 5432 failed: FATAL:  sorry, too many clients already
#
# (Background on this error at: https://sqlalche.me/e/20/e3q8)
# Error executing query: (psycopg2.OperationalError) connection to server at "128.1.227.35", port 5432 failed: FATAL:  sorry, too many clients already
# connection to server at "128.1.227.35", port 5432 failed: FATAL:  sorry, too many clients already
#
# (Background on this error at: https://sqlalche.me/e/20/e3q8)
# Error executing query: (psycopg2.OperationalError) connection to server at "128.1.227.35", port 5432 failed: FATAL:  sorry, too many clients already
# connection to server at "128.1.227.35", port 5432 failed: FATAL:  sorry, too many clients already
#
# (Background on this error at: https://sqlalche.me/e/20/e3q8)
# Error executing query: (psycopg2.OperationalError) connection to server at "128.1.227.35", port 5432 failed: FATAL:  sorry, too many clients already
# connection to server at "128.1.227.35", port 5432 failed: FATAL:  sorry, too many clients already
#
# (Background on this error at: https://sqlalche.me/e/20/e3q8)
# Error executing query: (psycopg2.OperationalError) connection to server at "128.1.227.35", port 5432 failed: FATAL:  sorry, too many clients already
# connection to server at "128.1.227.35", port 5432 failed: FATAL:  sorry, too many clients already
#
# (Background on this error at: https://sqlalche.me/e/20/e3q8)
# Error executing query: (psycopg2.OperationalError) connection to server at "128.1.227.35", port 5432 failed: FATAL:  sorry, too many clients already
# connection to server at "128.1.227.35", port 5432 failed: FATAL:  sorry, too many clients already
#
# (Background on this error at: https://sqlalche.me/e/20/e3q8)
# Error executing query: (psycopg2.OperationalError) connection to server at "128.1.227.35", port 5432 failed: FATAL:  sorry, too many clients already
# connection to server at "128.1.227.35", port 5432 failed: FATAL:  sorry, too many clients already
#
# (Background on this error at: https://sqlalche.me/e/20/e3q8)
# Error executing query: (psycopg2.OperationalError) connection to server at "128.1.227.35", port 5432 failed: FATAL:  sorry, too many clients already
# connection to server at "128.1.227.35", port 5432 failed: FATAL:  sorry, too many clients already
#
# (Background on this error at: https://sqlalche.me/e/20/e3q8)
# Error executing query: (psycopg2.OperationalError) connection to server at "128.1.227.35", port 5432 failed: FATAL:  sorry, too many clients already
# connection to server at "128.1.227.35", port 5432 failed: FATAL:  sorry, too many clients already
#
# (Background on this error at: https://sqlalche.me/e/20/e3q8)
# Error executing query: (psycopg2.OperationalError) connection to server at "128.1.227.35", port 5432 failed: FATAL:  sorry, too many clients already
# connection to server at "128.1.227.35", port 5432 failed: FATAL:  sorry, too many clients already
#
# (Background on this error at: https://sqlalche.me/e/20/e3q8)
# Error executing query: (psycopg2.OperationalError) connection to server at "128.1.227.35", port 5432 failed: FATAL:  sorry, too many clients already
# connection to server at "128.1.227.35", port 5432 failed: FATAL:  sorry, too many clients already
#
# (Background on this error at: https://sqlalche.me/e/20/e3q8)
# Error executing query: (psycopg2.OperationalError) connection to server at "128.1.227.35", port 5432 failed: FATAL:  sorry, too many clients already
# connection to server at "128.1.227.35", port 5432 failed: FATAL:  sorry, too many clients already
#
# (Background on this error at: https://sqlalche.me/e/20/e3q8)
# Error executing query: (psycopg2.OperationalError) connection to server at "128.1.227.35", port 5432 failed: FATAL:  sorry, too many clients already
# connection to server at "128.1.227.35", port 5432 failed: FATAL:  sorry, too many clients already
#
# (Background on this error at: https://sqlalche.me/e/20/e3q8)
# Error executing query: (psycopg2.OperationalError) connection to server at "128.1.227.35", port 5432 failed: FATAL:  sorry, too many clients already
# connection to server at "128.1.227.35", port 5432 failed: FATAL:  sorry, too many clients already
#
# (Background on this error at: https://sqlalche.me/e/20/e3q8)
# Error executing query: (psycopg2.OperationalError) connection to server at "128.1.227.35", port 5432 failed: FATAL:  sorry, too many clients already
# connection to server at "128.1.227.35", port 5432 failed: FATAL:  sorry, too many clients already
#
# (Background on this error at: https://sqlalche.me/e/20/e3q8)
# Error executing query: (psycopg2.OperationalError) connection to server at "128.1.227.35", port 5432 failed: FATAL:  sorry, too many clients already
# connection to server at "128.1.227.35", port 5432 failed: FATAL:  sorry, too many clients already
#
# (Background on this error at: https://sqlalche.me/e/20/e3q8)
# Error executing query: (psycopg2.OperationalError) connection to server at "128.1.227.35", port 5432 failed: FATAL:  sorry, too many clients already
# connection to server at "128.1.227.35", port 5432 failed: FATAL:  sorry, too many clients already
#
# (Background on this error at: https://sqlalche.me/e/20/e3q8)
# Error executing query: (psycopg2.OperationalError) connection to server at "128.1.227.35", port 5432 failed: FATAL:  sorry, too many clients already
# connection to server at "128.1.227.35", port 5432 failed: FATAL:  sorry, too many clients already
#
# (Background on this error at: https://sqlalche.me/e/20/e3q8)
# Error executing query: (psycopg2.OperationalError) connection to server at "128.1.227.35", port 5432 failed: FATAL:  sorry, too many clients already
# connection to server at "128.1.227.35", port 5432 failed: FATAL:  sorry, too many clients already
#
# (Background on this error at: https://sqlalche.me/e/20/e3q8)
# Error executing query: (psycopg2.OperationalError) connection to server at "128.1.227.35", port 5432 failed: FATAL:  sorry, too many clients already
# connection to server at "128.1.227.35", port 5432 failed: FATAL:  sorry, too many clients already
#
# (Background on this error at: https://sqlalche.me/e/20/e3q8)
# Error executing query: (psycopg2.OperationalError) connection to server at "128.1.227.35", port 5432 failed: FATAL:  sorry, too many clients already
# connection to server at "128.1.227.35", port 5432 failed: FATAL:  sorry, too many clients already
#
# (Background on this error at: https://sqlalche.me/e/20/e3q8)
# Error executing query: (psycopg2.OperationalError) connection to server at "128.1.227.35", port 5432 failed: FATAL:  sorry, too many clients already
# connection to server at "128.1.227.35", port 5432 failed: FATAL:  sorry, too many clients already
#
# (Background on this error at: https://sqlalche.me/e/20/e3q8)
# Error executing query: (psycopg2.OperationalError) connection to server at "128.1.227.35", port 5432 failed: FATAL:  sorry, too many clients already
# connection to server at "128.1.227.35", port 5432 failed: FATAL:  sorry, too many clients already
#
# (Background on this error at: https://sqlalche.me/e/20/e3q8)
# Error executing query: (psycopg2.OperationalError) connection to server at "128.1.227.35", port 5432 failed: FATAL:  sorry, too many clients already
# connection to server at "128.1.227.35", port 5432 failed: FATAL:  sorry, too many clients already
#
# (Background on this error at: https://sqlalche.me/e/20/e3q8)
# Error executing query: (psycopg2.OperationalError) connection to server at "128.1.227.35", port 5432 failed: FATAL:  sorry, too many clients already
# connection to server at "128.1.227.35", port 5432 failed: FATAL:  sorry, too many clients already
#
# (Background on this error at: https://sqlalche.me/e/20/e3q8)
# Error executing query: (psycopg2.OperationalError) connection to server at "128.1.227.35", port 5432 failed: FATAL:  sorry, too many clients already
# connection to server at "128.1.227.35", port 5432 failed: FATAL:  sorry, too many clients already
#
# (Background on this error at: https://sqlalche.me/e/20/e3q8)
# Error executing query: (psycopg2.OperationalError) connection to server at "128.1.227.35", port 5432 failed: FATAL:  sorry, too many clients already
# connection to server at "128.1.227.35", port 5432 failed: FATAL:  sorry, too many clients already
#
# (Background on this error at: https://sqlalche.me/e/20/e3q8)
# Error executing query: (psycopg2.OperationalError) connection to server at "128.1.227.35", port 5432 failed: FATAL:  sorry, too many clients already
# connection to server at "128.1.227.35", port 5432 failed: FATAL:  sorry, too many clients already
#
# (Background on this error at: https://sqlalche.me/e/20/e3q8)
# Error executing query: (psycopg2.OperationalError) connection to server at "128.1.227.35", port 5432 failed: FATAL:  sorry, too many clients already
# connection to server at "128.1.227.35", port 5432 failed: FATAL:  sorry, too many clients already
#
# (Background on this error at: https://sqlalche.me/e/20/e3q8)
# Error executing query: (psycopg2.OperationalError) connection to server at "128.1.227.35", port 5432 failed: FATAL:  sorry, too many clients already
# connection to server at "128.1.227.35", port 5432 failed: FATAL:  sorry, too many clients already
#
# (Background on this error at: https://sqlalche.me/e/20/e3q8)
# Error executing query: (psycopg2.OperationalError) connection to server at "128.1.227.35", port 5432 failed: FATAL:  sorry, too many clients already
# connection to server at "128.1.227.35", port 5432 failed: FATAL:  sorry, too many clients already
#
# (Background on this error at: https://sqlalche.me/e/20/e3q8)
# Error executing query: (psycopg2.OperationalError) connection to server at "128.1.227.35", port 5432 failed: FATAL:  sorry, too many clients already
# connection to server at "128.1.227.35", port 5432 failed: FATAL:  sorry, too many clients already
#
# (Background on this error at: https://sqlalche.me/e/20/e3q8)
# Error executing query: (psycopg2.OperationalError) connection to server at "128.1.227.35", port 5432 failed: FATAL:  sorry, too many clients already
# connection to server at "128.1.227.35", port 5432 failed: FATAL:  sorry, too many clients already
#
# (Background on this error at: https://sqlalche.me/e/20/e3q8)
# Error executing query: (psycopg2.OperationalError) connection to server at "128.1.227.35", port 5432 failed: FATAL:  sorry, too many clients already
# connection to server at "128.1.227.35", port 5432 failed: FATAL:  sorry, too many clients already
#
# (Background on this error at: https://sqlalche.me/e/20/e3q8)
# Error executing query: (psycopg2.OperationalError) connection to server at "128.1.227.35", port 5432 failed: FATAL:  sorry, too many clients already
# connection to server at "128.1.227.35", port 5432 failed: FATAL:  sorry, too many clients already
#
# (Background on this error at: https://sqlalche.me/e/20/e3q8)
# Error executing query: (psycopg2.OperationalError) connection to server at "128.1.227.35", port 5432 failed: FATAL:  sorry, too many clients already
# connection to server at "128.1.227.35", port 5432 failed: FATAL:  sorry, too many clients already
#
# (Background on this error at: https://sqlalche.me/e/20/e3q8)
# Error executing query: (psycopg2.OperationalError) connection to server at "128.1.227.35", port 5432 failed: FATAL:  sorry, too many clients already
# connection to server at "128.1.227.35", port 5432 failed: FATAL:  sorry, too many clients already
#
# (Background on this error at: https://sqlalche.me/e/20/e3q8)
# Error executing query: (psycopg2.OperationalError) connection to server at "128.1.227.35", port 5432 failed: FATAL:  sorry, too many clients already
# connection to server at "128.1.227.35", port 5432 failed: FATAL:  sorry, too many clients already
#
# (Background on this error at: https://sqlalche.me/e/20/e3q8)
# Error executing query: (psycopg2.OperationalError) connection to server at "128.1.227.35", port 5432 failed: FATAL:  sorry, too many clients already
# connection to server at "128.1.227.35", port 5432 failed: FATAL:  sorry, too many clients already
#
# (Background on this error at: https://sqlalche.me/e/20/e3q8)
# Error executing query: (psycopg2.OperationalError) connection to server at "128.1.227.35", port 5432 failed: FATAL:  sorry, too many clients already
# connection to server at "128.1.227.35", port 5432 failed: FATAL:  sorry, too many clients already
#
# (Background on this error at: https://sqlalche.me/e/20/e3q8)
# Error executing query: (psycopg2.OperationalError) connection to server at "128.1.227.35", port 5432 failed: FATAL:  sorry, too many clients already
# connection to server at "128.1.227.35", port 5432 failed: FATAL:  sorry, too many clients already
#
# (Background on this error at: https://sqlalche.me/e/20/e3q8)
# Error executing query: (psycopg2.OperationalError) connection to server at "128.1.227.35", port 5432 failed: FATAL:  sorry, too many clients already
# connection to server at "128.1.227.35", port 5432 failed: FATAL:  sorry, too many clients already
#
# (Background on this error at: https://sqlalche.me/e/20/e3q8)
# Error executing query: (psycopg2.OperationalError) connection to server at "128.1.227.35", port 5432 failed: FATAL:  sorry, too many clients already
# connection to server at "128.1.227.35", port 5432 failed: FATAL:  sorry, too many clients already
#
# (Background on this error at: https://sqlalche.me/e/20/e3q8)
# Error executing query: (psycopg2.OperationalError) connection to server at "128.1.227.35", port 5432 failed: FATAL:  sorry, too many clients already
# connection to server at "128.1.227.35", port 5432 failed: FATAL:  sorry, too many clients already
#
# (Background on this error at: https://sqlalche.me/e/20/e3q8)
# Error executing query: (psycopg2.OperationalError) connection to server at "128.1.227.35", port 5432 failed: FATAL:  sorry, too many clients already
# connection to server at "128.1.227.35", port 5432 failed: FATAL:  sorry, too many clients already
#
# (Background on this error at: https://sqlalche.me/e/20/e3q8)
# Error executing query: (psycopg2.OperationalError) connection to server at "128.1.227.35", port 5432 failed: FATAL:  sorry, too many clients already
# connection to server at "128.1.227.35", port 5432 failed: FATAL:  sorry, too many clients already
#
# (Background on this error at: https://sqlalche.me/e/20/e3q8)
# Error executing query: (psycopg2.OperationalError) connection to server at "128.1.227.35", port 5432 failed: FATAL:  sorry, too many clients already
# connection to server at "128.1.227.35", port 5432 failed: FATAL:  sorry, too many clients already
#
# (Background on this error at: https://sqlalche.me/e/20/e3q8)
# Error executing query: (psycopg2.OperationalError) connection to server at "128.1.227.35", port 5432 failed: FATAL:  sorry, too many clients already
# connection to server at "128.1.227.35", port 5432 failed: FATAL:  sorry, too many clients already
#
# (Background on this error at: https://sqlalche.me/e/20/e3q8)
# Error executing query: (psycopg2.OperationalError) connection to server at "128.1.227.35", port 5432 failed: FATAL:  sorry, too many clients already
# connection to server at "128.1.227.35", port 5432 failed: FATAL:  sorry, too many clients already
#
# (Background on this error at: https://sqlalche.me/e/20/e3q8)
# Error executing query: (psycopg2.OperationalError) connection to server at "128.1.227.35", port 5432 failed: FATAL:  sorry, too many clients already
# connection to server at "128.1.227.35", port 5432 failed: FATAL:  sorry, too many clients already
#
# (Background on this error at: https://sqlalche.me/e/20/e3q8)
# Error executing query: (psycopg2.OperationalError) connection to server at "128.1.227.35", port 5432 failed: FATAL:  sorry, too many clients already
# connection to server at "128.1.227.35", port 5432 failed: FATAL:  sorry, too many clients already
#
# (Background on this error at: https://sqlalche.me/e/20/e3q8)
# Error executing query: (psycopg2.OperationalError) connection to server at "128.1.227.35", port 5432 failed: FATAL:  sorry, too many clients already
# connection to server at "128.1.227.35", port 5432 failed: FATAL:  sorry, too many clients already
#
# (Background on this error at: https://sqlalche.me/e/20/e3q8)
# Error executing query: (psycopg2.OperationalError) connection to server at "128.1.227.35", port 5432 failed: FATAL:  sorry, too many clients already
# connection to server at "128.1.227.35", port 5432 failed: FATAL:  sorry, too many clients already
#
# (Background on this error at: https://sqlalche.me/e/20/e3q8)
# Error executing query: (psycopg2.OperationalError) connection to server at "128.1.227.35", port 5432 failed: FATAL:  sorry, too many clients already
# connection to server at "128.1.227.35", port 5432 failed: FATAL:  sorry, too many clients already
#
# (Background on this error at: https://sqlalche.me/e/20/e3q8)
# Error executing query: (psycopg2.OperationalError) connection to server at "128.1.227.35", port 5432 failed: FATAL:  sorry, too many clients already
# connection to server at "128.1.227.35", port 5432 failed: FATAL:  sorry, too many clients already
#
# (Background on this error at: https://sqlalche.me/e/20/e3q8)
# Error executing query: (psycopg2.OperationalError) connection to server at "128.1.227.35", port 5432 failed: FATAL:  sorry, too many clients already
# connection to server at "128.1.227.35", port 5432 failed: FATAL:  sorry, too many clients already
#
# (Background on this error at: https://sqlalche.me/e/20/e3q8)
# Error executing query: (psycopg2.OperationalError) connection to server at "128.1.227.35", port 5432 failed: FATAL:  sorry, too many clients already
# connection to server at "128.1.227.35", port 5432 failed: FATAL:  sorry, too many clients already
#
# (Background on this error at: https://sqlalche.me/e/20/e3q8)
# Error executing query: (psycopg2.OperationalError) connection to server at "128.1.227.35", port 5432 failed: FATAL:  sorry, too many clients already
# connection to server at "128.1.227.35", port 5432 failed: FATAL:  sorry, too many clients already
#
# (Background on this error at: https://sqlalche.me/e/20/e3q8)
# Error executing query: (psycopg2.OperationalError) connection to server at "128.1.227.35", port 5432 failed: FATAL:  sorry, too many clients already
# connection to server at "128.1.227.35", port 5432 failed: FATAL:  sorry, too many clients already
#
# (Background on this error at: https://sqlalche.me/e/20/e3q8)
# Error executing query: (psycopg2.OperationalError) connection to server at "128.1.227.35", port 5432 failed: FATAL:  sorry, too many clients already
# connection to server at "128.1.227.35", port 5432 failed: FATAL:  sorry, too many clients already
#
# (Background on this error at: https://sqlalche.me/e/20/e3q8)
# Error executing query: (psycopg2.OperationalError) connection to server at "128.1.227.35", port 5432 failed: FATAL:  sorry, too many clients already
# connection to server at "128.1.227.35", port 5432 failed: FATAL:  sorry, too many clients already
#
# (Background on this error at: https://sqlalche.me/e/20/e3q8)
# Error executing query: (psycopg2.OperationalError) connection to server at "128.1.227.35", port 5432 failed: FATAL:  sorry, too many clients already
# connection to server at "128.1.227.35", port 5432 failed: FATAL:  sorry, too many clients already
#
# (Background on this error at: https://sqlalche.me/e/20/e3q8)
# Error executing query: (psycopg2.OperationalError) connection to server at "128.1.227.35", port 5432 failed: FATAL:  sorry, too many clients already
# connection to server at "128.1.227.35", port 5432 failed: FATAL:  sorry, too many clients already
#
# (Background on this error at: https://sqlalche.me/e/20/e3q8)
# Error executing query: (psycopg2.OperationalError) connection to server at "128.1.227.35", port 5432 failed: FATAL:  sorry, too many clients already
# connection to server at "128.1.227.35", port 5432 failed: FATAL:  sorry, too many clients already
#
# (Background on this error at: https://sqlalche.me/e/20/e3q8)
# Error executing query: (psycopg2.OperationalError) connection to server at "128.1.227.35", port 5432 failed: FATAL:  sorry, too many clients already
# connection to server at "128.1.227.35", port 5432 failed: FATAL:  sorry, too many clients already
#
# (Background on this error at: https://sqlalche.me/e/20/e3q8)
# Error executing query: (psycopg2.OperationalError) connection to server at "128.1.227.35", port 5432 failed: FATAL:  sorry, too many clients already
# connection to server at "128.1.227.35", port 5432 failed: FATAL:  sorry, too many clients already
#
# (Background on this error at: https://sqlalche.me/e/20/e3q8)
# Error executing query: (psycopg2.OperationalError) connection to server at "128.1.227.35", port 5432 failed: FATAL:  sorry, too many clients already
# connection to server at "128.1.227.35", port 5432 failed: FATAL:  sorry, too many clients already
#
# (Background on this error at: https://sqlalche.me/e/20/e3q8)
# Error executing query: (psycopg2.OperationalError) connection to server at "128.1.227.35", port 5432 failed: FATAL:  sorry, too many clients already
# connection to server at "128.1.227.35", port 5432 failed: FATAL:  sorry, too many clients already
#
# (Background on this error at: https://sqlalche.me/e/20/e3q8)
# Error executing query: (psycopg2.OperationalError) connection to server at "128.1.227.35", port 5432 failed: FATAL:  sorry, too many clients already
# connection to server at "128.1.227.35", port 5432 failed: FATAL:  sorry, too many clients already
#
# (Background on this error at: https://sqlalche.me/e/20/e3q8)
# Error executing query: (psycopg2.OperationalError) connection to server at "128.1.227.35", port 5432 failed: FATAL:  sorry, too many clients already
# connection to server at "128.1.227.35", port 5432 failed: FATAL:  sorry, too many clients already
#
# (Background on this error at: https://sqlalche.me/e/20/e3q8)
# Error executing query: (psycopg2.OperationalError) connection to server at "128.1.227.35", port 5432 failed: FATAL:  sorry, too many clients already
# connection to server at "128.1.227.35", port 5432 failed: FATAL:  sorry, too many clients already
#
# (Background on this error at: https://sqlalche.me/e/20/e3q8)
# Error executing query: (psycopg2.OperationalError) connection to server at "128.1.227.35", port 5432 failed: FATAL:  sorry, too many clients already
# connection to server at "128.1.227.35", port 5432 failed: FATAL:  sorry, too many clients already
#
# (Background on this error at: https://sqlalche.me/e/20/e3q8)
# Error executing query: (psycopg2.OperationalError) connection to server at "128.1.227.35", port 5432 failed: FATAL:  sorry, too many clients already
# connection to server at "128.1.227.35", port 5432 failed: FATAL:  sorry, too many clients already
#
# (Background on this error at: https://sqlalche.me/e/20/e3q8)
# Error executing query: (psycopg2.OperationalError) connection to server at "128.1.227.35", port 5432 failed: FATAL:  sorry, too many clients already
# connection to server at "128.1.227.35", port 5432 failed: FATAL:  sorry, too many clients already
#
# (Background on this error at: https://sqlalche.me/e/20/e3q8)
# Error executing query: (psycopg2.OperationalError) connection to server at "128.1.227.35", port 5432 failed: FATAL:  sorry, too many clients already
# connection to server at "128.1.227.35", port 5432 failed: FATAL:  sorry, too many clients already
#
# (Background on this error at: https://sqlalche.me/e/20/e3q8)
# Error executing query: (psycopg2.OperationalError) connection to server at "128.1.227.35", port 5432 failed: FATAL:  sorry, too many clients already
# connection to server at "128.1.227.35", port 5432 failed: FATAL:  sorry, too many clients already
#
# (Background on this error at: https://sqlalche.me/e/20/e3q8)
# Error executing query: (psycopg2.OperationalError) connection to server at "128.1.227.35", port 5432 failed: FATAL:  sorry, too many clients already
# connection to server at "128.1.227.35", port 5432 failed: FATAL:  sorry, too many clients already
#
# (Background on this error at: https://sqlalche.me/e/20/e3q8)
# Error executing query: (psycopg2.OperationalError) connection to server at "128.1.227.35", port 5432 failed: FATAL:  sorry, too many clients already
# connection to server at "128.1.227.35", port 5432 failed: FATAL:  sorry, too many clients already
#
# (Background on this error at: https://sqlalche.me/e/20/e3q8)
# Error executing query: (psycopg2.OperationalError) connection to server at "128.1.227.35", port 5432 failed: FATAL:  sorry, too many clients already
# connection to server at "128.1.227.35", port 5432 failed: FATAL:  sorry, too many clients already
#
# (Background on this error at: https://sqlalche.me/e/20/e3q8)
# Error executing query: (psycopg2.OperationalError) connection to server at "128.1.227.35", port 5432 failed: FATAL:  sorry, too many clients already
# connection to server at "128.1.227.35", port 5432 failed: FATAL:  sorry, too many clients already
#
# (Background on this error at: https://sqlalche.me/e/20/e3q8)
# Error executing query: (psycopg2.OperationalError) connection to server at "128.1.227.35", port 5432 failed: FATAL:  sorry, too many clients already
# connection to server at "128.1.227.35", port 5432 failed: FATAL:  sorry, too many clients already
#
# (Background on this error at: https://sqlalche.me/e/20/e3q8)
# Error executing query: (psycopg2.OperationalError) connection to server at "128.1.227.35", port 5432 failed: FATAL:  sorry, too many clients already
# connection to server at "128.1.227.35", port 5432 failed: FATAL:  sorry, too many clients already
#
# (Background on this error at: https://sqlalche.me/e/20/e3q8)
# Error executing query: (psycopg2.OperationalError) connection to server at "128.1.227.35", port 5432 failed: FATAL:  sorry, too many clients already
# connection to server at "128.1.227.35", port 5432 failed: FATAL:  sorry, too many clients already
#
# (Background on this error at: https://sqlalche.me/e/20/e3q8)
# Error executing query: (psycopg2.OperationalError) connection to server at "128.1.227.35", port 5432 failed: FATAL:  sorry, too many clients already
# connection to server at "128.1.227.35", port 5432 failed: FATAL:  sorry, too many clients already
#
# (Background on this error at: https://sqlalche.me/e/20/e3q8)
# Error executing query: (psycopg2.OperationalError) connection to server at "128.1.227.35", port 5432 failed: FATAL:  sorry, too many clients already
# connection to server at "128.1.227.35", port 5432 failed: FATAL:  sorry, too many clients already
#
# (Background on this error at: https://sqlalche.me/e/20/e3q8)
# Error executing query: (psycopg2.OperationalError) connection to server at "128.1.227.35", port 5432 failed: FATAL:  sorry, too many clients already
# connection to server at "128.1.227.35", port 5432 failed: FATAL:  sorry, too many clients already
#
# (Background on this error at: https://sqlalche.me/e/20/e3q8)
# Error executing query: (psycopg2.OperationalError) connection to server at "128.1.227.35", port 5432 failed: FATAL:  sorry, too many clients already
# connection to server at "128.1.227.35", port 5432 failed: FATAL:  sorry, too many clients already
#
# (Background on this error at: https://sqlalche.me/e/20/e3q8)
# Error executing query: (psycopg2.OperationalError) connection to server at "128.1.227.35", port 5432 failed: FATAL:  sorry, too many clients already
# connection to server at "128.1.227.35", port 5432 failed: FATAL:  sorry, too many clients already
#
# (Background on this error at: https://sqlalche.me/e/20/e3q8)
# Error executing query: (psycopg2.OperationalError) connection to server at "128.1.227.35", port 5432 failed: FATAL:  sorry, too many clients already
# connection to server at "128.1.227.35", port 5432 failed: FATAL:  sorry, too many clients already
#
# (Background on this error at: https://sqlalche.me/e/20/e3q8)
# Error executing query: (psycopg2.OperationalError) connection to server at "128.1.227.35", port 5432 failed: FATAL:  sorry, too many clients already
# connection to server at "128.1.227.35", port 5432 failed: FATAL:  sorry, too many clients already
#
# (Background on this error at: https://sqlalche.me/e/20/e3q8)
# Error executing query: (psycopg2.OperationalError) connection to server at "128.1.227.35", port 5432 failed: FATAL:  sorry, too many clients already
# connection to server at "128.1.227.35", port 5432 failed: FATAL:  sorry, too many clients already
#
# (Background on this error at: https://sqlalche.me/e/20/e3q8)
# Error executing query: (psycopg2.OperationalError) connection to server at "128.1.227.35", port 5432 failed: FATAL:  sorry, too many clients already
# connection to server at "128.1.227.35", port 5432 failed: FATAL:  sorry, too many clients already
#
# (Background on this error at: https://sqlalche.me/e/20/e3q8)
# Error executing query: (psycopg2.OperationalError) connection to server at "128.1.227.35", port 5432 failed: FATAL:  sorry, too many clients already
# connection to server at "128.1.227.35", port 5432 failed: FATAL:  sorry, too many clients already
#
# (Background on this error at: https://sqlalche.me/e/20/e3q8)
# Error executing query: (psycopg2.OperationalError) connection to server at "128.1.227.35", port 5432 failed: FATAL:  sorry, too many clients already
# connection to server at "128.1.227.35", port 5432 failed: FATAL:  sorry, too many clients already
#
# (Background on this error at: https://sqlalche.me/e/20/e3q8)
# Error executing query: (psycopg2.OperationalError) connection to server at "128.1.227.35", port 5432 failed: FATAL:  sorry, too many clients already
# connection to server at "128.1.227.35", port 5432 failed: FATAL:  sorry, too many clients already
#
# (Background on this error at: https://sqlalche.me/e/20/e3q8)
# Error executing query: (psycopg2.OperationalError) connection to server at "128.1.227.35", port 5432 failed: FATAL:  sorry, too many clients already
# connection to server at "128.1.227.35", port 5432 failed: FATAL:  sorry, too many clients already
#
# (Background on this error at: https://sqlalche.me/e/20/e3q8)
# Error executing query: (psycopg2.OperationalError) connection to server at "128.1.227.35", port 5432 failed: FATAL:  sorry, too many clients already
# connection to server at "128.1.227.35", port 5432 failed: FATAL:  sorry, too many clients already
#
# (Background on this error at: https://sqlalche.me/e/20/e3q8)
# Error executing query: (psycopg2.OperationalError) connection to server at "128.1.227.35", port 5432 failed: FATAL:  sorry, too many clients already
# connection to server at "128.1.227.35", port 5432 failed: FATAL:  sorry, too many clients already
#
# (Background on this error at: https://sqlalche.me/e/20/e3q8)
# Error executing query: (psycopg2.OperationalError) connection to server at "128.1.227.35", port 5432 failed: FATAL:  sorry, too many clients already
# connection to server at "128.1.227.35", port 5432 failed: FATAL:  sorry, too many clients already
#
# (Background on this error at: https://sqlalche.me/e/20/e3q8)
# Error executing query: (psycopg2.OperationalError) connection to server at "128.1.227.35", port 5432 failed: FATAL:  sorry, too many clients already
# connection to server at "128.1.227.35", port 5432 failed: FATAL:  sorry, too many clients already
#
# (Background on this error at: https://sqlalche.me/e/20/e3q8)
# Error executing query: (psycopg2.OperationalError) connection to server at "128.1.227.35", port 5432 failed: FATAL:  sorry, too many clients already
# connection to server at "128.1.227.35", port 5432 failed: FATAL:  sorry, too many clients already
#
# (Background on this error at: https://sqlalche.me/e/20/e3q8)
# Error executing query: (psycopg2.OperationalError) connection to server at "128.1.227.35", port 5432 failed: FATAL:  sorry, too many clients already
# connection to server at "128.1.227.35", port 5432 failed: FATAL:  sorry, too many clients already
#
# (Background on this error at: https://sqlalche.me/e/20/e3q8)
# Error executing query: (psycopg2.OperationalError) connection to server at "128.1.227.35", port 5432 failed: FATAL:  sorry, too many clients already
# connection to server at "128.1.227.35", port 5432 failed: FATAL:  sorry, too many clients already
#
# (Background on this error at: https://sqlalche.me/e/20/e3q8)
# Error executing query: (psycopg2.OperationalError) connection to server at "128.1.227.35", port 5432 failed: FATAL:  sorry, too many clients already
# connection to server at "128.1.227.35", port 5432 failed: FATAL:  sorry, too many clients already
#
# (Background on this error at: https://sqlalche.me/e/20/e3q8)
# Error executing query: (psycopg2.OperationalError) connection to server at "128.1.227.35", port 5432 failed: FATAL:  sorry, too many clients already
# connection to server at "128.1.227.35", port 5432 failed: FATAL:  sorry, too many clients already
#
# (Background on this error at: https://sqlalche.me/e/20/e3q8)
# Error executing query: (psycopg2.OperationalError) connection to server at "128.1.227.35", port 5432 failed: FATAL:  sorry, too many clients already
# connection to server at "128.1.227.35", port 5432 failed: FATAL:  sorry, too many clients already
#
# (Background on this error at: https://sqlalche.me/e/20/e3q8)
# Error executing query: (psycopg2.OperationalError) connection to server at "128.1.227.35", port 5432 failed: FATAL:  sorry, too many clients already
# connection to server at "128.1.227.35", port 5432 failed: FATAL:  sorry, too many clients already
#
# (Background on this error at: https://sqlalche.me/e/20/e3q8)
# Error executing query: (psycopg2.OperationalError) connection to server at "128.1.227.35", port 5432 failed: FATAL:  sorry, too many clients already
# connection to server at "128.1.227.35", port 5432 failed: FATAL:  sorry, too many clients already
#
# (Background on this error at: https://sqlalche.me/e/20/e3q8)
# Error executing query: (psycopg2.OperationalError) connection to server at "128.1.227.35", port 5432 failed: FATAL:  sorry, too many clients already
# connection to server at "128.1.227.35", port 5432 failed: FATAL:  sorry, too many clients already
#
# (Background on this error at: https://sqlalche.me/e/20/e3q8)
# Error executing query: (psycopg2.OperationalError) connection to server at "128.1.227.35", port 5432 failed: FATAL:  sorry, too many clients already
# connection to server at "128.1.227.35", port 5432 failed: FATAL:  sorry, too many clients already
#
# (Background on this error at: https://sqlalche.me/e/20/e3q8)
# Error executing query: (psycopg2.OperationalError) connection to server at "128.1.227.35", port 5432 failed: FATAL:  sorry, too many clients already
# connection to server at "128.1.227.35", port 5432 failed: FATAL:  sorry, too many clients already
#
# (Background on this error at: https://sqlalche.me/e/20/e3q8)
# Error executing query: (psycopg2.OperationalError) connection to server at "128.1.227.35", port 5432 failed: FATAL:  sorry, too many clients already
# connection to server at "128.1.227.35", port 5432 failed: FATAL:  sorry, too many clients already
#
# (Background on this error at: https://sqlalche.me/e/20/e3q8)
# Error executing query: (psycopg2.OperationalError) connection to server at "128.1.227.35", port 5432 failed: FATAL:  sorry, too many clients already
# connection to server at "128.1.227.35", port 5432 failed: FATAL:  sorry, too many clients already
#
# (Background on this error at: https://sqlalche.me/e/20/e3q8)
# Error executing query: (psycopg2.OperationalError) connection to server at "128.1.227.35", port 5432 failed: FATAL:  sorry, too many clients already
# connection to server at "128.1.227.35", port 5432 failed: FATAL:  sorry, too many clients already
#
# (Background on this error at: https://sqlalche.me/e/20/e3q8)
# Error executing query: (psycopg2.OperationalError) connection to server at "128.1.227.35", port 5432 failed: FATAL:  sorry, too many clients already
# connection to server at "128.1.227.35", port 5432 failed: FATAL:  sorry, too many clients already
#
# (Background on this error at: https://sqlalche.me/e/20/e3q8)
# Error executing query: (psycopg2.OperationalError) connection to server at "128.1.227.35", port 5432 failed: FATAL:  sorry, too many clients already
# connection to server at "128.1.227.35", port 5432 failed: FATAL:  sorry, too many clients already
#
# (Background on this error at: https://sqlalche.me/e/20/e3q8)
# Error executing query: (psycopg2.OperationalError) connection to server at "128.1.227.35", port 5432 failed: FATAL:  sorry, too many clients already
# connection to server at "128.1.227.35", port 5432 failed: FATAL:  sorry, too many clients already
#
# (Background on this error at: https://sqlalche.me/e/20/e3q8)
# Error executing query: (psycopg2.OperationalError) connection to server at "128.1.227.35", port 5432 failed: FATAL:  sorry, too many clients already
# connection to server at "128.1.227.35", port 5432 failed: FATAL:  sorry, too many clients already
#
# (Background on this error at: https://sqlalche.me/e/20/e3q8)
# Error executing query: (psycopg2.OperationalError) connection to server at "128.1.227.35", port 5432 failed: FATAL:  sorry, too many clients already
# connection to server at "128.1.227.35", port 5432 failed: FATAL:  sorry, too many clients already
#
# (Background on this error at: https://sqlalche.me/e/20/e3q8)
# Error executing query: (psycopg2.OperationalError) connection to server at "128.1.227.35", port 5432 failed: FATAL:  sorry, too many clients already
# connection to server at "128.1.227.35", port 5432 failed: FATAL:  sorry, too many clients already
#
# (Background on this error at: https://sqlalche.me/e/20/e3q8)
# Error executing query: (psycopg2.OperationalError) connection to server at "128.1.227.35", port 5432 failed: FATAL:  sorry, too many clients already
# connection to server at "128.1.227.35", port 5432 failed: FATAL:  sorry, too many clients already
#
# (Background on this error at: https://sqlalche.me/e/20/e3q8)
# Error executing query: (psycopg2.OperationalError) connection to server at "128.1.227.35", port 5432 failed: FATAL:  sorry, too many clients already
# connection to server at "128.1.227.35", port 5432 failed: FATAL:  sorry, too many clients already
#
# (Background on this error at: https://sqlalche.me/e/20/e3q8)
# Error executing query: (psycopg2.OperationalError) connection to server at "128.1.227.35", port 5432 failed: FATAL:  sorry, too many clients already
# connection to server at "128.1.227.35", port 5432 failed: FATAL:  sorry, too many clients already
#
# (Background on this error at: https://sqlalche.me/e/20/e3q8)
# Error executing query: (psycopg2.OperationalError) connection to server at "128.1.227.35", port 5432 failed: FATAL:  sorry, too many clients already
# connection to server at "128.1.227.35", port 5432 failed: FATAL:  sorry, too many clients already
#
# (Background on this error at: https://sqlalche.me/e/20/e3q8)
# Error executing query: (psycopg2.OperationalError) connection to server at "128.1.227.35", port 5432 failed: FATAL:  sorry, too many clients already
# connection to server at "128.1.227.35", port 5432 failed: FATAL:  sorry, too many clients already
#
# (Background on this error at: https://sqlalche.me/e/20/e3q8)
# Error executing query: (psycopg2.OperationalError) connection to server at "128.1.227.35", port 5432 failed: FATAL:  sorry, too many clients already
# connection to server at "128.1.227.35", port 5432 failed: FATAL:  sorry, too many clients already
#
# (Background on this error at: https://sqlalche.me/e/20/e3q8)
# Error executing query: (psycopg2.OperationalError) connection to server at "128.1.227.35", port 5432 failed: FATAL:  sorry, too many clients already
# connection to server at "128.1.227.35", port 5432 failed: FATAL:  sorry, too many clients already
#
# (Background on this error at: https://sqlalche.me/e/20/e3q8)
# Error executing query: (psycopg2.OperationalError) connection to server at "128.1.227.35", port 5432 failed: FATAL:  sorry, too many clients already
# connection to server at "128.1.227.35", port 5432 failed: FATAL:  sorry, too many clients already
#
# (Background on this error at: https://sqlalche.me/e/20/e3q8)
# Error executing query: (psycopg2.OperationalError) connection to server at "128.1.227.35", port 5432 failed: FATAL:  sorry, too many clients already
# connection to server at "128.1.227.35", port 5432 failed: FATAL:  sorry, too many clients already
#
# (Background on this error at: https://sqlalche.me/e/20/e3q8)
# Error executing query: (psycopg2.OperationalError) connection to server at "128.1.227.35", port 5432 failed: FATAL:  sorry, too many clients already
# connection to server at "128.1.227.35", port 5432 failed: FATAL:  sorry, too many clients already
#
# (Background on this error at: https://sqlalche.me/e/20/e3q8)
# Error executing query: (psycopg2.OperationalError) connection to server at "128.1.227.35", port 5432 failed: FATAL:  sorry, too many clients already
# connection to server at "128.1.227.35", port 5432 failed: FATAL:  sorry, too many clients already
#
# (Background on this error at: https://sqlalche.me/e/20/e3q8)
# Error executing query: (psycopg2.OperationalError) connection to server at "128.1.227.35", port 5432 failed: FATAL:  sorry, too many clients already
# connection to server at "128.1.227.35", port 5432 failed: FATAL:  sorry, too many clients already
#
# (Background on this error at: https://sqlalche.me/e/20/e3q8)
# Error executing query: (psycopg2.OperationalError) connection to server at "128.1.227.35", port 5432 failed: FATAL:  sorry, too many clients already
# connection to server at "128.1.227.35", port 5432 failed: FATAL:  sorry, too many clients already
#
# (Background on this error at: https://sqlalche.me/e/20/e3q8)
# Error executing query: (psycopg2.OperationalError) connection to server at "128.1.227.35", port 5432 failed: FATAL:  sorry, too many clients already
# connection to server at "128.1.227.35", port 5432 failed: FATAL:  sorry, too many clients already
#
# (Background on this error at: https://sqlalche.me/e/20/e3q8)
# Error executing query: (psycopg2.OperationalError) connection to server at "128.1.227.35", port 5432 failed: FATAL:  sorry, too many clients already
# connection to server at "128.1.227.35", port 5432 failed: FATAL:  sorry, too many clients already
#
# (Background on this error at: https://sqlalche.me/e/20/e3q8)
# Error executing query: (psycopg2.OperationalError) connection to server at "128.1.227.35", port 5432 failed: FATAL:  sorry, too many clients already
# connection to server at "128.1.227.35", port 5432 failed: FATAL:  sorry, too many clients already
#
# (Background on this error at: https://sqlalche.me/e/20/e3q8)
# Error executing query: (psycopg2.OperationalError) connection to server at "128.1.227.35", port 5432 failed: FATAL:  sorry, too many clients already
# connection to server at "128.1.227.35", port 5432 failed: FATAL:  sorry, too many clients already
#
# (Background on this error at: https://sqlalche.me/e/20/e3q8)
# Error executing query: (psycopg2.OperationalError) connection to server at "128.1.227.35", port 5432 failed: FATAL:  sorry, too many clients already
# connection to server at "128.1.227.35", port 5432 failed: FATAL:  sorry, too many clients already
#
# (Background on this error at: https://sqlalche.me/e/20/e3q8)
# Error executing query: (psycopg2.OperationalError) connection to server at "128.1.227.35", port 5432 failed: FATAL:  sorry, too many clients already
# connection to server at "128.1.227.35", port 5432 failed: FATAL:  sorry, too many clients already
#
# (Background on this error at: https://sqlalche.me/e/20/e3q8)
# Error executing query: (psycopg2.OperationalError) connection to server at "128.1.227.35", port 5432 failed: FATAL:  sorry, too many clients already
# connection to server at "128.1.227.35", port 5432 failed: FATAL:  sorry, too many clients already
#
# (Background on this error at: https://sqlalche.me/e/20/e3q8)
# Error executing query: (psycopg2.OperationalError) connection to server at "128.1.227.35", port 5432 failed: FATAL:  sorry, too many clients already
# connection to server at "128.1.227.35", port 5432 failed: FATAL:  sorry, too many clients already
#
# (Background on this error at: https://sqlalche.me/e/20/e3q8)
# Error executing query: (psycopg2.OperationalError) connection to server at "128.1.227.35", port 5432 failed: FATAL:  sorry, too many clients already
# connection to server at "128.1.227.35", port 5432 failed: FATAL:  sorry, too many clients already
#
# (Background on this error at: https://sqlalche.me/e/20/e3q8)
# ...
# connection to server at "128.1.227.35", port 5432 failed: FATAL:  sorry, too many clients already
#
# (Background on this error at: https://sqlalche.me/e/20/e3q8)
# Error executing query: (psycopg2.OperationalError) connection to server at "128.1.227.35", port 5432 failed: FATAL:  sorry, too many clients already
# connection to server at "128.1.227.35", port 5432 failed: FATAL:  sorry, too many clients already
#
# (Background on this error at: https://sqlalche.me/e/20/e3q8)
# Error executing query: (psycopg2.OperationalError) connection to server at "128.1.227.35", port 5432 failed: FATAL:  sorry, too many clients already
# connection to server at "128.1.227.35", port 5432 failed: FATAL:  sorry, too many clients already
#
# (Background on this error at: https://sqlalche.me/e/20/e3q8)
# Error executing query: (psycopg2.OperationalError) connection to server at "128.1.227.35", port 5432 failed: FATAL:  sorry, too many clients already
# connection to server at "128.1.227.35", port 5432 failed: FATAL:  sorry, too many clients already
#
# (Background on this error at: https://sqlalche.me/e/20/e3q8)
# Error executing query: (psycopg2.OperationalError) connection to server at "128.1.227.35", port 5432 failed: FATAL:  sorry, too many clients already
# connection to server at "128.1.227.35", port 5432 failed: FATAL:  sorry, too many clients already
#
# (Background on this error at: https://sqlalche.me/e/20/e3q8)
# Error executing query: (psycopg2.OperationalError) connection to server at "128.1.227.35", port 5432 failed: FATAL:  sorry, too many clients already
# connection to server at "128.1.227.35", port 5432 failed: FATAL:  sorry, too many clients already
#
# (Background on this error at: https://sqlalche.me/e/20/e3q8)
# Error executing query: (psycopg2.OperationalError) connection to server at "128.1.227.35", port 5432 failed: FATAL:  sorry, too many clients already
# connection to server at "128.1.227.35", port 5432 failed: FATAL:  sorry, too many clients already
#
# (Background on this error at: https://sqlalche.me/e/20/e3q8)
# Error executing query: (psycopg2.OperationalError) connection to server at "128.1.227.35", port 5432 failed: FATAL:  sorry, too many clients already
# connection to server at "128.1.227.35", port 5432 failed: FATAL:  sorry, too many clients already
#
# (Background on this error at: https://sqlalche.me/e/20/e3q8)
# Error executing query: (psycopg2.OperationalError) connection to server at "128.1.227.35", port 5432 failed: FATAL:  sorry, too many clients already
# connection to server at "128.1.227.35", port 5432 failed: FATAL:  sorry, too many clients already
#
# (Background on this error at: https://sqlalche.me/e/20/e3q8)
# Error executing query: (psycopg2.OperationalError) connection to server at "128.1.227.35", port 5432 failed: FATAL:  sorry, too many clients already
# connection to server at "128.1.227.35", port 5432 failed: FATAL:  sorry, too many clients already
#
# (Background on this error at: https://sqlalche.me/e/20/e3q8)
# Error executing query: (psycopg2.OperationalError) connection to server at "128.1.227.35", port 5432 failed: FATAL:  sorry, too many clients already
# connection to server at "128.1.227.35", port 5432 failed: FATAL:  sorry, too many clients already
#
# (Background on this error at: https://sqlalche.me/e/20/e3q8)
# Error executing query: (psycopg2.OperationalError) connection to server at "128.1.227.35", port 5432 failed: FATAL:  sorry, too many clients already
# connection to server at "128.1.227.35", port 5432 failed: FATAL:  sorry, too many clients already
#
# (Background on this error at: https://sqlalche.me/e/20/e3q8)
# Error executing query: (psycopg2.OperationalError) connection to server at "128.1.227.35", port 5432 failed: FATAL:  sorry, too many clients already
# connection to server at "128.1.227.35", port 5432 failed: FATAL:  sorry, too many clients already
#
# (Background on this error at: https://sqlalche.me/e/20/e3q8)
# Error executing query: (psycopg2.OperationalError) connection to server at "128.1.227.35", port 5432 failed: FATAL:  sorry, too many clients already
# connection to server at "128.1.227.35", port 5432 failed: FATAL:  sorry, too many clients already
#
# (Background on this error at: https://sqlalche.me/e/20/e3q8)
# Error executing query: (psycopg2.OperationalError) connection to server at "128.1.227.35", port 5432 failed: FATAL:  sorry, too many clients already
# connection to server at "128.1.227.35", port 5432 failed: FATAL:  sorry, too many clients already
#
# (Background on this error at: https://sqlalche.me/e/20/e3q8)
# Error executing query: (psycopg2.OperationalError) connection to server at "128.1.227.35", port 5432 failed: FATAL:  sorry, too many clients already
# connection to server at "128.1.227.35", port 5432 failed: FATAL:  sorry, too many clients already
#
# (Background on this error at: https://sqlalche.me/e/20/e3q8)
# Error executing query: (psycopg2.OperationalError) connection to server at "128.1.227.35", port 5432 failed: FATAL:  sorry, too many clients already
# connection to server at "128.1.227.35", port 5432 failed: FATAL:  sorry, too many clients already
#
# (Background on this error at: https://sqlalche.me/e/20/e3q8)
# Error executing query: (psycopg2.OperationalError) connection to server at "128.1.227.35", port 5432 failed: FATAL:  sorry, too many clients already
# connection to server at "128.1.227.35", port 5432 failed: FATAL:  sorry, too many clients already
#
# (Background on this error at: https://sqlalche.me/e/20/e3q8)
# Error executing query: (psycopg2.OperationalError) connection to server at "128.1.227.35", port 5432 failed: FATAL:  sorry, too many clients already
# connection to server at "128.1.227.35", port 5432 failed: FATAL:  sorry, too many clients already
#
# (Background on this error at: https://sqlalche.me/e/20/e3q8)
# Error executing query: (psycopg2.OperationalError) connection to server at "128.1.227.35", port 5432 failed: FATAL:  sorry, too many clients already
# connection to server at "128.1.227.35", port 5432 failed: FATAL:  sorry, too many clients already
#
# (Background on this error at: https://sqlalche.me/e/20/e3q8)
# Error executing query: (psycopg2.OperationalError) connection to server at "128.1.227.35", port 5432 failed: FATAL:  sorry, too many clients already
# connection to server at "128.1.227.35", port 5432 failed: FATAL:  sorry, too many clients already
#
# (Background on this error at: https://sqlalche.me/e/20/e3q8)
# Error executing query: (psycopg2.OperationalError) connection to server at "128.1.227.35", port 5432 failed: FATAL:  sorry, too many clients already
# connection to server at "128.1.227.35", port 5432 failed: FATAL:  sorry, too many clients already
#
# (Background on this error at: https://sqlalche.me/e/20/e3q8)
# Error executing query: (psycopg2.OperationalError) connection to server at "128.1.227.35", port 5432 failed: FATAL:  sorry, too many clients already
# connection to server at "128.1.227.35", port 5432 failed: FATAL:  sorry, too many clients already
#
# (Background on this error at: https://sqlalche.me/e/20/e3q8)
# Error executing query: (psycopg2.OperationalError) connection to server at "128.1.227.35", port 5432 failed: FATAL:  sorry, too many clients already
# connection to server at "128.1.227.35", port 5432 failed: FATAL:  sorry, too many clients already
#
# (Background on this error at: https://sqlalche.me/e/20/e3q8)
# Error executing query: (psycopg2.OperationalError) connection to server at "128.1.227.35", port 5432 failed: FATAL:  sorry, too many clients already
# connection to server at "128.1.227.35", port 5432 failed: FATAL:  sorry, too many clients already
#
# (Background on this error at: https://sqlalche.me/e/20/e3q8)
# Error executing query: (psycopg2.OperationalError) connection to server at "128.1.227.35", port 5432 failed: FATAL:  sorry, too many clients already
# connection to server at "128.1.227.35", port 5432 failed: FATAL:  sorry, too many clients already
#
# (Background on this error at: https://sqlalche.me/e/20/e3q8)
# Error executing query: (psycopg2.OperationalError) connection to server at "128.1.227.35", port 5432 failed: FATAL:  sorry, too many clients already
# connection to server at "128.1.227.35", port 5432 failed: FATAL:  sorry, too many clients already
#
# (Background on this error at: https://sqlalche.me/e/20/e3q8)
# Error executing query: (psycopg2.OperationalError) connection to server at "128.1.227.35", port 5432 failed: FATAL:  sorry, too many clients already
# connection to server at "128.1.227.35", port 5432 failed: FATAL:  sorry, too many clients already
#
# (Background on this error at: https://sqlalche.me/e/20/e3q8)
# Error executing query: (psycopg2.OperationalError) connection to server at "128.1.227.35", port 5432 failed: FATAL:  sorry, too many clients already
# connection to server at "128.1.227.35", port 5432 failed: FATAL:  sorry, too many clients already
#
# (Background on this error at: https://sqlalche.me/e/20/e3q8)
# Error executing query: (psycopg2.OperationalError) connection to server at "128.1.227.35", port 5432 failed: FATAL:  sorry, too many clients already
# connection to server at "128.1.227.35", port 5432 failed: FATAL:  sorry, too many clients already
#
# (Background on this error at: https://sqlalche.me/e/20/e3q8)
# Error executing query: (psycopg2.OperationalError) connection to server at "128.1.227.35", port 5432 failed: FATAL:  sorry, too many clients already
# connection to server at "128.1.227.35", port 5432 failed: FATAL:  sorry, too many clients already
#
# (Background on this error at: https://sqlalche.me/e/20/e3q8)
# Error executing query: (psycopg2.OperationalError) connection to server at "128.1.227.35", port 5432 failed: FATAL:  sorry, too many clients already
# connection to server at "128.1.227.35", port 5432 failed: FATAL:  sorry, too many clients already
#
# (Background on this error at: https://sqlalche.me/e/20/e3q8)
# Error executing query: (psycopg2.OperationalError) connection to server at "128.1.227.35", port 5432 failed: FATAL:  sorry, too many clients already
# connection to server at "128.1.227.35", port 5432 failed: FATAL:  sorry, too many clients already
#
# (Background on this error at: https://sqlalche.me/e/20/e3q8)
# Error executing query: (psycopg2.OperationalError) connection to server at "128.1.227.35", port 5432 failed: FATAL:  sorry, too many clients already
# connection to server at "128.1.227.35", port 5432 failed: FATAL:  sorry, too many clients already
#
# (Background on this error at: https://sqlalche.me/e/20/e3q8)
# Error executing query: (psycopg2.OperationalError) connection to server at "128.1.227.35", port 5432 failed: FATAL:  sorry, too many clients already
# connection to server at "128.1.227.35", port 5432 failed: FATAL:  sorry, too many clients already
#
# (Background on this error at: https://sqlalche.me/e/20/e3q8)
# Error executing query: (psycopg2.OperationalError) connection to server at "128.1.227.35", port 5432 failed: FATAL:  sorry, too many clients already
# connection to server at "128.1.227.35", port 5432 failed: FATAL:  sorry, too many clients already
#
# (Background on this error at: https://sqlalche.me/e/20/e3q8)
# Error executing query: (psycopg2.OperationalError) connection to server at "128.1.227.35", port 5432 failed: FATAL:  sorry, too many clients already
# connection to server at "128.1.227.35", port 5432 failed: FATAL:  sorry, too many clients already
#
# (Background on this error at: https://sqlalche.me/e/20/e3q8)
# Error executing query: (psycopg2.OperationalError) connection to server at "128.1.227.35", port 5432 failed: FATAL:  sorry, too many clients already
# connection to server at "128.1.227.35", port 5432 failed: FATAL:  sorry, too many clients already
#
# (Background on this error at: https://sqlalche.me/e/20/e3q8)
# Error executing query: (psycopg2.OperationalError) connection to server at "128.1.227.35", port 5432 failed: FATAL:  sorry, too many clients already
# connection to server at "128.1.227.35", port 5432 failed: FATAL:  sorry, too many clients already
#
# (Background on this error at: https://sqlalche.me/e/20/e3q8)
# Error executing query: (psycopg2.OperationalError) connection to server at "128.1.227.35", port 5432 failed: FATAL:  sorry, too many clients already
# connection to server at "128.1.227.35", port 5432 failed: FATAL:  sorry, too many clients already
#
# (Background on this error at: https://sqlalche.me/e/20/e3q8)
# Error executing query: (psycopg2.OperationalError) connection to server at "128.1.227.35", port 5432 failed: FATAL:  sorry, too many clients already
# connection to server at "128.1.227.35", port 5432 failed: FATAL:  sorry, too many clients already
#
# (Background on this error at: https://sqlalche.me/e/20/e3q8)
# Error executing query: (psycopg2.OperationalError) connection to server at "128.1.227.35", port 5432 failed: FATAL:  sorry, too many clients already
# connection to server at "128.1.227.35", port 5432 failed: FATAL:  sorry, too many clients already
#
# (Background on this error at: https://sqlalche.me/e/20/e3q8)
# Error executing query: (psycopg2.OperationalError) connection to server at "128.1.227.35", port 5432 failed: FATAL:  sorry, too many clients already
# connection to server at "128.1.227.35", port 5432 failed: FATAL:  sorry, too many clients already
#
# (Background on this error at: https://sqlalche.me/e/20/e3q8)
# Error executing query: (psycopg2.OperationalError) connection to server at "128.1.227.35", port 5432 failed: FATAL:  sorry, too many clients already
# connection to server at "128.1.227.35", port 5432 failed: FATAL:  sorry, too many clients already
#
# (Background on this error at: https://sqlalche.me/e/20/e3q8)
# Error executing query: (psycopg2.OperationalError) connection to server at "128.1.227.35", port 5432 failed: FATAL:  sorry, too many clients already
# connection to server at "128.1.227.35", port 5432 failed: FATAL:  sorry, too many clients already
#
# (Background on this error at: https://sqlalche.me/e/20/e3q8)
# Error executing query: (psycopg2.OperationalError) connection to server at "128.1.227.35", port 5432 failed: FATAL:  sorry, too many clients already
# connection to server at "128.1.227.35", port 5432 failed: FATAL:  sorry, too many clients already
#
# (Background on this error at: https://sqlalche.me/e/20/e3q8)
# Error executing query: (psycopg2.OperationalError) connection to server at "128.1.227.35", port 5432 failed: FATAL:  sorry, too many clients already
# connection to server at "128.1.227.35", port 5432 failed: FATAL:  sorry, too many clients already
#
# (Background on this error at: https://sqlalche.me/e/20/e3q8)
# Error executing query: (psycopg2.OperationalError) connection to server at "128.1.227.35", port 5432 failed: FATAL:  sorry, too many clients already
# connection to server at "128.1.227.35", port 5432 failed: FATAL:  sorry, too many clients already
#
# (Background on this error at: https://sqlalche.me/e/20/e3q8)
# Error executing query: (psycopg2.OperationalError) connection to server at "128.1.227.35", port 5432 failed: FATAL:  sorry, too many clients already
# connection to server at "128.1.227.35", port 5432 failed: FATAL:  sorry, too many clients already
#
# (Background on this error at: https://sqlalche.me/e/20/e3q8)
# Error executing query: (psycopg2.OperationalError) connection to server at "128.1.227.35", port 5432 failed: FATAL:  sorry, too many clients already
# connection to server at "128.1.227.35", port 5432 failed: FATAL:  sorry, too many clients already
#
# (Background on this error at: https://sqlalche.me/e/20/e3q8)
# Error executing query: (psycopg2.OperationalError) connection to server at "128.1.227.35", port 5432 failed: FATAL:  sorry, too many clients already
# connection to server at "128.1.227.35", port 5432 failed: FATAL:  sorry, too many clients already
#
# (Background on this error at: https://sqlalche.me/e/20/e3q8)
# Error executing query: (psycopg2.OperationalError) connection to server at "128.1.227.35", port 5432 failed: FATAL:  sorry, too many clients already
# connection to server at "128.1.227.35", port 5432 failed: FATAL:  sorry, too many clients already
#
# (Background on this error at: https://sqlalche.me/e/20/e3q8)
# Total Processed Data: 8742

# %%
#
# code for image clustering
#

import pandas as pd
import numpy as np
import requests
from collections import defaultdict
from io import BytesIO
from PIL import Image
import matplotlib.pyplot as plt
from sklearn.cluster import KMeans
from sklearn.decomposition import PCA
from sklearn.metrics import silhouette_score
from sklearn.preprocessing import StandardScaler
from urllib.parse import urlsplit, urlunsplit
import data_connector
from tensorflow.keras.applications import VGG16
from tensorflow.keras.applications.vgg16 import preprocess_input
from tensorflow.keras.preprocessing.image import img_to_array
import cv2

# Load a pre-trained VGG16 model without the top layer (output layer)
model = VGG16(weights='imagenet', include_top=False, input_shape=(224, 224, 3))

# Step 1: Data Loading and Cleaning
def load_image(url, url_prefix, size=(512, 512)):
    # Remove the filename extension
    parts = list(urlsplit(url))
    path = parts[2]
    path = '/'.join(part.rsplit('.', 1)[0] for part in path.split('/'))
    parts[2] = path
    url = urlunsplit(parts)

    # Add the URL prefix
    full_url = url_prefix + url
    # print(full_url)

    response = requests.get(full_url)
    img = Image.open(BytesIO(response.content))
    img = img.resize(size)
    img = np.array(img)

    if len(img.shape) == 2:  # Grayscale image
        img = np.stack([img] * 3, axis=-1)  # Convert to RGB by stacking the grayscale values
    
    if (len(img.shape)) > 2:
        if img.shape[2] == 4:
            img = img[:, :, :3]  # Remove alpha channel if present
    img = img / 255.0  # Normalize
    return img

# Step 2: Feature Extraction
def extract_features(img):
    h, w, c = img.shape
    return img.reshape(1, h * w * c)

def extract_features_cnn(img):
    # Resize the image to the input size expected by VGG16
    img_resized = cv2.resize(img, (224, 224))
    
    # Convert to array and preprocess for VGG16
    img_array = img_to_array(img_resized)
    img_array = np.expand_dims(img_array, axis=0)
    img_array = preprocess_input(img_array)
    
    # Extract features using VGG16
    features = model.predict(img_array)
    
    # Flatten the feature maps
    features = features.flatten()
    
    return features.reshape(1, -1)


# Main function to execute the steps
def main(df, url_column, url_prefix):
    all_features = []
    for url in df[url_column]:
        print(url)
        try:
            img = load_image(url, url_prefix)  # Attempt to load the image
        except Exception as e:  # Catch any exception that occurs during image loading
            print(f"Error loading image from {url}: {e}")
            continue  # Skip this image and move to the next one

        features = extract_features_cnn(img)
        all_features.append(features)

    if not all_features:  # Check if we successfully loaded any features
        print("No valid images were loaded.")
        return []

    all_features = np.vstack(all_features)

    # Determine optimal clusters
    # print(all_features)
    optimal_clusters, inertia, silhouette_scores = determine_optimal_clusters(all_features)
    if optimal_clusters is None:
        print("Could not determine optimal clusters due to insufficient unique labels.")
        return []

    print('Optimal Cluster %s' % (optimal_clusters))
    cluster_labels, kmeans = perform_clustering(all_features, optimal_clusters)
    print_cluster_content(cluster_labels)
    pca_result = visualize_clusters(all_features, cluster_labels)
    output = prepare_output(cluster_labels, pca_result, all_features)
    outputlist = prepare_output_final(output)

    # Calculate average distance from centroid for each cluster
    average_distances = average_distance_from_centroid(outputlist)
    score = normalize_distances(average_distances)
    print('score')
    print(score)

    return output, optimal_clusters, inertia, silhouette_scores, outputlist, score


# Step 3: Optimal Cluster Determination
import numpy as np
from sklearn.cluster import KMeans
from sklearn.metrics import silhouette_score
import matplotlib.pyplot as plt

from sklearn.metrics import calinski_harabasz_score, davies_bouldin_score

def determine_optimal_clusters(features, max_clusters=15):
    inertia = []
    silhouette_scores = []
    calinski_harabasz_scores = []
    davies_bouldin_scores = []
    range_n_clusters = list(range(2, min(max_clusters, len(features))))

    for n_clusters in range_n_clusters:
        kmeans = KMeans(n_clusters=n_clusters, random_state=42)
        cluster_labels = kmeans.fit_predict(features)
        inertia.append(kmeans.inertia_)

        # Calculate silhouette score only if there is more than one cluster
        if len(np.unique(cluster_labels)) > 1:
            silhouette_scores.append(silhouette_score(features, cluster_labels))
            calinski_harabasz_scores.append(calinski_harabasz_score(features, cluster_labels))
            davies_bouldin_scores.append(davies_bouldin_score(features, cluster_labels))
        else:
            silhouette_scores.append(-1)
            calinski_harabasz_scores.append(float('inf'))  # Davies-Bouldin prefers smaller values
            davies_bouldin_scores.append(float('inf'))

    # If all silhouette scores are -1, return None
    if all(score == -1 for score in silhouette_scores):
        return None, inertia, silhouette_scores

    # Normalize the metrics for better comparison
    silhouette_scores = np.array(silhouette_scores)
    silhouette_scores = (silhouette_scores - silhouette_scores.min()) / (silhouette_scores.max() - silhouette_scores.min())

    calinski_harabasz_scores = np.array(calinski_harabasz_scores)
    calinski_harabasz_scores = (calinski_harabasz_scores - calinski_harabasz_scores.min()) / (calinski_harabasz_scores.max() - calinski_harabasz_scores.min())

    davies_bouldin_scores = np.array(davies_bouldin_scores)
    davies_bouldin_scores = (davies_bouldin_scores.max() - davies_bouldin_scores) / (davies_bouldin_scores.max() - davies_bouldin_scores.min())  # Invert because lower is better

    # Aggregate the scores
    combined_scores = silhouette_scores + calinski_harabasz_scores + davies_bouldin_scores

    # Find the optimal number of clusters with the highest combined score
    optimal_clusters = range_n_clusters[np.argmax(combined_scores)]

    # Optional: plot inertia, silhouette scores, and combined scores for visualization
    plt.figure(figsize=(18, 6))
    
    plt.subplot(1, 3, 1)
    plt.plot(range_n_clusters, inertia, marker='o')
    plt.title('Inertia (Elbow Method)')
    plt.xlabel('Number of Clusters')
    plt.ylabel('Inertia')

    plt.subplot(1, 3, 2)
    plt.plot(range_n_clusters, silhouette_scores, marker='o', label='Silhouette')
    plt.plot(range_n_clusters, calinski_harabasz_scores, marker='x', label='Calinski-Harabasz')
    plt.plot(range_n_clusters, davies_bouldin_scores, marker='s', label='Davies-Bouldin')
    plt.title('Individual Scores')
    plt.xlabel('Number of Clusters')
    plt.ylabel('Normalized Score')
    plt.legend()

    plt.subplot(1, 3, 3)
    plt.plot(range_n_clusters, combined_scores, marker='o')
    plt.title('Combined Score')
    plt.xlabel('Number of Clusters')
    plt.ylabel('Combined Score')

    plt.tight_layout()
    plt.show()

    # return optimal_clusters, inertia, silhouette_scores, calinski_harabasz_scores, davies_bouldin_scores, combined_scores
    return optimal_clusters, inertia, combined_scores #, calinski_harabasz_scores, davies_bouldin_scores, combined_scores

# Step 4: Clustering
def perform_clustering(features, n_clusters):
    kmeans = KMeans(n_clusters=n_clusters)
    cluster_labels = kmeans.fit_predict(features)
    return cluster_labels, kmeans

# Step 5: Print Cluster Content
def print_cluster_content(cluster_labels):
    unique_labels = np.unique(cluster_labels)
    for label in unique_labels:
        print(f"Cluster {label}: {np.sum(cluster_labels == label)} members")

# Step 6: PCA Scatter Plot
def visualize_clusters(features, cluster_labels):
    pca = PCA(n_components=2)
    pca_result = pca.fit_transform(features)
    plt.figure(figsize=(8, 6))
    scatter = plt.scatter(pca_result[:, 0], pca_result[:, 1], c=cluster_labels, cmap='viridis')
    plt.colorbar(scatter)
    plt.xlabel('PCA Component 1')
    plt.ylabel('PCA Component 2')
    plt.title('Clusters Visualization with PCA')
    # plt.show()
    return pca_result

# Step 7: Prepare Output
def prepare_output(cluster_labels, pca_result, features):
    output = []
    unique_labels = np.unique(cluster_labels)
    
    for label in unique_labels:
        members = np.where(cluster_labels == label)[0].tolist()
        cluster_pca1 = pca_result[cluster_labels == label, 0].tolist()
        cluster_pca2 = pca_result[cluster_labels == label, 1].tolist()
        cluster_features = features[cluster_labels == label]
        
        # Check if the cluster contains more than one unique point
        if len(cluster_features) > 1:
            # Check if the number of unique labels is more than one before calculating silhouette score
            if len(np.unique(cluster_labels)) > 1:
                try:
                    similarity_score = silhouette_score(cluster_features, [label] * len(cluster_features))
                except ValueError:
                    similarity_score = -1
            else:
                similarity_score = -1  # Set to -1 if silhouette score can't be calculated
        else:
            similarity_score = -1  # Set to -1 if there is only one point in the cluster
        
        output.append({
            'cluster': label,
            'members': members,
            'pca1': cluster_pca1,
            'pca2': cluster_pca2,
            'similarity_score': similarity_score
        })
    
    # Convert to DataFrame
    df_output = pd.DataFrame(output)
    
    # Convert DataFrame to list
    list_output = df_output.to_numpy().tolist()
    
    return list_output


# Function to compute the centroid of a cluster
def compute_centroid(points):
    points = np.array(points)
    return np.mean(points, axis=0)

# Function to calculate the Euclidean distance
def euclidean_distance(point1, point2):
    return np.linalg.norm(np.array(point1) - np.array(point2))

# Function to compute the average distance from the centroid for each cluster
def average_distance_from_centroid(data):
    clusters = defaultdict(list)
    
    # Grouping points by cluster number
    for entry in data:
        _, _, cluster_number, PCA1, PCA2 = entry
        clusters[cluster_number].append((PCA1, PCA2))
    
    average_distances = {}
    
    for cluster_number, points in clusters.items():
        centroid = compute_centroid(points)
        total_distance = sum(euclidean_distance(point, centroid) for point in points)
        average_distance = total_distance / len(points)
        average_distances[cluster_number] = average_distance
    
    return average_distances

# Function to normalize the distances to a score between 0 and 1
def normalize_distances(average_distances):
    min_distance = min(average_distances.values())
    max_distance = max(average_distances.values())
    
    normalized_scores = {}
    for cluster_number, avg_distance in average_distances.items():
        if max_distance == min_distance:  # Avoid division by zero
            normalized_scores[cluster_number] = 0.0
            normalized_scores[cluster_number] = 1 - normalized_scores[cluster_number]
        else:
            normalized_scores[cluster_number] = (avg_distance - min_distance) / (max_distance - min_distance)
            normalized_scores[cluster_number] = 1 - normalized_scores[cluster_number]
    
    return normalized_scores

def prepare_output_final(output):
    # create list of:
    memberIdx = 0
    outputlist = []
    
    for i in range(len(output)):
        # 0: cluster number
        # 1: member
        # 2: PCA1
        # 3: PCA2
        # 4: Sim Score ->> from score list
        
        # iterate thru member
        for j in range(len(output[i][1])):
            memberIndex = output[i][1][j]
            PCA1 = output[i][2][j]
            PCA2 = output[i][3][j]
            clusterId = output[i][0]
            # simScore = output[i][4][j]
            key_id = result_df['key_id'][memberIndex]
            
            # print(key_id, memberIndex, clusterId, PCA1, PCA2, simScore)
            outputlist.append([key_id, memberIndex, clusterId, PCA1, PCA2])
    
    return outputlist

def recording_output(output_final, score, platform_id):
# id, ref_id, cluster_no, platform_id, job_id
    query_sql = """
    insert into ret_cluster_image_result_monitor 
    (ref_id, cluster_no, platform_id, job_id, pca1, pca2, score)
    """

    for i in range(len(output_final)):
        sim_score = score[output_final[i][2]]
        valuesql = "values ( '" + str(output_final[i][0]) + "','" + str(output_final[i][2])  + "','" + str(platform_id) + "','" + str(i_process_id) + "','"+ str(output_final[i][3]) +"','" + str(output_final[i][4]) + "','" + str(sim_score) + "' )"
        ssql = query_sql + valuesql
        # print(ssql)
        data_connector.execute_query_psql(ssql)
# Out:
# 2024-09-12 17:11:42.867125: E external/local_xla/xla/stream_executor/cuda/cuda_fft.cc:485] Unable to register cuFFT factory: Attempting to register factory for plugin cuFFT when one has already been registered
# 2024-09-12 17:11:42.882896: E external/local_xla/xla/stream_executor/cuda/cuda_dnn.cc:8454] Unable to register cuDNN factory: Attempting to register factory for plugin cuDNN when one has already been registered
# 2024-09-12 17:11:42.887666: E external/local_xla/xla/stream_executor/cuda/cuda_blas.cc:1452] Unable to register cuBLAS factory: Attempting to register factory for plugin cuBLAS when one has already been registered
# 2024-09-12 17:11:42.899098: I tensorflow/core/platform/cpu_feature_guard.cc:210] This TensorFlow binary is optimized to use available CPU instructions in performance-critical operations.
# To enable the following instructions: AVX2 FMA, in other operations, rebuild TensorFlow with the appropriate compiler flags.
# 2024-09-12 17:11:43.758509: W tensorflow/compiler/tf2tensorrt/utils/py_utils.cc:38] TF-TRT Warning: Could not find TensorRT
# WARNING: All log messages before absl::InitializeLog() is called are written to STDERR
# I0000 00:00:1726161104.278591  733309 cuda_executor.cc:1015] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero. See more at https://github.com/torvalds/linux/blob/v6.0/Documentation/ABI/testing/sysfs-bus-pci#L344-L355
# I0000 00:00:1726161104.334090  733309 cuda_executor.cc:1015] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero. See more at https://github.com/torvalds/linux/blob/v6.0/Documentation/ABI/testing/sysfs-bus-pci#L344-L355
# I0000 00:00:1726161104.335802  733309 cuda_executor.cc:1015] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero. See more at https://github.com/torvalds/linux/blob/v6.0/Documentation/ABI/testing/sysfs-bus-pci#L344-L355
# I0000 00:00:1726161104.337758  733309 cuda_executor.cc:1015] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero. See more at https://github.com/torvalds/linux/blob/v6.0/Documentation/ABI/testing/sysfs-bus-pci#L344-L355
# I0000 00:00:1726161104.339109  733309 cuda_executor.cc:1015] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero. See more at https://github.com/torvalds/linux/blob/v6.0/Documentation/ABI/testing/sysfs-bus-pci#L344-L355
# I0000 00:00:1726161104.340458  733309 cuda_executor.cc:1015] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero. See more at https://github.com/torvalds/linux/blob/v6.0/Documentation/ABI/testing/sysfs-bus-pci#L344-L355
# I0000 00:00:1726161104.508612  733309 cuda_executor.cc:1015] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero. See more at https://github.com/torvalds/linux/blob/v6.0/Documentation/ABI/testing/sysfs-bus-pci#L344-L355
# I0000 00:00:1726161104.510091  733309 cuda_executor.cc:1015] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero. See more at https://github.com/torvalds/linux/blob/v6.0/Documentation/ABI/testing/sysfs-bus-pci#L344-L355
# I0000 00:00:1726161104.511430  733309 cuda_executor.cc:1015] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero. See more at https://github.com/torvalds/linux/blob/v6.0/Documentation/ABI/testing/sysfs-bus-pci#L344-L355
# 2024-09-12 17:11:44.513297: I tensorflow/core/common_runtime/gpu/gpu_device.cc:2021] Created device /job:localhost/replica:0/task:0/device:GPU:0 with 1035 MB memory:  -> device: 0, name: NVIDIA A10G, pci bus id: 0000:00:1e.0, compute capability: 8.6

# %%
img_prefix_http = "https://staging.disestages.com/api/media/photo/download/%s/"

# Processing jobs for each platform
# 10 = tiktok
# 20 = youtube
# 30 = instagram_post
# 40 = facebook_post
# 50 = google_result
# 60 = twitter_tweets

iRowCount = 0

# Twitter
if df_job['is_twitter'][0]:
    ssql = """
    select  a.id as key_id,
            b.filename as filename
    from    twitter_tweets a inner join media_files b 
            on a.id = b.tweet_id
    where a.monitoring_id = '%s'
    """
    ssql = ssql % social_media_monitoring_id
    print(ssql)
    
    img_prefix_http = "https://staging.disestages.com/api/media/photo/download/%s/" % "twitter"
    print(img_prefix_http)
    
    result_df = data_connector.execute_query_psql(ssql)
    
    if len(result_df) > 0:
        try:
            # processing
            output, optimal_clusters, inertia, silhouette_scores, output_final, score = main(result_df, 'filename', img_prefix_http)
            
            # Recording Result
            recording_output(output_final, score, 60)
            iRowCount += len(output_final)
        except Exception as e:
            print(f"Error processing Twitter data: {e}")

# TikTok
if df_job['is_tiktok'][0]:
    ssql = """
    select  a.id as key_id,
            b.filename as filename
    from    tiktok a inner join media_files_tiktok b 
            on a.id = b.tiktok_id 
    where a.monitoring_id = '%s'
    """
    ssql = ssql % social_media_monitoring_id
    print(ssql)
    
    img_prefix_http = "https://staging.disestages.com/api/media/photo/download/%s/" % "tiktok"
    print(img_prefix_http)
    
    result_df = data_connector.execute_query_psql(ssql)
    
    if len(result_df) > 0:
        try:
            # processing
            output, optimal_clusters, inertia, silhouette_scores, output_final, score = main(result_df, 'filename', img_prefix_http)
            
            # Recording Result
            recording_output(output_final, score, 10)
            iRowCount += len(output_final)
        except Exception as e:
            print(f"Error processing TikTok data: {e}")

# Facebook
elif df_job['is_facebook'][0]:
    ssql = """
    select  a.id as key_id,
            b.filename as filename
    from    facebook_post a inner join media_files_facebook b
            on a.id = b.facebook_id 
    where a.monitoring_id = '%s'
    """
    ssql = ssql % social_media_monitoring_id
    print(ssql)
    
    img_prefix_http = "https://staging.disestages.com/api/media/photo/download/%s/" % "facebook"
    print(img_prefix_http)
    
    result_df = data_connector.execute_query_psql(ssql)
    
    if len(result_df) > 0:
        try:
            # processing
            output, optimal_clusters, inertia, silhouette_scores, output_final, score = main(result_df, 'filename', img_prefix_http)
            
            # Recording Result
            recording_output(output_final, score, 40)
            iRowCount += len(output_final)
        except Exception as e:
            print(f"Error processing Facebook data: {e}")
# Out:
#     select  a.id as key_id,
#             b.filename as filename
#     from    twitter_tweets a inner join media_files b
#             on a.id = b.tweet_id
#     where a.monitoring_id = '67a4e45c-9eeb-49fd-a21e-59ddb2ef0865'
#
# https://staging.disestages.com/api/media/photo/download/twitter/
# GWwfzsaWkAAKt0H.jpg
# WARNING: All log messages before absl::InitializeLog() is called are written to STDERR
# I0000 00:00:1726161107.065340  746006 service.cc:146] XLA service 0x7fab0c006540 initialized for platform CUDA (this does not guarantee that XLA will be used). Devices:
# I0000 00:00:1726161107.065378  746006 service.cc:154]   StreamExecutor device (0): NVIDIA A10G, Compute Capability 8.6
# 2024-09-12 17:11:47.073772: I tensorflow/compiler/mlir/tensorflow/utils/dump_mlir_util.cc:268] disabling MLIR crash reproducer, set env var `MLIR_CRASH_REPRODUCER_DIRECTORY` to enable.
# 2024-09-12 17:11:47.162655: I external/local_xla/xla/stream_executor/cuda/cuda_dnn.cc:531] Loaded cuDNN version 8903
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 850ms/step
# GXLPqVlbcAAfFug.jpg
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 19ms/step
# I0000 00:00:1726161107.761583  746006 device_compiler.h:188] Compiled cluster using XLA!  This line is logged at most once for the lifetime of the process.
# GXMQywxbEAAUwV4.jpg
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 19ms/step
# GXK57HKaQAA7EDB.jpg
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 21ms/step
# GXOqfrIaMAACOX4.jpg
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 18ms/step
# GXOn8ipa4AA6qvt.jpg
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 18ms/step
# GXOnt4ca0AA09Tx.jpg
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 19ms/step
# GXOanJybgAIxPtO.jpg
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 19ms/step
# GXJ4TYQaUAACkXN.jpg
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step
# GXMg9gBbQAAFe3s.jpg
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 22ms/step
# GXOMtMwbYAAQKPq.jpg
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 23ms/step
# GXNqIOFaMAAjE1O.jpg
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 23ms/step
# GXMiNAdbsAAlhnW.jpg
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step
# GXNeOFObgAQxENp.jpg
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 19ms/step
# GXNdPh8XEAADKRA.jpg
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 23ms/step
# GXNdAtHbsAAyjiV.jpg
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step
# GXNcgxgbgAEnnqI.jpg
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step
# GXNX9D0agAAfaFQ.jpg
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step
# GXNTcjDasAAo0hy.jpg
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 23ms/step
# GXNTbHja8AE91Ax.jpg
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step
# GXNTZnSbkAAh7p8.jpg
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 19ms/step
# GXNTYDFaQAAbRKI.jpg
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 19ms/step
# GXNSg8-aYAARX_y.jpg
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 19ms/step
# GXNSkhDaAAAWYVq.jpg
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 19ms/step
# GXNSWyMagAANXoY.jpg
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step
# GXNSKcUbkAE8Su9.jpg
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 21ms/step
# GXNR5sjaEAA93l2.jpg
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 23ms/step
# GXNRmONbAAEvine.jpg
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 19ms/step
# GXNRlata4AAt8xK.jpg
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 19ms/step
# GXNRj2WbcAATN7e.jpg
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step
# GXNPqxmbkAAwK2u.jpg
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 23ms/step
# GXNPAnAbkAAYxhz.jpg
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 19ms/step
# GXNO88CbkAAccd9.jpg
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 23ms/step
# GXNO7aQaYAAwQZK.jpg
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step
# GXNMSUIbwAAhyQR.jpg
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 23ms/step
# GXNL6NqbMAAZd_0.jpg
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 27ms/step
# GXNLnc8bcAEvF1S.jpg
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step
# GXNKrQxaoAAJlJz.jpg
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step
# GXNJstYWIAABI4V.jpg
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 19ms/step
# GXNJoCZW0AAkvGY.jpg
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step
# GXNID7XaIAATjSr.jpg
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step
# GXNH9L8akAAB5Y1.jpg
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 22ms/step
# GXNH0qvaoAAZ-eU.jpg
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step
# GXNHo-HbUAAuJEz.jpg
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 22ms/step
# GXNHaHhakAAeCgB.jpg
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 19ms/step
# GXNG-JYakAAgGeK.jpg
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 18ms/step
# GXNCv3HbAAA3BVI.jpg
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 18ms/step
# GXNCl4XagAAkg4l.jpg
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 18ms/step
# GXM-VuTbIAAO_G-.jpg
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 26ms/step
# GXM91Sra0AA3Goc.jpg
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 19ms/step
# GXM84O9asAAlx0a.jpg
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 23ms/step
# GXM7YraakAA4vAU.jpg
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 19ms/step
# GXM66-eaYAAa0wZ.jpg
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 26ms/step
# GXM5y7GaEAAuGRu.jpg
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 23ms/step
# GXM5Ypaa0AAO7n0.jpg
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 22ms/step
# GXM3vO-agAA2HT-.jpg
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step
# GXM3pg0aMAAzeHM.jpg
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step
# GXM2gK9bgAEw0RW.jpg
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step
# GXM1WoDbIAA0eiD.jpg
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 21ms/step
# GXM1V7dbkAApn5t.jpg
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step
# GXM1VTIbcAAIQq6.jpg
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 19ms/step
# GXMu1utboAAFbBN.jpg
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 19ms/step
# GXMuppabYAAqDFt.jpg
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step
# GXMuSocakAAX0ZU.jpg
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 19ms/step
# GXMuPoAaEAA-DAH.jpg
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 19ms/step
# GXMuNDXbsAAT7Y0.jpg
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 23ms/step
# GXMuIi2bsAAgmAY.jpg
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 21ms/step
# GXMuH4HbIAAum3l.jpg
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 24ms/step
# GXMs66OaQAALV4h.jpg
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 24ms/step
# GXMpJ-IaAAAJ8WF.jpg
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 27ms/step
# GXMpGouawAAXC0j.jpg
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 21ms/step
# GXMn98XaoAA8TDN.jpg
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 23ms/step
# GXMnz2FbYAAqq9B.jpg
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 24ms/step
# GXMm3_jbwAAiJ7J.jpg
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 24ms/step
# GXMliOBa0AArFa-.png
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 19ms/step
# GXMknf6bEAAO3CC.jpg
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 21ms/step
# GXMiVBWboAEvdp2.jpg
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step
# GXMh5M8bEAAE4gA.jpg
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step
# GXMh3dxagAAq-gL.jpg
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step
# GXMh1v4aMAALAnN.jpg
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 25ms/step
# GXMh0M6boAAzQoh.jpg
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step
# GXMhzR5agAMg-Bo.jpg
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 23ms/step
# GXMhyP9aoAA9xA_.jpg
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 24ms/step
# GXMhddfbgAAIQq3.jpg
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 21ms/step
# GXMhdCmaYAA4k1B.jpg
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 24ms/step
# GXMhcl8akAEYa9S.jpg
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 19ms/step
# GXMhbufaMAAj_L8.jpg
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 19ms/step
# GXMhbTDawAASQ5T.jpg
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 19ms/step
# GXMha24aUAA5WeO.jpg
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 19ms/step
# GXMhaUObAAAjwCa.jpg
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 19ms/step
# GXMhZBDakAApiI8.jpg
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step
# GXMhW6yaIAAIxaM.jpg
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step
# GXMhWdbaYAA2x-I.jpg
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 19ms/step
# GXMhWCRbMAA_UAw.jpg
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 25ms/step
# GXMhVkfbEAAo381.jpg
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step
# GXMhUpwagAApOuW.jpg
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 23ms/step
# GXMhUO2aIAAaRYr.jpg
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 24ms/step
# GXMhTyrbcAACB4f.jpg
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 22ms/step
# GXMhQwEawAA3XcV.jpg
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 23ms/step
# GXMhP28bAAAnBiI.jpg
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step
# GXMhNkzagAA_Bf9.jpg
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 19ms/step
# GXMgcaLaAAAXJ4-.jpg
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step
# GXMgbM6aQAAalbH.jpg
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 19ms/step
# GXMgMOIaoAAi6R2.jpg
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 19ms/step
# GXMe8WtaAAA9TIQ.jpg
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 19ms/step
# GXMeKP1a4AAZSBH.jpg
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 19ms/step
# GXMd_ntbUAA0QiE.jpg
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step
# GXMdW8dbIAAriQA.jpg
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 19ms/step
# GXMc3FaasAA4vnQ.jpg
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 19ms/step
# GXMcxxDaYAAnXXK.jpg
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 19ms/step
# GXMcXMYbIAAPpoT.jpg
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step
# GXMb8HtaEAAtwy0.jpg
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 24ms/step
# GXMa5jraQAApZEt.png
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 23ms/step
# GXMZZOSakAAwo_d.jpg
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 19ms/step
# GXMYzx-asAA5zR4.jpg
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 21ms/step
# GXMYRmPbMAAaULU.jpg
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 26ms/step
# GXMX0VIb0AAM1rq.jpg
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 30ms/step
# GXMXk8kbAAAiIdC.jpg
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 21ms/step
# GXMUeivbUAAU18F.jpg
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step
# GXMS6JYaUAAvc9G.jpg
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 33ms/step
# GXMSs1HboAAF58O.jpg
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 23ms/step
# GXMSbw7bcAAJhP0.jpg
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step
# GXMQFwWa8AAKj37.jpg
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 26ms/step
# GXMPWrjbkAAlbPF.jpg
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step
# GXMPWU0aMAAcLuR.jpg
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 24ms/step
# GXMPUdfbAAA8Bkd.jpg
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 19ms/step
# GXMPRZXboAAM9BC.jpg
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 63ms/step
# GXMNhpZaoAAQ0kt.jpg
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 70ms/step
# GXMLq2MaMAAna5q.jpg
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 77ms/step
# GXMIj7tbcAASeRk.jpg
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 36ms/step
# GXMGD4xbEAApw6U.jpg
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 59ms/step
# GXMFVkobwAAyNNj.jpg
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 60ms/step
# GXMFRn9bsAAneZC.jpg
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 29ms/step
# GXMBzKeagAAyQRA.jpg
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 47ms/step
# GXMBPIUasAAe8hg.jpg
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 79ms/step
# GXMBK94bcAAs2em.jpg
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 60ms/step
# GXMBJxgaEAAY5_r.jpg
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 57ms/step
# GXL-CD8aoAAyNW2.jpg
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 74ms/step
# GXL-EhBa8AArF2g.jpg
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 37ms/step
# GXL9iGdbMAAz67e.jpg
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 28ms/step
# GXL8vDmaIAAij-o.jpg
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 30ms/step
# GXL8FykawAElVuQ.jpg
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 74ms/step
# GXL8VABboAAeVQj.jpg
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 38ms/step
# GXL7t2uakAAcgWS.jpg
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 55ms/step
# GXL7C-pasAAgwVc.jpg
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 66ms/step
# GXL6WF1bEAArYQ_.jpg
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 83ms/step
# GXL6O5pbIAAcCr7.jpg
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 69ms/step
# GXL6IaTaIAESX10.jpg
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 30ms/step
# GXL53QDaoAAqKSn.jpg
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 68ms/step
# GXL5pqXaAAAVjUE.jpg
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 71ms/step
# GXL5ZOhbwAAf5Hi.jpg
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 65ms/step
# GXL5TSVaIAAAUrL.jpg
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 40ms/step
# GXL4t1KbAAEzqjP.jpg
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 71ms/step
# GXL4nBlbkAAJtbZ.jpg
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 26ms/step
# GXL4fzIaEAAK78N.jpg
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 26ms/step
# GXL4Y7oakAAXLZh.jpg
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 27ms/step
# GXL38ahbYAA4dwN.jpg
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 27ms/step
# GXL31egaEAEfaUY.jpg
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 29ms/step
# GXL3ooia8AA2ENW.jpg
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 19ms/step
# GXL3mIba0AAwL0X.jpg
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 35ms/step
# GXL3cTQbYAAw6e7.jpg
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 27ms/step
# GXL3W4Gb0AAgQnW.jpg
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 26ms/step
# GXL3MT_bgAAxDTt.jpg
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 37ms/step
# GXL3MnRaoAARBDe.jpg
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 40ms/step
# GXL28BjbYAAfeYn.jpg
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 29ms/step
# GXL26p-aQAAHdF6.jpg
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 29ms/step
# GXL2vZ8a8AA3_k9.jpg
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 29ms/step
# GXL2gqwaEAAj-_Y.jpg
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 29ms/step
# GXL2e6gbUAAoiuk.jpg
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 30ms/step
# GXL2Zioa0AARhrB.jpg
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 27ms/step
# GXL2CcwaIAAhGfY.jpg
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 25ms/step
# GXL1pPAawAAidNv.jpg
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 30ms/step
# GXL1orUasAAacNw.jpg
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 29ms/step
# GXL1oWpbkAATwXE.jpg
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 28ms/step
# GXL01WKaEAAIih6.jpg
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 30ms/step
# GXL0doYbEAANiWk.jpg
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 29ms/step
# GXL0ZfpaAAA-W3d.jpg
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 24ms/step
# GXL0RXhbQAEBgHr.jpg
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 28ms/step
# GXL0UdeaMAAYyf3.jpg
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 31ms/step
# GXLz7RlbsAAIcFP.jpg
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 30ms/step
# GXLz55_boAA1MuQ.jpg
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 45ms/step
# GXLzZ5baIAA2Hsx.jpg
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 33ms/step
# GXLzYuvaYAApSuP.jpg
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 30ms/step
# GXLzUluaAAAP9Yn.jpg
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 25ms/step
# GXLzUFwa0AA_2yJ.jpg
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 28ms/step
# GXLzR12bEAA9o8G.jpg
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 29ms/step
# GXLwyZuaAAADWa6.jpg
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 29ms/step
# GXLwImKbEAA2Vk7.jpg
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 28ms/step
# GXLvmoDbcAAvnCi.jpg
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 29ms/step
# GXLvTwzaAAA_vCx.jpg
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 30ms/step
# GXLuSVab0AAZqrf.jpg
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 23ms/step
# GXLuKUmbcAADB-z.jpg
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step
# GXLuGCSaUAAqRuC.jpg
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step
# GXLqkraaYAETiB1.jpg
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 19ms/step
# GXLqUROb0AAHglB.jpg
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 19ms/step
# GXLqNi7a4AACwR2.jpg
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 19ms/step
# GXLp6R1aUAETcHj.jpg
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step
# GXLpu-2bcAAYcN9.jpg
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 29ms/step
# GXLpmvFbUAAd2N4.jpg
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 31ms/step
# GXLplYoaIAArmIj.jpg
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 35ms/step
# GXLpY0hacAA9xL6.jpg
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 28ms/step
# GXLo4DLb0AAc9IZ.jpg
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 55ms/step
# GXLo2jYaUAE_hXx.jpg
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 51ms/step
# GXLoyD_bMAElF_h.jpg
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 38ms/step
# GXLoauqbEAATLDr.jpg
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 29ms/step
# GXLoB40b0AEBFrc.jpg
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 36ms/step
# GXLnxukawAAqL4x.jpg
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 26ms/step
# GXLnyUaboAAdZbR.jpg
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 33ms/step
# GXLmKG1a4AAZwd-.jpg
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 28ms/step
# GXLl51ma0AAgu2w.jpg
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 28ms/step
# GXLlmXRb0AAMsua.jpg
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 29ms/step
# GXLk_DXbwAAuq-Q.jpg
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 36ms/step
# GXLjgwPaYAABqYA.jpg
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 33ms/step
# GXLi5JUbgAA-DG5.jpg
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 32ms/step
# GXLinUIagAAcEoX.jpg
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 40ms/step
# GXLimEOboAA706u.jpg
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 28ms/step
# GXLiNyXbUAA0E1R.jpg
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 39ms/step
# GXLiMPYbcAAhBf8.jpg
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 30ms/step
# GXLhy3Da4AAr4Q6.jpg
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 31ms/step
# GXLhn2Ba4AAw0R8.jpg
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 33ms/step
# GXLhjA5a8AATLEA.jpg
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 28ms/step
# GXLhV61bkAADwD6.jpg
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 27ms/step
# GXLhFIIawAAj-Hk.jpg
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 31ms/step
# GXLg5-gbMAAGqpT.jpg
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 30ms/step
# GXLgxgVacAAb8ON.jpg
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 37ms/step
# GXLgv3QagAAdLQw.jpg
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 30ms/step
# GXLgo5Fa0AAIP2S.jpg
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 30ms/step
# GXLgO0ca8AAJy2Z.jpg
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 28ms/step
# GXLgOQjbIAAhODL.jpg
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step
# GXLgDDrasAA1GLY.jpg
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 23ms/step
# GXLf-rmaQAAxddb.jpg
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step
# GXLfxmkbUAA7fZN.jpg
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 21ms/step
# GXLfsFzbQAA7QrX.jpg
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 19ms/step
# GXLfqKKacAAqIG6.jpg
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 28ms/step
# GXLfmhKakAAa0tj.jpg
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 31ms/step
# GXLfnfMbcAAEwng.jpg
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 22ms/step
# GXLfb_Pa0AA7Cly.jpg
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 28ms/step
# GXLfQ7qbcAAadtZ.jpg
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 23ms/step
# GXLfRdla4AEF9uH.jpg
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 35ms/step
# GXLfMCAbcAAHgdq.jpg
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step
# GXLfHHDbUAApwV8.jpg
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 22ms/step
# GXLfGDzasAA8nhd.jpg
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 21ms/step
# GXLeGWeawAARsbE.jpg
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 30ms/step
# GXLef35boAAnthI.jpg
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step
# GXLentcaoAApBjD.jpg
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 21ms/step
# GXLei9nacAAY-Bd.jpg
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step
# GXLecbDbYAAW72C.jpg
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 21ms/step
# GXLeY0-akAA6SJt.jpg
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 23ms/step
# GXLeMiPasAAoL9e.jpg
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step
# GXLeE6HaEAABZcl.jpg
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step
# GXLd3nbbAAANsAv.jpg
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 19ms/step
# GXLd1FFbUAAens4.jpg
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 19ms/step
# GXLdve1agAATiSw.jpg
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 19ms/step
# GXLdkuxaEAAQcMw.jpg
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 19ms/step
# GXLdfgvbIAAWbHy.jpg
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 19ms/step
# GXLdYqfagAA90vi.jpg
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 25ms/step
# GXLdRpfaYAAFVVX.jpg
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 24ms/step
# GXLdNkJb0AAA68v.jpg
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 24ms/step
# GXLdI1hbwAAbOlh.jpg
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 19ms/step
# GXLdE0WbIAAYzRq.jpg
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 24ms/step
# GXLdHZTagAAlqDM.jpg
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 21ms/step
# GXLdF19aAAAsLiv.jpg
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step
# GXLdFEjbkAAFsE4.jpg
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 25ms/step
# GXLc9czaoAAekms.jpg
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 21ms/step
# GXLc8L7aAAA3Hp5.jpg
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 21ms/step
# GXLc4MVakAAhcKB.jpg
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step
# GXLc2HVbwAAKMrD.jpg
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 28ms/step
# GXLcq11bAAAkOf6.jpg
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step
# GXLchk_bkAAM9cM.jpg
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 21ms/step
# GXLcNHKbAAA7vWx.jpg
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step
# GXLcMCfaIAAxJUF.jpg
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 19ms/step
# GXLcMKLbYAAqEqO.jpg
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step
# GXLcDszbgAAX88w.jpg
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step
# GXLcAhiasAAZhwy.jpg
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 19ms/step
# GXLb8zmbUAARwU0.jpg
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step
# GXLbzVkaQAADxfk.jpg
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step
# GXLbtGZa0AERvEq.jpg
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 19ms/step
# GXLbmfPbcAAvif1.jpg
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 19ms/step
# GXLbiadbcAEGDn9.jpg
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 19ms/step
# GXLbdBwaMAAFL95.jpg
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step
# GXLbOzhasAEziYc.jpg
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 19ms/step
# GXLbJ-7akAAjmfV.jpg
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step
# GXLbECTawAAAaMG.jpg
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step
# GXLa8kIbcAAlmST.jpg
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 19ms/step
# GXLa1cTakAAT0DB.jpg
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 19ms/step
# GXLaybQbsAA-Ghv.jpg
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 19ms/step
# GXLato3asAAPFph.jpg
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 19ms/step
# GXLapO3a8AA3MDw.jpg
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 19ms/step
# GXLZ52KakAAic32.jpg
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step
# GXLZf4naAAAFEto.jpg
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 19ms/step
# GXLZSJ0aUAAWiyp.jpg
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step
# GXLZJ-ea8AEZQJ2.jpg
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 19ms/step
# GXLZHevboAAXaSL.jpg
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 19ms/step
# GXLY_1HaMAAjc_H.jpg
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 24ms/step
# GXLZA4LboAA_FRP.jpg
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 19ms/step
# GXLY7iPacAEIhZn.jpg
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step
# GXLY5erbkAAv8_d.jpg
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 23ms/step
# GXLY5GgbQAA07kW.jpg
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 22ms/step
# GXLYxzfbkAAgBY2.jpg
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 23ms/step
# GXLYxLqbYAA0_AA.jpg
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step
# GXLYuFCasAADjs2.jpg
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 24ms/step
# GXLYtFkaEAAiALn.jpg
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step
# GXLYsk5bwAAVcFe.jpg
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 21ms/step
# GXLYphDa4AAs3Yb.jpg
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 21ms/step
# GXLYkDDaoAAY6cg.jpg
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 22ms/step
# GXLYjsWaUAETs_d.jpg
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 27ms/step
# GXLYX7sbsAAmhxb.jpg
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 27ms/step
# GXLWsf5bgAAR7uX.jpg
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 26ms/step
# GXLWP3ubkAAujb_.jpg
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 19ms/step
# GXLVkyna4AAMjAv.jpg
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 19ms/step
# GXLUxEyaMAAns5e.jpg
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 25ms/step
# GXLUr4kacAA7al6.jpg
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 19ms/step
# GXLNeKcagAAP9LY.jpg
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 19ms/step
# GXLM3K7bMAAmEjH.jpg
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 24ms/step
# GXLJIlMbwAAlNxD.jpg
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 25ms/step
# GXLIreja4AACQ_3.jpg
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step
# GXLFNLWbMAAxSX5.jpg
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 19ms/step
# GW8xHB2aYAAlVqw.jpg
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step
# GXLAN8jaQAAvlpE.png
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 25ms/step
# GXK_M9ma0AAjlSs.jpg
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step
# GXK-OPNbAAAi4zv.jpg
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 23ms/step
# GXK6qTCaEAEBSic.jpg
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step
# GXK5s1QbwAArzFI.jpg
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step
# GXK4k6sb0AAUjE2.jpg
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 25ms/step
# GXK4QHeagAA1cge.jpg
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 25ms/step
# GXK4KP6bgAAadtX.jpg
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step
# GXK3njMaIAAoZRp.jpg
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step
# GXK2f8ZbMAAdX79.jpg
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 19ms/step
# GXK0afIa8AAHUvv.jpg
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 25ms/step
# GXKzm4QbAAAtzac.jpg
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 21ms/step
# GXK01_QakAA3IL8.jpg
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 22ms/step
# GXK0y0ObMAEdLj0.jpg
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step
# GXK0gUsaEAA0jph.jpg
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 19ms/step
# GXK0P7ia8AA3iLE.jpg
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 19ms/step
# GXK0MV0aEAAkz17.jpg
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 24ms/step
# GXK0LKVbUAAL1kj.jpg
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 19ms/step
# GXKzsmJaQAAiWmW.jpg
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 19ms/step
# GXKyY3CbMAAtkOA.jpg
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 19ms/step
# GXKxwJ9b0AA8XGC.jpg
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 21ms/step
# GXKxwM3aAAAonDN.jpg
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 23ms/step
# GXKwjRgbEAA846R.jpg
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 19ms/step
# GXKwS-fbYAAGhB6.jpg
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step
# GXKwJfsbQAAOOiM.jpg
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 21ms/step
# GXKvxy5aIAAkC72.jpg
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 27ms/step
# GXKvvYsbAAAWV7J.jpg
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step
# GXB7zYyaIAAk1fv.jpg
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 27ms/step
# GXKLLx5bQAA2gBI.jpg
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step
# GXKuib5bEAAzyiz.jpg
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step
# GXKt_ZUbsAAOZYs.jpg
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 21ms/step
# GXKtzRQbgAALXUr.jpg
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step
# GXKsBctXEAAL4fk.jpg
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 24ms/step
# GXKraAUbEAA49sQ.jpg
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step
# GXKqPrGasAAJuz6.jpg
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step
# GXKpynzaIAA0jgx.jpg
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step
# GXKmp6Na4AAgP33.jpg
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 21ms/step
# GXKlelYbUAAYjQL.jpg
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 21ms/step
# GXKkByjaAAAQ8Xm.jpg
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 22ms/step
# GXKj9dtbMAAmzQg.jpg
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step
# GXKjLSuaUAAms-o.jpg
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 19ms/step
# GXKjFCRagAArfBN.jpg
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 19ms/step
# GXKi6CFaIAAmlME.jpg
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 18ms/step
# GXKhupHa0AEjzpY.jpg
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 19ms/step
# GXKhkVua8AAsK8J.jpg
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 19ms/step
# GXKhjebbYAA2j_S.jpg
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 23ms/step
# GXKhE-2bsAATEds.jpg
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step
# GXKg1E2a4AArvfh.jpg
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 23ms/step
# GXKgfswXkAAg8eI.jpg
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 22ms/step
# GXKfRmfasAEetLV.jpg
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 22ms/step
# GXKfPV7awAAvfQ8.jpg
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 23ms/step
# GXKfNK6bgAAusvD.jpg
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 24ms/step
# GXKfLPcbEAECXOH.jpg
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step
# GXKejNCacAAc_gX.jpg
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step
# GXKdpqGaoAAbicr.jpg
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 23ms/step
# GXKdoa3asAAss_W.jpg
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 23ms/step
# GXKdm6Ib0AAo9f7.jpg
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 22ms/step
# GXKdlDha4AApGyV.jpg
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 21ms/step
# GXKdPejasAAyBfg.jpg
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 25ms/step
# GXKdKICbsAAv8hi.jpg
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 21ms/step
# GXKcy83bMAA3Xtl.jpg
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 28ms/step
# GXKcxOQbMAAucHe.jpg
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step
# GXKcgnHaEAEvcz5.jpg
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 23ms/step
# GXKbDpvaoAAC2_3.jpg
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 22ms/step
# GXKa60baAAA9DfG.jpg
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 22ms/step
# GXKaf_-bIAA9ddJ.jpg
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 21ms/step
# GXKZMUtbkAAYErf.jpg
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 22ms/step
# GXKY3aMbcAAVhwe.jpg
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 25ms/step
# GXKZK1qbQAAvUG4.jpg
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 21ms/step
# GXKYhjRbUAAM145.jpg
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 23ms/step
# GXKYLgvWwAAOVaz.jpg
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step
# GXKXZrsaAAAAP1b.jpg
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 21ms/step
# GXKXVtoaMAAji3Y.jpg
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 21ms/step
# GXKXNsXb0AATmpm.jpg
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 21ms/step
# GXKXGiebsAAzk0q.jpg
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 21ms/step
# GXKWbgQboAArKSN.jpg
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 21ms/step
# GXKW35maQAAQuQr.jpg
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step
# GXKW0-HbEAAUT1K.jpg
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 22ms/step
# GXKWswCbUAAyQns.jpg
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step
# GXKWFC6a4AA9A7H.jpg
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 23ms/step
# GXKWDpkbkAALde3.jpg
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 19ms/step
# GXKVx1XbIAAStnV.jpg
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 28ms/step
# GXKVeOMaEAA3b5N.jpg
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 28ms/step
# GXKVdNPbgAAuPB5.jpg
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 27ms/step
# GXKVcQubYAAbHHu.jpg
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 24ms/step
# GXKVbTEb0AAptXv.jpg
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 33ms/step
# GXKVab5bIAA0nph.jpg
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step
# GXKVMY4bEAAeBt8.jpg
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 22ms/step
# GXKVL4EaIAA3ywF.jpg
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step
# GXKVAGMawAA9tg3.jpg
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 24ms/step
# GXKU0s2bQAAjNvq.jpg
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 21ms/step
# GXKUn77aYAAj_nK.jpg
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 23ms/step
# GXKUNg5aQAAjgGr.jpg
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 23ms/step
# GXKTXAHbYAA0-KN.jpg
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 28ms/step
# GXKTN8GbEAAdk4L.jpg
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 31ms/step
# GXKSpXCbgAABoux.jpg
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step
# GXKSnccaUAA26d2.png
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 29ms/step
# GXKSGm7bgAAWT5m.jpg
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 21ms/step
# GXKR7H6bkAArhqs.jpg
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 21ms/step
# GXKR1Cia4AAITXt.jpg
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step
# GXKR0b4awAAzbif.jpg
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 21ms/step
# GXKRz8lagAA927a.jpg
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 21ms/step
# GXKQjWSbgAEU-Fb.jpg
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 21ms/step
# GXKQabtagAANTv7.jpg
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 26ms/step
# GXKQXTSaAAAwvOn.jpg
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 19ms/step
# GXKQSfSaAAAZm_x.jpg
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step
# GXKQEtaa0AAxbxJ.jpg
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 19ms/step
# GXKPc0ob0AAkxy-.jpg
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 19ms/step
# GXKPQ7LbcAEXJ5j.jpg
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step
# GXKOsdDbAAAF8zu.jpg
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 19ms/step
# GXKOmxpb0AA9kNr.jpg
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 25ms/step
# GXKNKmgaEAA6OIp.jpg
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 25ms/step
# GXKJvAJasAAUcjx.jpg
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 19ms/step
# GXKJAyObsAApv9S.jpg
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 19ms/step
# GXKHcRLbEAAPWiZ.jpg
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 19ms/step
# GXKG3R4bQAAY4-q.jpg
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 23ms/step
# GXKGvexbEAAA0FE.jpg
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 19ms/step
# GXKGsZmaEAAyHRr.jpg
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 22ms/step
# GXKGhi1bwAAA5AQ.jpg
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 21ms/step
# GXKGT9Pa4AEyMmM.jpg
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 21ms/step
# GXKGIIxacAAeevb.jpg
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 21ms/step
# GXKF_Bsa8AA6fWn.jpg
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 22ms/step
# GXKF1KDaMAAtASZ.jpg
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 30ms/step
# GXKFsAVbcAAWbVs.jpg
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 21ms/step
# GXKFixcbUAE8pTJ.jpg
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 24ms/step
# GXKFWgebUAAJ26U.jpg
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 21ms/step
# GXKFLSTaoAAuT2V.jpg
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 19ms/step
# GXKFFLgaUAA8Rdi.jpg
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 21ms/step
# GXKEzQtb0AAJwxk.jpg
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 22ms/step
# GXKEtB6bUAAqP9n.jpg
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 26ms/step
# GXKErbAboAABKQN.jpg
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 27ms/step
# GXKEqAxagAAQqOl.jpg
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 32ms/step
# GXKC-qQbkAANlZ4.jpg
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step
# GXKAuahboAAPpnH.jpg
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 22ms/step
# GXJ_XuQbsAEK-j-.jpg
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 28ms/step
# GXJ_HI6aoAAthu4.jpg
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 24ms/step
# GXJ_AzfbQAARH8P.jpg
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 24ms/step
# GXJ-tPPaYAAHWAM.jpg
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 28ms/step
# GXJ-HfrasAAc0T6.jpg
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 21ms/step
# GXJ-EjLbIAA_m7s.jpg
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 21ms/step
# GXJ-BPua0AAIckV.jpg
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step
# GXJ9-v9bcAA7Ydb.jpg
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step
# GXJ9eSEbkAAAQ6P.jpg
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 21ms/step
# GXJ9NSEbAAEOgfv.jpg
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 19ms/step
# GXJ83N3bgAAuB9r.jpg
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step
# GXJ8kuNacAAVib0.jpg
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 27ms/step
# GXJ6UvhaQAAuSz-.jpg
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 23ms/step
# GXJ5bUIaUAA6XN5.jpg
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 21ms/step
# GXJ48xbaYAA9UMd.jpg
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step
# GXJ46EDbIAAb_v3.jpg
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step
# GXJ370gaMAAuWSs.jpg
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 26ms/step
# GXJ1lMMaIAEqt0l.jpg
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 21ms/step
# GXJ0Iuva0AA-x3r.jpg
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 19ms/step
# GXJtKi1a4AAJXHu.jpg
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step
# GXJtG1WbEAYHkYY.jpg
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 21ms/step
# GXJs6XVaMAAU0gy.jpg
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step
# GXJszBZbEAQNUmt.jpg
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step
# GXJsvjbbEAAkukZ.jpg
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 21ms/step
# GXJssVybEAANOgQ.jpg
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 21ms/step
# GXJsj4RbEAAcW-Q.jpg
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step
# GXJscFLa4AA82xc.jpg
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 27ms/step
# GXJsU-4bEAIBeUy.jpg
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 25ms/step
# GXJsL7_bEAIst7J.jpg
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 21ms/step
# GXJsDeHbEAEo-DH.jpg
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step
# GXJq7bsbEAI0WYI.jpg
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 21ms/step
# GXJo08sbAAEisIP.jpg
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 26ms/step
# GXJm_jaaAAA4MIC.jpg
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 25ms/step
# GXJiDYzbEAQKyqj.jpg
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 19ms/step
# GXJgBtCacAAjWVK.jpg
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 24ms/step
# GXHHYEXaQAAFXw6.jpg
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 21ms/step
# GXI7ggnagAAwDtI.jpg
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 22ms/step
# GXIy1dEbEAYTPJZ.jpg
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 25ms/step
# GXItSRWbEAQwlF5.jpg
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 21ms/step
# GXIntf5acAAj23q.jpg
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 25ms/step
# GXInsKfbQAAE_zH.jpg
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 24ms/step
# GXIlRZmbEAIG2o9.jpg
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step
# GXIjFfUbEAIhz8V.jpg
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 21ms/step
# GXIfqhJbEAEUEmW.jpg
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step
# GXIdwvDawAAwASY.jpg
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 22ms/step
# GXIdxmFbYAEJ16A.jpg
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 19ms/step
# GXIdxPhbEAE9qQI.jpg
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step
# GXIdGRWbEAAJEI5.jpg
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step
# GXIcX_DbEAMqrWE.jpg
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step
# GXIb6ZjbEAESr6P.jpg
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step
# GXIZNtYbEAQ67vt.jpg
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step
# GXIZCyHaYAA_tMY.jpg
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step
# GXIYEe3bEAACydG.jpg
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 19ms/step
# GXIXwfaasAAu8wp.jpg
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 21ms/step
# GXIXqDlbEAIPrj_.jpg
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 21ms/step
# GXIXoMFbEAAg79w.jpg
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 19ms/step
# GXIXh96bEAUii0_.jpg
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 19ms/step
# GXIXceabEAUqvNc.jpg
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 19ms/step
# GXIXV46bEAUPO0V.jpg
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 19ms/step
# GXIWuFDaYAArQCY.jpg
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 19ms/step
# GXIVC4LbEAAa6Hu.jpg
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step
# GXIVCfhbEAMMlQs.jpg
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 24ms/step
# GXIUkFMbEAIo5vw.jpg
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 28ms/step
# GXIUenzaEAAshzo.jpg
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step
# GXIUi6PbEAI5uAb.jpg
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 21ms/step
# GXIUQnlbwAAoQQs.jpg
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 22ms/step
# GXITWPibAAAMKC1.jpg
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 23ms/step
# GXISw7bbEAQfxtG.jpg
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step
# GXISdQCa4AAxBJF.jpg
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step
# GXISXHwbEAIo-WX.jpg
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step
# GXISLk5akAAoFz-.jpg
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 21ms/step
# GXISJ3lbEAM6H28.jpg
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 21ms/step
# GXISIitbEAICglw.jpg
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 21ms/step
# GXISC-QbEAQqOur.jpg
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 21ms/step
# GXIR2GCa4AAGIvc.jpg
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 26ms/step
# GXIRzLzbkAAhtRc.jpg
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 24ms/step
# GXIR0rabEAQ4knU.jpg
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step
# GXIRq0mbEAQZc2E.jpg
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 22ms/step
# GXIRag6bEAAOdFw.jpg
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step
# GXIRYDVbEAMVsQE.jpg
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step
# GXIRXfsbAAATsW0.jpg
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 24ms/step
# GXIRXTjbEAA9a80.jpg
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step
# GXIRVudagAAhFNe.jpg
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 21ms/step
# GXIRTybbEAEEsiH.jpg
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 26ms/step
# GXIRTyzbEAIal6k.jpg
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 28ms/step
# GXIRQfobEAAyS1i.jpg
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 21ms/step
# GXIRNoEbEAEM4qb.jpg
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 21ms/step
# GXIRCuGbEAEqAZ7.jpg
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 23ms/step
# GXINOz9bIAAQF9i.jpg
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 23ms/step
# GXINNR6acAE5B1D.jpg
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 19ms/step
# GXINIQ1bEAAyqak.jpg
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step
# GXIM29vboAAxthA.jpg
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 21ms/step
# GXILhujbEAcCAXb.jpg
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 21ms/step
# GXILS-7bEAA_SOf.jpg
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 22ms/step
# GXIK2sLbEAIQvhy.jpg
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 21ms/step
# GXIK5QfbEAYueU9.jpg
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step
# GXIJEDobEAUca5M.jpg
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step
# GXIIkiPbgAAiLuW.jpg
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step
# GXIG0S3acAAIcP-.jpg
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step
# GXIFs9zbEAIG63r.jpg
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 23ms/step
# GXIEulJaQAAvLp5.jpg
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step
# GXIDmbvbEAgUQqF.jpg
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 19ms/step
# GXIDHagbEAIOjRz.jpg
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 21ms/step
# GXIDFvXbEAENANp.jpg
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 21ms/step
# GXICNDRaEAANs6P.jpg
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 19ms/step
# GXIC4N1bYAApWUk.jpg
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 19ms/step
# GXICwM0bEAcX0av.jpg
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step
# GXICrTebEAQMIog.jpg
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 19ms/step
# GXICe28bEAAQbLW.jpg
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 19ms/step
# GXICHJabEAErN2C.jpg
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 19ms/step
# GXICLnAaIAAwjZ9.png
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step
# GXICEsCbEAA-TOu.jpg
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 19ms/step
# GXIBtVmbEAkuOrl.jpg
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step
# GXIBo03bEAQxcZi.jpg
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 22ms/step
# GXIBjijbEAMWw4A.jpg
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 19ms/step
# GXIA4bzbEAQkQKT.jpg
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 19ms/step
# GXIBfsJa0AA8Ukh.jpg
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 23ms/step
# GXIBQqGaUAEv2P_.jpg
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 19ms/step
# GXIBeIAbEAA3C9P.jpg
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 25ms/step
# GXIBCwObEAcNVzk.jpg
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 22ms/step
# GXIBPgAaUAAXSGS.jpg
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 19ms/step
# GXIA_FoakAASjJ9.jpg
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step
# GXIA-D8boAAxwV0.jpg
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 24ms/step
# GXIA79SbEAIUqfP.jpg
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 28ms/step
# GXIA7AebEAEnsXi.jpg
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step
# GXIA4q1a4AEVmEF.jpg
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step
# GXIAw7vbEAIDyXq.jpg
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 23ms/step
# GXIAdDsaMAADJ4g.jpg
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 25ms/step
# GXIAfeGbEAMYnwS.jpg
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step
# GXIAWXDbEAIWbmJ.jpg
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 22ms/step
# GXIASaDbEAcHI3s.jpg
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 22ms/step
# GXIAMqfboAALHFa.jpg
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 22ms/step
# GXH_8vWbEAMIYfk.jpg
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 27ms/step
# GXIAJJfbEAA0KxM.jpg
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 24ms/step
# GXH_-nyakAEayxe.jpg
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 25ms/step
# GXH_-zebMAAY34Q.jpg
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 22ms/step
# GXH_4B6aMAAgo8G.jpg
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step
# GXH_54obEAInhs1.jpg
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 19ms/step
# GXH_PcaaYAALSFE.jpg
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 22ms/step
# GXH_iVebEAIcc3C.jpg
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step
# GXH_rN8bEAIKfIJ.jpg
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 19ms/step
# GXH_duQbEAUCFwu.jpg
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 24ms/step
# GXH-1HLbEAMBxDz.jpg
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 21ms/step
# GXH_g0PbEAQDBPq.jpg
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 29ms/step
# GXH_aWGasAAd3O5.jpg
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 43ms/step
# GXH_bIabsAA66t3.jpg
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 62ms/step
# GXH_XlqbEAEmtdr.jpg
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 31ms/step
# GXH_TdqbEAktuLM.jpg
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 60ms/step
# GXH_TL1bEAQG3ao.jpg
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 47ms/step
# GXH_QwGb0AAFctg.jpg
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 81ms/step
# GXH_NPAbEAUGrbK.jpg
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 96ms/step
# GXH_MnubEAAa4d4.jpg
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 72ms/step
# GXH_K_GbEAU-jaL.jpg
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 40ms/step
# GXH_LCVbEAQ8Qd6.jpg
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 50ms/step
# GXH-mvZbEAMMZBy.jpg
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 39ms/step
# GXH_FS3bEAANDuE.jpg
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 40ms/step
# GXH_C-mbEAMqN_R.jpg
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 58ms/step
# GXH_DdYbEAEn8Ni.jpg
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 32ms/step
# GXH-7P-bEAEavKW.jpg
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 36ms/step
# GXH-1c5bEAE5K5n.jpg
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 29ms/step
# GXH-3hJbEAQYXOX.jpg
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 38ms/step
# GXH-0XPbEAASOpR.jpg
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 84ms/step
# GXH-c7bbsAAvnLF.jpg
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 44ms/step
# GXH-yo7aYAALbAv.jpg
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 60ms/step
# GXH-xt7bEAEYE7W.jpg
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 34ms/step
# GXH-xMBbwAA4OKP.jpg
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 29ms/step
# GXH-vMfbEAAFjhm.jpg
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 84ms/step
# GXH-vP5bEAM8nSN.jpg
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 58ms/step
# GXH-u5sbEAg97Y8.jpg
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 37ms/step
# GXH-uWebEAE6tY2.jpg
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 51ms/step
# GXH-q9PbEAAiSz5.jpg
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 82ms/step
# GXH-tPAbUAArDNd.jpg
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 68ms/step
# GXH-qbYaIAAXqsY.jpg
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 76ms/step
# GXH-sQObEAQutBF.jpg
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 30ms/step
# GXH-sN2aQAA3-Zl.jpg
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step
# GXH-qCFbgAA0fBP.jpg
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 29ms/step
# GXH-pm4bEAIhI6S.jpg
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 30ms/step
# GXH-oKrbEAA0A9x.jpg
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 25ms/step
# GXH-o1rbwAAWKC1.jpg
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 31ms/step
# GXH-oVUaAAERGq2.jpg
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 33ms/step
# GXH-lGMbEAQ34pX.jpg
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 29ms/step
# GXH-npJbEAUJoAG.jpg
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 32ms/step
# GXH-n0EbEAILM0k.jpg
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 41ms/step
# GXH-m33bEAMehOs.jpg
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 36ms/step
# GXH-mufbwAAE3c8.jpg
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 30ms/step
# GXH-mDZaUAAJDsL.jpg
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 27ms/step
# GXH-lLibEAMyA2N.jpg
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 29ms/step
# GXH-loAbEAE57cj.jpg
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 34ms/step
# GXH-lhBa4AAhrXs.jpg
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 31ms/step
# GXH-jl6bEAAOCDA.jpg
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 30ms/step
# GXH-jNPbEAMyC6t.jpg
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 33ms/step
# GXH-jTZbEAETCCP.jpg
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 34ms/step
# GXH-jI4bEAUG09R.jpg
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 26ms/step
# GXH-atqa0AAF-E7.jpg
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 37ms/step
# GXH-fBibcAAzOX5.jpg
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 25ms/step
# GXH-cTnboAAZNyI.jpg
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 32ms/step
# GXH-f74bEAAblJC.jpg
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 31ms/step
# GXH-fEEbEAA6nxN.jpg
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 29ms/step
# GXH-e6_bEAQml3V.jpg
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 29ms/step
# GXH-duZbEA8smEM.jpg
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 28ms/step
# GXH-deUbEAEGzK5.jpg
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 30ms/step
# GXH-dOUbEAQz93J.jpg
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 46ms/step
# GXH-XIva0AA8022.jpg
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 29ms/step
# GXH-cjYbEAI25aC.jpg
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 30ms/step
# GXH-btfbEAACg3m.jpg
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 37ms/step
# GXH-bUSbEAY3a8t.jpg
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 23ms/step
# GXH-X1ybEAIPYo7.jpg
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 25ms/step
# GXH-YRDbEAQJuWU.jpg
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 23ms/step
# GXH-Xx7bEAQ1lOS.jpg
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 29ms/step
# GXH-XruasAAyATs.jpg
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 26ms/step
# GXH-SsSa0AAr1oo.jpg
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 27ms/step
# GXH-VBUboAAiyCW.jpg
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 23ms/step
# GXH-UlcbEAAfJfD.jpg
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 31ms/step
# GXH-Uk6bEAMoomB.jpg
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 39ms/step
# GXH-Tv9boAA7fQh.jpg
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 37ms/step
# GXH-QkHbEAYVMNW.jpg
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 28ms/step
# GXH-Q1JaUAAXIBu.jpg
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 40ms/step
# GXH-QVuaIAACaub.jpg
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 38ms/step
# GXH-QzjbEAMyqyb.jpg
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 28ms/step
# GXH-JQjbYAAnn6A.jpg
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 31ms/step
# GXH9M9haAAAIqFE.jpg
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 30ms/step
# GXH9MYdbEAIEHln.jpg
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 28ms/step
# GXH9LtKbEAIWaYG.jpg
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 26ms/step
# GXH9LG4bEAEoB04.jpg
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 27ms/step
# GXH8oM2bEAAHWfs.jpg
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 28ms/step
# GXHAwphbEAIBIGh.jpg
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 33ms/step
# GXH8NPpbkAA5fMt.jpg
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 33ms/step
# GXH8IbtaEAA_E9A.jpg
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 29ms/step
# GXH8HHqbEAYCZtx.jpg
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 31ms/step
# GXH8FhMasAAVttm.jpg
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 32ms/step
# GXH7spmbEAIkgA2.jpg
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 29ms/step
# GXH7am0bEAQDVkH.jpg
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 28ms/step
# GXH7ZKgbEAQ8GXK.jpg
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 26ms/step
# GXH7YtqbEAYL_7E.jpg
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 29ms/step
# GXH7WdtacAAohG7.jpg
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 27ms/step
# GXH611qbEAE_zn7.jpg
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 29ms/step
# GXH60MObEAQkeC_.jpg
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 26ms/step
# GXH6yj8bEAYZ_ZJ.jpg
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 26ms/step
# GXH5qMjaQAAIGM0.jpg
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 24ms/step
# GXH4tNmasAADuII.jpg
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 21ms/step
# GXH4_JWboAA1tUp.jpg
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 33ms/step
# GXH3QoAbEAI9hJX.jpg
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step
# GXH1B83bEAMcKtT.jpg
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 19ms/step
# GXH05bRbEAQF37G.jpg
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 25ms/step
# GXH0M99aUAAyvzE.jpg
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step
# GXHyrHJaQAAR04b.jpg
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 25ms/step
# GXHyf38aEAAiG6a.jpg
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 30ms/step
# GXHyg9IbEAIvL59.jpg
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 24ms/step
# GXHyY69bEAQE3po.jpg
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 25ms/step
# GXHyOejbgAAMZqA.jpg
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 26ms/step
# GXHyQ7YbQAA2NLD.jpg
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step
# GXHyJNwbcAA04jZ.jpg
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 22ms/step
# GXHyBObbEAEFlc-.jpg
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 22ms/step
# GXHx3RobEAMO3tj.jpg
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step
# GXHx5YGbEAYVZuv.jpg
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 28ms/step
# GXHx0b-bEAIb_EL.jpg
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step
# GXHxxLDbYAANFeK.jpg
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 26ms/step
# GXHxT02bEAE0VME.jpg
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step
# GXHxBggbEAUTAdl.jpg
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step
# GXHwvOabEAQFIha.jpg
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 21ms/step
# GXHwWIkasAApyY7.jpg
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 21ms/step
# GXHu7TYbwAAOTq4.jpg
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 19ms/step
# GXHuMhkbEAUDRw2.jpg
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 21ms/step
# GXHt7YubMAApYTb.jpg
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step
# GXHtCxabEAokXOf.jpg
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 29ms/step
# GXHs34zbEAQg4DD.jpg
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 22ms/step
# GXHs4qSbEAEcaBJ.jpg
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 21ms/step
# GXHs0yLbEAMO_vj.jpg
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 24ms/step
# GXHsrlIbEAEJEux.jpg
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 23ms/step
# GXHHWZuasAAyYnq.jpg
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step
# GXHoNbsbEAUTVEY.jpg
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 19ms/step
# GXHkuMLbgAA4xPY.jpg
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 19ms/step
# GXHj2JQbEAYfq1V.jpg
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 19ms/step
# GXHjKSHbEAMAa4I.jpg
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 19ms/step
# GXHi6-7bEAc1yqr.jpg
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 37ms/step
# GXHgB04bEBsKSdl.jpg
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 21ms/step
# GXHf5JHaIAAPxer.jpg
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 22ms/step
# GXHfC4SaQAA5Gqs.jpg
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 22ms/step
# GXHe_Y_bEAItf0Y.jpg
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 27ms/step
# GXHej96aEAAyVWU.jpg
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step
# GXHbx2bbEAI8oNM.jpg
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 28ms/step
# GXHbcPQbEAIcOLh.jpg
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 26ms/step
# GXHbbCtbEAMQnCH.jpg
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 21ms/step
# GXHbObxbEAIiv6g.jpg
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 21ms/step
# GXHa6cAbEAEGKOL.jpg
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step
# GXHaey_bEAIAVqR.jpg
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step
# GXHYsPNbkAAQa3t.jpg
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 21ms/step
# GXHWx6_aEAAcmky.jpg
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 21ms/step
# GXHWfbQaEAAQmlx.jpg
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 21ms/step
# GXHWe_mbMAAqMIp.png
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 21ms/step
# GXHWdrlagAASLbk.png
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step
# GXHSI-PbEAMqsIt.jpg
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step
# GXHQm-VbEAIqiuQ.jpg
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 22ms/step
# GXHNifObEAE69VH.jpg
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 19ms/step
# GXHNfXcbEAEpsOa.jpg
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 19ms/step
# GXHKmj_bEAUPDPn.jpg
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 19ms/step
# GXHE9iMbEAYNYVR.jpg
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 18ms/step
# GXHEx3IbEAIJfQf.jpg
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 18ms/step
# GXHDT-JbEAgNZMX.jpg
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 19ms/step
# GXHDSM4bEAIrh6P.jpg
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 19ms/step
# GXHAP_xbEAIWkGP.jpg
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 19ms/step
# GXG_GEHaAAAW4-o.jpg
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 23ms/step
# GXG9wvGbEAY1kdD.jpg
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 19ms/step
# GXG8RbbbEAEceD9.jpg
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 19ms/step
# GXGCGhCboAAjtFr.jpg
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step
# GXG39vybEAMPYr_.jpg
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 19ms/step
# GXGxSr-bUAAiw8y.jpg
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 19ms/step
# GXGu9-IbEAQkp-7.jpg
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 21ms/step
# GXGuoeTbEAMHGO5.jpg
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 21ms/step
# GXGuSkpbsAAe8CG.jpg
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 26ms/step
# GXGtFbgbEAE8DRI.jpg
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 22ms/step
# GXGrI9UbEAMQUiq.jpg
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 22ms/step
# GXGpqMtbEAEwrGm.jpg
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step
# GXGpT04bEAU1KUN.jpg
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step
# GXGpI-0bEAE_JtN.jpg
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 25ms/step
# GXGozCJbEAAqwlf.jpg
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 23ms/step
# GXGoMCybEAA7Zxc.jpg
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 19ms/step
# GXGk9WcWUAA3til.jpg
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 21ms/step
# GXGkiImWoAAqVPR.jpg
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 22ms/step
# GXGj35pbEAEa9WL.jpg
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step
# GXGjhFCbEAIuiX9.jpg
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 27ms/step
# GXGivczb0AAWFmG.jpg
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 19ms/step
# GXGgRnHaoAAyG79.jpg
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 22ms/step
# GXGfT7ebEAA6vYF.jpg
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 21ms/step
# GXGegNBbEAAMo4P.jpg
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 22ms/step
# GXGecYubEAMgw-y.jpg
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step
# GXGecOFbEAApwYx.jpg
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 21ms/step
# GXGdzmRbEAEBrw2.jpg
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 22ms/step
# GXGdxL6bcAARSmT.jpg
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step
# GXGb8u2bEAEqDmB.jpg
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 29ms/step
# GXGa4bxasAA2Psm.jpg
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 23ms/step
# GXGY_ieb0AAp5Cl.jpg
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 21ms/step
# GXGYnlWbEAQVtoy.jpg
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step
# GXGYXjDbEAAEfH-.jpg
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step
# GXGYZzZbEAEUwJ8.jpg
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 21ms/step
# GXGX2sabEAEvy6c.jpg
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 26ms/step
# GXGXMQ3bEAALGAY.jpg
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 22ms/step
# GXGWl0HaEAAIySC.jpg
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step
# GXGUwDtbEAAcPXz.jpg
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 21ms/step
# GXGTNomboAAIHGf.jpg
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 22ms/step
# GXGSGCrbIAAUqB3.jpg
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 21ms/step
# GXGPr5XbEAAPJyi.jpg
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 25ms/step
# GXGOvwAbEAE73JZ.jpg
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step
# GXGOqFgbMAAtcEI.jpg
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 21ms/step
# GXGOpJnbEAMkyeP.jpg
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step
# GXGMgWCbEAE282w.jpg
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 19ms/step
# GXGL9ZXbEAAfCsr.jpg
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 23ms/step
# GXGL3qNbEAMOkzS.jpg
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 27ms/step
# GXGLUbBbEAA47F2.jpg
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 21ms/step
# GXGLDeBa8AA79lB.jpg
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step
# GXGK88LbgAAQwZK.jpg
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 24ms/step
# GXGKHF_bEAEROKw.jpg
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 28ms/step
# GXGJzwvbEAIs2Kq.jpg
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step
# GXGJo4DbEAAeTAL.jpg
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 25ms/step
# GXGHX1KbkAAMDAe.jpg
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 22ms/step
# GXGHMSPbEAAJp0A.jpg
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 23ms/step
# ...
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step
# GW362_Za8AQapT_.jpg
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step
# GW36xtUW4AA3udx.jpg
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step
# GW36mx3WkAA5Ota.jpg
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step
# GW36U1ia8AMRG9m.jpg
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 19ms/step
# GW36TcEXAAAxd-s.jpg
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step
# GW355cVa8AI4rK9.jpg
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 19ms/step
# GW354-2X0AMNZs2.jpg
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step
# GW35x8FW8AAFm0I.jpg
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 19ms/step
# GW35HhhW8AA5tm8.jpg
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 19ms/step
# GW35BelXUAA0WBc.jpg
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step
# GW35AZIbMAAtRKp.jpg
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step
# GW34DAcXEAAGUqf.jpg
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step
# GW34GjfWEAE5Ohs.jpg
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step
# GW34EhSXUAAGhgx.jpg
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 19ms/step
# GW333Fca8AgiL9f.jpg
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 19ms/step
# GW33wnCa8AMnJI7.jpg
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 19ms/step
# GW33YEEa8AE8856.jpg
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 19ms/step
# GW32XQbXIAA0k6k.jpg
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 19ms/step
# GW32GP7WsAAoFlF.jpg
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 19ms/step
# GW3xtPxWIAAAM55.jpg
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 19ms/step
# GW3oFHvb0AA1JCX.jpg
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 19ms/step
# GW3eDtsXIAAOVnS.jpg
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 19ms/step
# GW3avyna8AEY4xu.jpg
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step
# GW3IbScWgAA-wu7.jpg
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 19ms/step
# GW3E7Xia8AAAdoB.jpg
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step
# GW3E2SRbUAAwgt2.jpg
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step
# GW3EzybXwAE2vzd.jpg
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step
# GW3ErKTa8AQCj9F.jpg
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step
# GW29ZSaX0AAYl-n.jpg
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step
# GW28ccrWMAAH-bQ.jpg
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step
# GW25Z3TXQAAi4Hl.jpg
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 19ms/step
# GW25hDkXwAAZgtE.jpg
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step
# GW24t-ka8AACkyQ.jpg
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 19ms/step
# GW24IdZa8AQccFt.jpg
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 19ms/step
# GW23m4Ma8AA1qU2.jpg
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step
# GW2zW-1a8AAfLTk.jpg
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step
# GW2zP4VX0AEto-N.jpg
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step
# GW2y1QeXMAEfj-o.jpg
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 19ms/step
# GW2yoQOaYAAe2Dz.jpg
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step
# GW2yWj1a4AAKc0x.jpg
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step
# GW2xR-BaYAAeDUY.jpg
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step
# GWxASN8XYAAb8Of.jpg
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step
# GW2dhgEWMAAVR0P.jpg
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step
# GW2ddCZbUAAwOT3.jpg
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step
# GW2dDBzWYAAG9Q9.jpg
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 19ms/step
# GW2cX3LXcAELqvY.jpg
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 19ms/step
# GW2Wy34a8AAZaG_.jpg
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step
# GW2S7vtXUAA48Y3.jpg
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 21ms/step
# GW2PBDYWkAAsRDz.jpg
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 19ms/step
# GW2IWb0agAAfV2t.jpg
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step
# GW2GW4sasAAX3B-.jpg
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 19ms/step
# GW2F140akAARsKk.jpg
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step
# GW2DtpiaUAAwP4j.jpg
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step
# GW15h_9XYAEnj83.jpg
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step
# GW15O-bagAAryXc.jpg
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step
# GW12YB4WIAAIZqj.jpg
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step
# GW109gya0AAcL4f.jpg
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 19ms/step
# GW1xvs2bQAAXRMa.png
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 19ms/step
# GW1vLuLa8AAnVWg.jpg
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 21ms/step
# GW1qSpLXIAEycfv.jpg
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step
# GW1o_IibQAAQVmh.jpg
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step
# GW1DFzrWUAASEUZ.jpg
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step
# GW09Wx1XcAAan6h.jpg
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 19ms/step
# GW00rKsa8AAonVk.jpg
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step
# GW00jbnagAAFvFY.jpg
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step
# GWzsA47a0AApZlO.jpg
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 19ms/step
# GWzeYcqawAAPaQt.jpg
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 19ms/step
# GWzeHduWUAAgMtE.jpg
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 19ms/step
# GWzdNe3bkAAcKA_.jpg
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 19ms/step
# GWzcTfVaMAA6cPi.jpg
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 18ms/step
# GWzaQ0mXkAA-uvX.jpg
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 19ms/step
# GWzV_iyXYAENxoI.jpg
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step
# GWzJU6yaMAAoO8m.jpg
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step
# GWzJDw6bgAANklv.jpg
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step
# GWy8Gq0bEAAWyu-.jpg
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step
# GWyujOZboAA8prA.jpg
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 19ms/step
# GWytY27WMAAVktN.jpg
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 19ms/step
# GWyoqNTawAAPDyr.jpg
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 19ms/step
# GWynyTuakAAh-Fc.jpg
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 19ms/step
# GWymc9FbUAAkldd.jpg
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 19ms/step
# GWylHZcbEAAha0W.jpg
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 19ms/step
# GWylEHfaMAEGpUh.jpg
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step
# GWyk1SQWsAAc05l.jpg
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step
# GWykm6zXgAAEPLe.jpg
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step
# GWykNq9W8AArV30.jpg
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step
# GWyXx6GXEAAadNI.jpg
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step
# GWyU_BeW4AAGk9R.jpg
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step
# GWyTxyRXgAEbhhi.jpg
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step
# GWyRx8VXUAAAxoB.jpg
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 19ms/step
# GWyQ3DlaIAEbVgj.jpg
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 19ms/step
# GWyOfgwbwAAwodB.jpg
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 19ms/step
# GWyOdt4WAAAX-4x.jpg
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step
# GWyNsU1aMAA75Bw.jpg
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 19ms/step
# GWyNGjyWAAEqqus.jpg
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step
# GWyIDv-WgAA0-0m.jpg
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step
# GWx3rwHXkAA0f3t.jpg
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step
# GWx0VoOWwAAh2jn.jpg
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step
# GWxxkdZbYAA5AR-.jpg
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step
# GWxptnCXEAAyS3v.jpg
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step
# GWxkBnjWMAApDyq.jpg
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step
# GWxghIZb0AAfO9-.jpg
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 19ms/step
# GWxefIjWEAA4KTq.jpg
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 19ms/step
# GWxehYSa8AEMcF5.jpg
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 19ms/step
# GWxdWFwX0AAty_U.jpg
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 19ms/step
# GWxZoPpWMAArKFD.jpg
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step
# GWxXYL9XEAAsEft.jpg
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step
# GWxXPGRaMAAt_6G.jpg
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step
# GWxPNN1WkAA88AZ.jpg
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step
# GWxPfhna8AQ-ph5.jpg
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step
# GWxO2mhaoAAd74C.jpg
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 21ms/step
# GWxIH2sbwAA8YgA.jpg
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 21ms/step
# GWxF2a1a8AAWdFj.jpg
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step
# GWxFk9PWcAA0uxv.jpg
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 19ms/step
# GWxFduzaUAAsT3t.jpg
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 19ms/step
# GWxEPfWa8AIP6HC.jpg
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step
# GWxDnWtWAAAF94G.jpg
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 19ms/step
# GWxDaqCbwAAAD9h.jpg
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 19ms/step
# GWxDMGTa8AMeSJq.jpg
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 19ms/step
# GWxCsGAa8AQyFKy.jpg
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 19ms/step
# GWxA2_GXsAAQODT.jpg
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step
# GWw-96Ua8AIR4rf.jpg
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step
# GWw8n_Ja8AI5u3e.jpg
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 21ms/step
# GWw8T-qWcAAUEoU.jpg
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step
# GWw7mM6WsAAVCkX.jpg
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 19ms/step
# GWw6NmoXgAABIWQ.jpg
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 19ms/step
# GWw1UIDbsAAKVYy.jpg
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 19ms/step
# GWwoNmvawAADghT.jpg
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 19ms/step
# GWwoKtPXwAAd-er.jpg
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step
# GWwn5h0boAAGz_S.jpg
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 19ms/step
# GWwmK7aa8AIjfEu.jpg
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step
# GWwmFRNXwAAg6Xo.jpg
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step
# GWwkBgOWEAA6X59.jpg
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step
# GWwjvsBW0AAf3Nd.jpg
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step
# GWwjJ-2agAAwPIu.jpg
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step
# GWwi2MDWYAIh_lT.jpg
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 19ms/step
# GWwiv_KbAAAfg8E.jpg
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 19ms/step
# GWwiHAIa8AMTy5q.jpg
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step
# GWwh0nkW4AAhXyw.jpg
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step
# GWwhN48a8Ac_OMb.jpg
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step
# GWwhCNNXcAAT-Qy.jpg
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 19ms/step
# GWwgtQvWsAEPulN.jpg
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 19ms/step
# GWwgarlWEAANNRa.jpg
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 22ms/step
# GWwgGx_WIAAkdlr.jpg
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 24ms/step
# GWwf4oFa8AENMMe.jpg
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 29ms/step
# GWwfkQJbAAAWCWv.jpg
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 24ms/step
# GWwfC7easAApk_6.jpg
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 22ms/step
# GWwepgvWwAAn4C_.jpg
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 22ms/step
# GWweW-nW4AAXoab.jpg
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 22ms/step
# GWwXX-ya8AIV9L4.jpg
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 22ms/step
# GWwXUvcbgAAMmFn.jpg
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step
# GWwWu9Ba8AA0Wxa.jpg
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 21ms/step
# GWup6cUa8AI4hjr.jpg
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 21ms/step
# GXPQprMbgAAZ_3O.jpg
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 22ms/step
# GXPQSc0bYAAFxT-.jpg
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step
# GXPQRz6aYAA9O7S.jpg
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 52ms/step
# GXPQPSFbAAALDA4.jpg
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 21ms/step
# GXPKxSdbgAI_Y42.jpg
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 24ms/step
# GXPFWkbaAAAAVrP.jpg
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 19ms/step
# GXPC7nobEAAnZZa.jpg
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step
# GXO57qlbEAA0L1p.jpg
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step
# GXO4RpsbgAEkc1e.jpg
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step
# GXO0xiGaQAAV6L5.jpg
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 19ms/step
# GXO0r-YaMAAokcH.jpg
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 19ms/step
# GXO0nc_asAAIS3h.jpg
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 19ms/step
# GXKxiA7bcAAEGHZ.jpg
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 19ms/step
# GXPUi8TbgAEYzxO.jpg
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step
# GXPUfwTaIAAnWxd.jpg
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step
# GXPZjn3a0AAhMEp.jpg
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 21ms/step
# GXPYcVEbgAM2dLt.jpg
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step
# GXPYKa-bgAAE_Y9.jpg
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 19ms/step
# GXPYAj5bEAA8Ki7.jpg
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step
# GXPXfaLbcAA2Dbo.jpg
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step
# GXPXOogaYAAtZd5.jpg
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step
# GXPXL85bgAAP46F.jpg
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step
# GXPViBBbQAA1dbn.jpg
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 19ms/step
# GXPVS5hbgAAj6zl.jpg
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 19ms/step
# GXPVTP1acAA_8LJ.jpg
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step
# GXPUrjsbMAAGARM.jpg
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 19ms/step
# GXPUammbgAEXHnY.jpg
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 21ms/step
# GXP19_5boAAW3tV.jpg
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step
# GXP1sInbAAAxMis.jpg
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step
# GXP1p-8bgAI0YwP.jpg
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 19ms/step
# GXP1jZGbgAEvK8I.jpg
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 19ms/step
# GXP1datbgAUtyDh.jpg
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 21ms/step
# GXP1dBpbgAMhvdb.jpg
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 19ms/step
# GXP0v8VbcAAvSVB.jpg
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 19ms/step
# GXP0n4ObgAA2cxb.jpg
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 19ms/step
# GXP0paibkAA5eQS.jpg
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step
# GXP0oHnaYAADk97.jpg
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 19ms/step
# GXP0VE1aQAAk5-q.jpg
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step
# GXP0L0Ua0AAMPv7.jpg
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step
# GXP0Ev6aUAAtyEq.jpg
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 21ms/step
# GXP0EU8bgAI9ypi.jpg
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 19ms/step
# GXPz_GvakAAzQVt.jpg
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step
# GXPz_u8bgAEF_sw.jpg
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step
# GXPz7rIbgAQpZed.jpg
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step
# GXPz3XObcAAm7o_.jpg
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 21ms/step
# GXPz1E7aUAAF173.jpg
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 19ms/step
# GXPzzaDbgAEQiKI.jpg
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 19ms/step
# GXPzm65aAAAX9zO.jpg
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step
# GXPzgSzbgAER_5l.jpg
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 19ms/step
# GXPzfiAbkAAcjWs.jpg
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 19ms/step
# GXPzevGaAAAnFJ6.jpg
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step
# GXPzd6abQAAqyE0.jpg
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 98ms/step
# GXPzdNQbgAEnond.jpg
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 81ms/step
# GXPzcb5a8AA1kEj.jpg
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 91ms/step
# GXPzbpSbgAUYsuh.jpg
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 53ms/step
# GXPza2fbwAAgSDy.jpg
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 38ms/step
# GXPzaETbcAASvdj.jpg
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 75ms/step
# GXPzZPwakAAIlq9.jpg
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 89ms/step
# GXPzYX_bQAAkRW5.jpg
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 46ms/step
# GXPzXn4bgAA4y8B.jpg
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 75ms/step
# GXPzW1SbkAAtaD1.jpg
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 29ms/step
# GXPzWETaQAAu2O2.jpg
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 80ms/step
# GXPzVLhbgAAuWQS.jpg
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 34ms/step
# GXPzM_PbUAA-50v.jpg
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 21ms/step
# GXPzMQwa8AA1EOr.jpg
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 25ms/step
# GXPzLeYaAAA8k_U.jpg
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 69ms/step
# GXPzKrYbgAASAYh.jpg
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 36ms/step
# GXPzJ-TbgAAGkbi.jpg
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 29ms/step
# GXPyZFpagAAVHEh.jpg
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 35ms/step
# GXPyWznbgAIJ69a.jpg
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 34ms/step
# GXPyKn5agAAP_u4.jpg
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 38ms/step
# GXPx8oLa0AAvA6q.jpg
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 56ms/step
# GXPx1t8bcAA4qnO.jpg
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 84ms/step
# GW7POt0WAAAqqT1.jpg
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 60ms/step
# GXEhEZUbcAANiF_.jpg
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 84ms/step
# GXEfp5SaoAAlMTW.jpg
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 31ms/step
# GXGGZZgbEAIuQ3r.jpg
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 32ms/step
# GXGWmBIbEAYnZei.jpg
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 29ms/step
# GXGGnCibEAAGPmX.jpg
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 26ms/step
# GXFjN9RbEAUe015.jpg
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 29ms/step
# GWwjVKwbAAA-i8z.jpg
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 29ms/step
# GW3eXMmWgAAGNMO.jpg
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 21ms/step
# GW2_6kkaEAAF_OP.jpg
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 21ms/step
# GW29OszXkAA1I-L.jpg
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 23ms/step
# GW28x4Ra8AI6u7p.jpg
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 21ms/step
# GW28B8XasAAd26T.jpg
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step
# GW27zFsXwAADCTp.jpg
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 22ms/step
# GW26aCnXMAE9ZE9.jpg
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 22ms/step
# GW26WgbbsAAvDVk.jpg
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 21ms/step
# GW26TeMbIAASS1c.jpg
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 22ms/step
# GW26AbBa8AE0m9q.jpg
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 22ms/step
# GW25vAUa8AEgc-J.jpg
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 21ms/step
# GW25rk_WMAA9Y2L.jpg
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 21ms/step
# GW25nG4W8AA2gDU.jpg
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 22ms/step
# GW25FowWMAA5YFV.jpg
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 21ms/step
# GW25VgXXcAA4G1Y.jpg
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 22ms/step
# GW25Mr5a8AErn5X.jpg
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 23ms/step
# GW25ItoW8AEaL1x.jpg
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 21ms/step
# GW23gMDa8AQSW5Z.jpg
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 24ms/step
# GW24kfgbIAA-Nst.jpg
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 21ms/step
# GW24VKUa8AMDo-u.jpg
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 23ms/step
# GW9oXo2bEAA1fDS.jpg
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 22ms/step
# GW_iGgZbEAAn1gz.jpg
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 24ms/step
# GW9JT_WaMAAlqia.jpg
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 21ms/step
# GW8VId_bQAAb24K.jpg
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 22ms/step
# GW8Q3hLakAA0nE3.jpg
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 23ms/step
# GW8NFC7aUAArLeP.jpg
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 22ms/step
# GW8MlUFbgAAA2JZ.jpg
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 29ms/step
# GW75wrsa8AEN9Nk.jpg
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 28ms/step
# GW71a0ea8AAZD9R.jpg
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 28ms/step
# GW7telvbkAAQ7Si.jpg
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 25ms/step
# GW7jLstagAAkJL-.jpg
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 23ms/step
# GW7huQdaQAA-l_U.jpg
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 22ms/step
# GW38tvxXcAAj_Qj.jpg
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 22ms/step
# GW35MEaa8AQuub7.jpg
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 21ms/step
# GW3QE45XUAAOKi2.jpg
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step
# GW3PNSdXIAAfali.jpg
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step
# GW3NCOca8AMnjlD.jpg
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step
# GW2_ZbfXsAACx6J.jpg
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step
# GW260kZXkAAYN63.jpg
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 21ms/step
# GW26VV1WsAATdAQ.jpg
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 39ms/step
# GW2uXVeWcAA6TlX.jpg
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 19ms/step
# GW2dMM_a8AEBYbo.jpg
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step

# %%
import psycopg2
from tqdm.notebook import tqdm

# Database connection configuration
DB_CONFIG = {
    'dbname': 'medols',
    'user': 'postgres',
    'password': 'FEWcTB3JIX5gK4T06c1MdkM9N2S8w9pb',
    'host': '128.1.227.35',
    'port': '5432'
}

def connect_db():
    return psycopg2.connect(**DB_CONFIG)

def run_insert_statements(monitoring_id):
    # Delete existing records for this monitoring_id
    delete_query = f"DELETE FROM social_media_activity WHERE monitoring_id_platform_data = '{monitoring_id}';"
    
    queries = [
        # Insert from vw_monitoring_facebook
        f"""
        INSERT INTO social_media_activity (
        monitoring_id_platform_data, name, description, created_date_platform_data,
        post_date, user_id_platform_data, profile_id, likes_count, shares_count,
        views_count, comment_count, sentiment_id, sentiment_category, sentiment_score,
        post_url, profile_url, cluster_no, cluster_score, pca_1, pca_2,
        iskol, img_cluster_no, img_pca_1, img_pca_2, img_cluster_score,
        table_name_platform_data, image_filename, following_count, follower_count, 
        subscriber_count, fullname  )
        SELECT monitoring_id, name, description, created_date, post_date,
        user_id, profile_id, likes_count, shares_count, views_count,
        comment_count, sentiment_id, sentiment_category, score AS sentiment_score,
        post_url, profile_url, cluster_no, cluster_score, pca_1, pca_2, iskol,
        img_cluster_no, img_pca_1, img_pca_2, img_cluster_score, 'vw_monitoring_facebook', filename,
        following_count, follower_count, friend_count, fullname
        FROM vw_monitoring_facebook
        WHERE monitoring_id = '{monitoring_id}';
        """,
        
        # Insert from vw_monitoring_google
        f"""
        INSERT INTO social_media_activity (
        monitoring_id_platform_data, source, description, created_date_platform_data,
        publish_date, updated_date_platform_data, link_url, content,
        title_platform_data, sentiment_category, sentiment_score, sentiment_id,
        cluster_no, cluster_score, pca_1, pca_2, img_cluster_no,
        img_cluster_score, img_pca_1, img_pca_2, table_name_platform_data)
        SELECT monitoring_id, source, description, created_date,
        publish_date, updated_date, link, content, title,
        sentiment_category, score AS sentiment_score, sentiment_id,
        cluster_no, cluster_score, pca_1, pca_2,
        img_cluster_no, img_cluster_score, img_pca_1,
        img_pca_2, 'vw_monitoring_google' AS table_name_platform_data
        FROM vw_monitoring_google
        WHERE monitoring_id = '{monitoring_id}';
        """,
        
        # Insert from vw_monitoring_instagram
        f"""
        INSERT INTO social_media_activity (
        instagram_post_id, link_url, post_content, publish_date,
        like_count, shares_count, comment_count, created_date_platform_data,
        monitoring_id_platform_data, profile_id, fullname,
        username_platform_data, is_tc_completed, post_exclude,
        sentiment_id, sentiment_category, sentiment_score, cluster_no,
        cluster_score, pca_1, pca_2, iskol, img_cluster_no,
        img_cluster_score, img_pca_1, img_pca_2, table_name_platform_data)
        SELECT instagram_post_id, link_url, post_content, publish_date,
        like_count, shared_count AS shares_count, comment_count,
        created_date, monitoring_id, profile_id, fullname,
        username, is_tc_completed, post_exclude, sentiment_id,
        sentiment_category, sentiment_score, cluster_no, cluster_score,
        pca_1, pca_2, iskol,img_cluster_no, img_cluster_score,
        img_pca_1, img_pca_2, 'vw_monitoring_instagram'
        FROM vw_monitoring_instagram
        WHERE monitoring_id = '{monitoring_id}';
        """,
        
        # Insert from vw_monitoring_tiktok
        f"""
        INSERT INTO social_media_activity (
        tiktok_id, monitoring_id_platform_data,create_time, description,
        is_polri, tiktok_created_date, tiktok_updated_date, nickname,
        unique_id, comment_count, digg_count, play_count, share_count,
        sentiment_category, sentiment_score, sentiment_id, follower_count,
        following_count, heart_count, video_count, cluster_no, cluster_score,
        pca_1, pca_2, iskol, img_cluster_no,
        img_pca_1, img_pca_2, img_cluster_score, table_name_platform_data,
        image_filename)
        SELECT tiktok_id, monitoring_id, create_time, "desc" AS description,
        is_polri, tiktok_created_date, tiktok_updated_date,
        nickname, unique_id, comment_count, digg_count,
        play_count, share_count, sentiment_category, score AS sentiment_score,
        id AS sentiment_id, follower_count, following_count, heart_count,
        video_count, cluster_no, cluster_score, pca_1, pca_2,
        iskol, img_cluster_no, img_pca_1, img_pca_2,
        img_cluster_score, 'vw_monitoring_tiktok', filename
        FROM vw_monitoring_tiktok
        WHERE monitoring_id = '{monitoring_id}';
        """,
        
        # Insert from vw_monitoring_twitter
        f"""
        INSERT INTO social_media_activity (
        twitter_tweets_id, monitoring_id_platform_data, user_id_platform_data, date,
        time,timezone,screen_name,name,is_polri,is_tc_completed,original_tweet,
        tweet,replies_count,likes_count,retweets_count,view_count,follower_count,
        sentiment_category,sentiment_score,sentiment_id,cluster_no,cluster_score,
        pca_1,pca_2,iskol,img_cluster_no,img_pca_1,img_pca_2, img_cluster_score,
        table_name_platform_data, image_filename )
        SELECT twitter_tweets_id, monitoring_id, user_id, date, time,
        timezone, screen_name, name, is_polri, is_tc_completed, original_tweet,
        tweet, replies_count, likes_count, retweets_count, view_count,
        follower_count, sentiment_category, score AS sentiment_score, sentiment_id,
        cluster_no, cluster_score, pca_1, pca_2, iskol, img_cluster_no,
        img_pca_1, img_pca_2, img_cluster_score, 'vw_monitoring_twitter', filename
        FROM vw_monitoring_twitter
        WHERE monitoring_id = '{monitoring_id}';
        """,
        
        # Insert from vw_monitoring_youtube
        f"""
        INSERT INTO social_media_activity (
        id_platform_data, monitoring_id_platform_data, channel_id, title_platform_data,
        description, channel_name, published_date, publish_time, created_date_platform_data,
        view_count, like_count, favorite_count, comment_count, sentiment_id,
        sentiment_category, sentiment_score, cluster_no, cluster_score,
        pca_1, pca_2, subscriber_count, video_count, channel_created_date,
        iskol,img_cluster_no,img_pca_1, img_pca_2, img_cluster_score, 
        table_name_platform_data)
        SELECT id, monitoring_id, channel_id, title, description, channel_name,
        published_date, publish_time, created_date, view_count, like_count,
        favorite_count, comment_count, sentiment_id, sentiment_category,
        score AS sentiment_score, cluster_no, cluster_score, pca_1,
        pca_2, subscriber_count, video_count, channel_created_date,
        iskol, img_cluster_no, img_pca_1, img_pca_2, img_cluster_score, 
        'vw_monitoring_youtube'
        FROM vw_monitoring_youtube
        WHERE monitoring_id = '{monitoring_id}';
        """
    ]

    rows_affected = []

    try:
        conn = connect_db()
        with conn.cursor() as cur:
            # Execute delete query
            cur.execute(delete_query)
            print(f"Deleted existing records for monitoring_id: {monitoring_id}")
            
            for query in queries:
                cur.execute(query)
                rows_affected.append(cur.rowcount)
        conn.commit()
    except Exception as e:
        print(f"An error occurred: {e}")
        conn.rollback()
    finally:
        conn.close()

    return rows_affected

# Process key_monitoring_media_online if not null
if media_online_monitoring_id:
    print(f"Processing key_monitoring_media_online: {media_online_monitoring_id}")
    rows_inserted = run_insert_statements(media_online_monitoring_id)
    print(f"Rows affected for key_monitoring_media_online {media_online_monitoring_id}: {rows_inserted}")

# Process key_monitoring_media_social if not null
if social_media_monitoring_id:
    print(f"Processing key_monitoring_media_social: {social_media_monitoring_id}")
    rows_inserted = run_insert_statements(social_media_monitoring_id)
    print(f"Rows affected for key_monitoring_media_social {social_media_monitoring_id}: {rows_inserted}")

# %%
# Finishing Jobs
# Create Parameter Record
sql = "insert into ret_analysis_parameter (job_id, param_id, param_name, param_value) values (%s, %s, %s, %s)"
# Execute the query
data_connector.execute_query_psql(sql % (i_process_id, 1, "'#Content Processed'",iRowCount))

# Create Tweet Cluster Record
sql = "update ret_analysis_header set datetime_finish = NOW() where job_id = %s"
# Executing query
data_connector.execute_query_psql(sql % (i_process_id) )

sql = "update screen_analisis_ai set status = 3, duration = EXTRACT(EPOCH FROM (now() - start_process)), end_process = NOW() where id = %s"
data_connector.execute_query_psql(sql % (i_process_id))

print('inserting result finished')
