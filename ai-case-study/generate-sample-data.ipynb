# %%
import pandas as pd
import numpy as np
import psycopg2
from psycopg2.extensions import register_adapter, AsIs
import uuid

def insert_twitter_public_metrics(conn, monitoring_id):
    # Function to insert data into twitter_public_metrics table
    def insert_data(cur, monitoring_id, follower_count, following_count, tweet_count, listed_count, created_date):
        query = """
        INSERT INTO twitter_public_metrics (monitoring_id, followers_count, following_count, tweet_count, listed_count, created_date)
        VALUES ('%s', %s, %s, %s, %s, '%s')
        """ % (monitoring_id, follower_count, following_count, tweet_count, listed_count, created_date) 
        # print(query)
        cur.execute(query, (monitoring_id, follower_count, following_count, tweet_count, listed_count, created_date))

    # Generate data using pandas DataFrame
    start_date = '2024-02-01 00:00:00'
    end_date = '2024-02-29 23:59:59'
    timestamps = pd.date_range(start=start_date, end=end_date, freq='15T')
    # Simulate follower count with negative growth
    follower_changes = np.random.randint(-500, 1000, size=len(timestamps))
    follower_counts = np.maximum.accumulate(np.cumsum(follower_changes))
    following_counts = np.cumsum(np.random.randint(50, 500, size=len(timestamps)))
    tweet_counts = np.cumsum(np.random.randint(10, 100, size=len(timestamps)))
    listed_counts = np.cumsum(np.random.randint(5, 50, size=len(timestamps)))

    # Connect to the PostgreSQL database
    with conn.cursor() as cur:
        # Register UUID adapter to psycopg2
        register_adapter(uuid.UUID, lambda u: AsIs(str(u)))
        
        # Insert data into twitter_public_metrics table
        for i in range(len(timestamps)):
            created_date = timestamps[i]
            insert_data(cur, monitoring_id, follower_counts[i], following_counts[i], tweet_counts[i], listed_counts[i], created_date)
        conn.commit()

# Connect to the PostgreSQL database
conn = psycopg2.connect(
    host="98.98.117.105",
    database="medols",
    user="postgres",
    password="FEWcTB3JIX5gK4T06c1MdkM9N2S8w9pb"
)

# Define the list of monitoring IDs
monitoring_ids = ['6d677700-bc32-4d46-bf2e-0c0dfb8c651e',
'6ddeca92-1b85-4996-a418-7fffb4a75c58',
'6fc5670a-b099-4b55-9bd9-6f91172f92fd',
'8dbec388-4203-4609-8386-6bae7639eb03',
'9d19f6ba-6848-4652-a61e-c96df6b31171',
'9e915ea6-3b24-45f0-b815-2c7203d1b342',
'53c6f97a-0b19-4cd3-8078-5f7eb7a9a4cb',
'59a18943-aa28-4677-a267-b1b3e8c66629',
'81cab97d-2b2b-4e09-9af0-b756f80016cb',
'83a5fe00-d72f-426f-94a9-7efaf4753d7f',
'120b95f8-2b51-46e7-b41b-75ae5aeea972',
'2456da39-9cea-4fdd-97d4-2a3b7525b00b',
'3445a813-f1e1-437c-9b38-eed674f1a0a7',
'12334e38-6ccd-4432-9567-bcfdd434cae7',
'58518e95-6daa-48e8-8e49-ea30c601979d',
'291810ae-c970-4286-926c-fa2d11e4deab',
'0206758a-d692-4eca-b301-02d964adb419',
'5614011e-1008-4ea5-813f-67b4e504b44b',
'a3c8bfaf-9bce-48d3-9fcb-4611f4e5b92d',
'ad850dc6-ca9a-4e85-8b6e-fb31862db64e',
'b781a71c-df1c-47d3-bff8-c287e2f1131a',
'ca0c9e12-5272-4fa2-938c-0287d16d1278',
'd399cfae-b24c-458f-815b-d1d8ec3f1ca0',
'ec44dd26-e393-48c8-b576-066323f2966e']

# Iterate through the list of monitoring IDs and call the insert function
for monitoring_id in monitoring_ids:
    insert_twitter_public_metrics(conn, uuid.UUID(monitoring_id))

# Close the database connection
conn.close()


import pandas as pd
import numpy as np
import psycopg2
from psycopg2.extensions import register_adapter, AsIs
import uuid

def insert_tiktok_public_metrics(conn, monitoring_id):
    # Function to insert data into twitter_public_metrics table
    def insert_data(cur, monitoring_id, follower_count, following_count, video_count, friend_count, heart_count, digg_count, created_date):
        query = """
        INSERT INTO tiktok_public_metrics (monitoring_id, followers_count, following_count, video_count, friend_count, heart_count, digg_count, created_date)
        VALUES ('%s', %s, %s, %s, %s, %s, %s, '%s')
        """ % (monitoring_id, follower_count, following_count, video_count, friend_count, heart_count, digg_count, created_date)
        print(query)
        cur.execute(query, (monitoring_id, follower_count, following_count, video_count, friend_count, heart_count, digg_count, created_date))

    # Generate data using pandas DataFrame
    start_date = '2024-02-01 00:00:00'
    end_date = '2024-02-29 23:59:59'
    timestamps = pd.date_range(start=start_date, end=end_date, freq='15T')
    # Simulate follower count with negative growth
    follower_changes = np.random.randint(-500, 1000, size=len(timestamps))
    follower_counts = np.maximum.accumulate(np.cumsum(follower_changes))
    following_counts = np.cumsum(np.random.randint(1, 3, size=len(timestamps)))
    video_counts = np.cumsum(np.random.randint(10, 100, size=len(timestamps)))
    friend_counts = np.cumsum(np.random.randint(50, 100, size=len(timestamps)))
    heart_counts = np.cumsum(np.random.randint(1000, 50000, size=len(timestamps)))
    digg_counts = np.cumsum(np.random.randint(1, 10, size=len(timestamps)))

    # Connect to the PostgreSQL database
    with conn.cursor() as cur:
        # Register UUID adapter to psycopg2
        register_adapter(uuid.UUID, lambda u: AsIs(str(u)))
        
        # Insert data into twitter_public_metrics table
        for i in range(len(timestamps)):
            created_date = timestamps[i]
            insert_data(cur, monitoring_id, follower_counts[i], following_counts[i], video_counts[i], friend_counts[i], heart_counts[i], digg_counts[i], created_date)
        conn.commit()

# Connect to the PostgreSQL database
conn = psycopg2.connect(
    host="98.98.117.105",
    database="medols",
    user="postgres",
    password="FEWcTB3JIX5gK4T06c1MdkM9N2S8w9pb"
)

# Define the list of monitoring IDs
monitoring_ids = ['523905fb-44b6-484e-bafa-51cdbc468c93',
'c80ed9a4-9fcf-411c-92b4-45bc8d7c85e6',
'd502e238-81c0-4bf3-a3b6-6275e5e956ae',
'1e1c1dd5-9135-4148-aecb-cb6e255260ad',
'9d19f6ba-6848-4652-a61e-c96df6b31171',
'43453533-a0a4-41a4-b3d8-6d3f0dea32b6',
'3445a813-f1e1-437c-9b38-eed674f1a0a7',
'1fe16663-ffee-4481-b9e3-7b99558e8939',
'a90fbabe-b956-46c7-9680-a6e6331b6baa',
'3b27c3be-fedc-4de1-a6fb-c5a188ec1fd7',
'31008254-02c3-4a87-b78c-1f5c9f24dd10',
'e283e04b-31e8-44d8-803b-1c63d64ecbca',
'61a1b5d4-6f46-4e80-9235-4b09485721d4',
'6fc5670a-b099-4b55-9bd9-6f91172f92fd',
'8dbec388-4203-4609-8386-6bae7639eb03',
'9e915ea6-3b24-45f0-b815-2c7203d1b342',
'17e9f360-0cb4-42ef-ac76-114f5ef8a452',
'5047a1b2-7a42-4e07-9e92-667eb8c622ba',
'2f97e723-8792-48bc-be30-076642164b68',
'e1a994fe-ffbe-4906-b55f-fd0f0b54ecfd',
'805e95a2-45ec-4df8-baad-7e732f6d144a',
'7a9ebce0-0508-4e22-a9a0-045ac58f71ce',
'c84b5c41-aed1-44f3-8709-a4a2af3ee9e6',
'81cab97d-2b2b-4e09-9af0-b756f80016cb',
'ad850dc6-ca9a-4e85-8b6e-fb31862db64e',
'5abb3be8-bca8-408a-abb0-79c5cd839e80',
'e154ce76-3a69-488a-b31c-41a00d51a59d',
'0e697c6b-10a5-4446-8c7f-bc39decd126f',
'0bb1f845-9065-4fd4-8b67-012ffe994ee7',
'74e355f5-67cc-4d42-bda9-beaa0325e6ed',
'67fc31bb-c82b-406e-b3c1-82100c37eafb',
'67fa0c0a-38bd-4894-9f6c-e88f0eae84b5',
'4eace84b-6344-455e-91fb-bd398a04405d',
'7179ed91-a040-4e93-afb1-03b510eba7e6',
'd32d4b58-f12b-4a0a-95ea-e4fe9b9ee6da',
'12e6fc83-4dd5-4894-ae3a-e87a48104403',
'863e7254-153a-4201-a42e-1aecf6bd0f23',
'7524f9a3-d363-49e5-8b10-6373f19d8278',
'7783b76d-b249-4dc5-a110-d5b717ea7cee']

# Iterate through the list of monitoring IDs and call the insert function
for monitoring_id in monitoring_ids:
    insert_tiktok_public_metrics(conn, uuid.UUID(monitoring_id))

# Close the database connection
conn.close()

# %%
import pandas as pd
import numpy as np
import psycopg2
from psycopg2.extensions import register_adapter, AsIs
import uuid

def insert_twitter_public_metrics(conn, monitoring_id):
    # Function to insert data into twitter_public_metrics table
    def insert_data(cur, monitoring_id, follower_count, following_count, tweet_count, listed_count, created_date):
        query = """
        INSERT INTO twitter_public_metrics (monitoring_id, followers_count, following_count, tweet_count, listed_count, created_date)
        VALUES ('%s', %s, %s, %s, %s, '%s')
        """ % (monitoring_id, follower_count, following_count, tweet_count, listed_count, created_date) 
        # print(query)
        cur.execute(query, (monitoring_id, follower_count, following_count, tweet_count, listed_count, created_date))

    # Generate data using pandas DataFrame
    start_date = '2024-02-01 00:00:00'
    end_date = '2024-02-29 23:59:59'
    timestamps = pd.date_range(start=start_date, end=end_date, freq='15T')
    # Simulate follower count with negative growth
    follower_changes = np.random.randint(-500, 1000, size=len(timestamps))
    follower_counts = np.maximum.accumulate(np.cumsum(follower_changes))
    following_counts = np.cumsum(np.random.randint(50, 500, size=len(timestamps)))
    tweet_counts = np.cumsum(np.random.randint(10, 100, size=len(timestamps)))
    listed_counts = np.cumsum(np.random.randint(5, 50, size=len(timestamps)))

    # Connect to the PostgreSQL database
    with conn.cursor() as cur:
        # Register UUID adapter to psycopg2
        register_adapter(uuid.UUID, lambda u: AsIs(str(u)))
        
        # Insert data into twitter_public_metrics table
        for i in range(len(timestamps)):
            created_date = timestamps[i]
            insert_data(cur, monitoring_id, follower_counts[i], following_counts[i], tweet_counts[i], listed_counts[i], created_date)
        conn.commit()

# Connect to the PostgreSQL database
conn = psycopg2.connect(
    host="98.98.117.105",
    database="medols",
    user="postgres",
    password="FEWcTB3JIX5gK4T06c1MdkM9N2S8w9pb"
)

# Define the list of monitoring IDs
monitoring_ids = ['6d677700-bc32-4d46-bf2e-0c0dfb8c651e',
'6ddeca92-1b85-4996-a418-7fffb4a75c58',
'6fc5670a-b099-4b55-9bd9-6f91172f92fd',
'8dbec388-4203-4609-8386-6bae7639eb03',
'9d19f6ba-6848-4652-a61e-c96df6b31171',
'9e915ea6-3b24-45f0-b815-2c7203d1b342',
'53c6f97a-0b19-4cd3-8078-5f7eb7a9a4cb',
'59a18943-aa28-4677-a267-b1b3e8c66629',
'81cab97d-2b2b-4e09-9af0-b756f80016cb',
'83a5fe00-d72f-426f-94a9-7efaf4753d7f',
'120b95f8-2b51-46e7-b41b-75ae5aeea972',
'2456da39-9cea-4fdd-97d4-2a3b7525b00b',
'3445a813-f1e1-437c-9b38-eed674f1a0a7',
'12334e38-6ccd-4432-9567-bcfdd434cae7',
'58518e95-6daa-48e8-8e49-ea30c601979d',
'291810ae-c970-4286-926c-fa2d11e4deab',
'0206758a-d692-4eca-b301-02d964adb419',
'5614011e-1008-4ea5-813f-67b4e504b44b',
'a3c8bfaf-9bce-48d3-9fcb-4611f4e5b92d',
'ad850dc6-ca9a-4e85-8b6e-fb31862db64e',
'b781a71c-df1c-47d3-bff8-c287e2f1131a',
'ca0c9e12-5272-4fa2-938c-0287d16d1278',
'd399cfae-b24c-458f-815b-d1d8ec3f1ca0',
'ec44dd26-e393-48c8-b576-066323f2966e']

# Iterate through the list of monitoring IDs and call the insert function
for monitoring_id in monitoring_ids:
    insert_twitter_public_metrics(conn, uuid.UUID(monitoring_id))

# Close the database connection
conn.close()

# %%
import pandas as pd
import numpy as np
import psycopg2
from psycopg2.extensions import register_adapter, AsIs
import uuid

def insert_youtube_public_metrics(conn, monitoring_id):
    # Function to insert data into twitter_public_metrics table
    def insert_data(cur, monitoring_id, view_count, subscriber_count, video_count, created_date):
        query = """
        INSERT INTO youtube_public_metrics (monitoring_id, view_count, subscriber_count, video_count, created_date)
        VALUES ('%s', %s, %s ,%s, '%s')
        """ % (monitoring_id, view_count, subscriber_count, video_count, created_date)
        # print(query)
        cur.execute(query, (monitoring_id, view_count, subscriber_count, video_count, created_date))

    # Generate data using pandas DataFrame
    start_date = '2024-02-01 00:00:00'
    end_date = '2024-02-01 23:59:59'
    timestamps = pd.date_range(start=start_date, end=end_date, freq='15T')
    # Simulate follower count with negative growth
    follower_changes = np.random.randint(-500, 1000, size=len(timestamps))
    subscriber_counts = np.maximum.accumulate(np.cumsum(follower_changes))
    view_counts = np.cumsum(np.random.randint(1000, 100000, size=len(timestamps)))
    video_counts = np.cumsum(np.random.randint(1, 25, size=len(timestamps)))

    # Connect to the PostgreSQL database
    with conn.cursor() as cur:
        # Register UUID adapter to psycopg2
        register_adapter(uuid.UUID, lambda u: AsIs(str(u)))
        
        # Insert data into twitter_public_metrics table
        for i in range(len(timestamps)):
            created_date = timestamps[i]
            insert_data(cur, monitoring_id, view_counts[i], subscriber_counts[i], video_counts[i], created_date)
        conn.commit()

# Connect to the PostgreSQL database
conn = psycopg2.connect(
    host="98.98.117.105",
    database="medols",
    user="postgres",
    password="FEWcTB3JIX5gK4T06c1MdkM9N2S8w9pb"
)

# Define the list of monitoring IDs
monitoring_ids = ['eae9013b-900c-4486-a7aa-72cd3e353d66',
'603921d9-20fe-4261-8604-941a9afefaee',
'fb47aca7-8eb9-47ac-8039-5265b6cbd343',
'48dc1dee-91cf-4e79-898d-fda5c0ee4356',
'9d1850ee-7a21-4313-b850-faa7b45d0ea2',
'601010da-937d-4fef-9db3-625c55ea0a1a',
'2413a15e-7adf-4ced-ada7-32e58a9aa7ad',
'2319eaac-cbcd-4a0d-9433-bd7c028b86f5',
'2a0a21c9-a458-4d79-82ea-2144803b1309',
'1d8aa86e-a2ce-4f15-a022-218d79bddc57',
'6a2f4752-8a5a-498f-a78b-f96f6cbd6d4d',
'3cf2f24f-a467-4fe4-8aed-a3d5db1fb69c',
'51c681f4-9a7f-4ff6-a32c-d797014af7c0',
'2fd6bd06-6fee-4ad7-a38c-46d859772c4c',
'ffd4a089-9118-4b23-b9c2-bb1e0ebcc527',
'34ffb71f-e6ee-46eb-b67b-140f1e4926e6',
'7766e969-5047-411a-9349-0aa0f693b9fe',
'38b207e3-389f-40b1-a8bb-ff5d5ad4c588',
'03cc6da8-fac1-4517-90c1-66f273ec8800',
'0c961b4c-83bb-4b18-a038-64a88573d337',
'12306daf-ccc1-46e2-af00-e352e72fdf6d',
'5ba1dba8-7695-4ade-b129-e00fb7d82c79',
'7bfb1bcf-8d32-474d-957d-af22446824eb',
'b1d252fb-e9e4-40fa-b819-04c03ba6971f',
'e5eaf705-8209-4b6c-a13f-923e30eedaec',
'e770064f-558b-43eb-95e6-cb17335578dd',
'193538e2-776d-4f0c-852c-cdc333af9723',
'360d2eb1-d89f-47f0-98eb-e4a33c71731d',
'974b37df-0d01-4e58-9bc7-676793eefea2',
'c6f4a04d-8f8f-4b89-a9e0-b9ad5a12246c',
'90e10112-318e-4400-9404-03322dbbbf5a',
'4ad872bd-a90f-4533-a8a4-cd7589e5865f',
'3a4aa0b5-507d-4226-8ee0-c484667771c7',
'3881988b-e09e-424a-883b-7116ef233aca',
'1dfba198-6cb6-44fb-be89-27f7153dea1a',
'e4e2a108-09e6-4736-b95f-46c0c89e66c5',
'8f7193ed-4b49-4832-8ca1-5963ce38ebd7',
'fc77a861-ae3a-4bce-9b02-288961466284',
'13057aa3-e3f7-4255-9dd4-21c2893dfbfe',
'fce62dc9-e829-40a2-abb0-9d28ca90c17f',
'22147b9c-0c93-48e5-9ab9-fe454ac0dc39',
'e70d2aed-02ba-4a2b-bafb-c6a2a7b37a59',
'284274e2-82c2-42f7-aaa1-65c236ddb24b',
'588aa066-c227-4e1d-b52e-97e5ac9a2edc',
'599712a7-5293-42a7-8392-a0b20b253784',
'1f8006c6-b45c-42de-bf60-2f7eaac3e8d7',
'c08d1c18-59aa-4db2-94b8-268b82f3f5cf',
'44c068fa-1544-4490-9e9b-f804b2c33899',
'8aa62c7c-30b1-41e7-bf75-94db9ecbb3a3',
'52d4b50e-16f2-444f-92d2-bcb6a79d4950',
'da3e9e50-211c-4aec-90ca-d06c0177218f',
'33833a7c-cb98-40eb-9dcf-27071611054c',
'3b0cfa5a-b3d7-4015-aef6-3f3b8ac175e1',
'b88011b1-bb87-4da5-afd0-9325ba4ff546',
'a4f6b1e5-046e-43c3-80ef-9607255069d3',
'8bf38d8b-6dd7-477f-b568-f0ae316b181c',
'0e28792b-24e6-4c68-ab3f-d96d78330f21',
'f231b91d-e808-4754-9a08-3c91e96cee46',
'8b5a6ac7-e6c9-4408-9004-4e1e53d7cc33',
'9a2ea5a7-57b8-4a56-9e9f-d3d7749b3c92',
'ce060be7-66c1-41fa-9c72-ec914f164d26',
'bf255c94-5217-4849-acb0-ebf6dc2b5c56',
'fdeab4ca-b9d6-4d38-b12e-12f14a062ca0',
'a1c37203-3b7d-4829-b427-9b3595c975b0',
'4cfb2250-48d1-4bc9-9c80-317dbb66b406',
'1e70d7f9-6955-485a-9357-8688d0209ebd',
'26132fdd-052a-42a6-9b16-5f1cb419eb1b',
'0827b67e-d517-4a19-bf73-3dfd5f454864',
'b75da47f-5c3d-49a9-bb32-7e0de836dce0',
'56af658a-6486-4cbc-b28d-586c78213fe0',
'57a7243d-a016-465e-aa81-cfb1f5f2c68a',
'58dfcfb0-3231-4010-8dc1-5b1965813de3',
'a6eefce1-b2fb-4d98-b5fd-7fbd4661b5a8',
'b160d7f4-e031-450a-8041-61d11b2b694d',
'b06b50c4-f7df-4bbb-b7e7-45b9bb762a48',
'e2fed92e-2ca3-4de5-a137-046ec5a9f735',
'c8c3592a-25be-4c07-a2e5-c5324bccb433',
'2b0e945b-f842-4d9a-9924-575e4ae76efb']

# Iterate through the list of monitoring IDs and call the insert function
for monitoring_id in monitoring_ids:
    insert_youtube_public_metrics(conn, uuid.UUID(monitoring_id))

# Close the database connection
conn.close()
# Out:
#   Cell In[15], line 18
#     start_date = '2024-02-01 00:00:00'
#     ^
# SyntaxError: invalid syntax
