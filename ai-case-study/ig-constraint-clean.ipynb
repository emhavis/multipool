# %%
import psycopg2
from tqdm import tqdm

# Database connection
connection = psycopg2.connect(
    host='98.98.117.105',
    user='postgres',
    password='FEWcTB3JIX5gK4T06c1MdkM9N2S8w9pb',
    database='medols'
)

try:
    with connection.cursor() as cursor:
        # Find duplicate instagram_post_id
        find_duplicates_sql = """
        SELECT instagram_post_id, COUNT(*)
        FROM instagram_post_sentiment
        GROUP BY instagram_post_id
        HAVING COUNT(*) > 1
        """
        cursor.execute(find_duplicates_sql)
        duplicates = cursor.fetchall()

        # Handle duplicates with tqdm progress bar
        for instagram_post_id, count in tqdm(duplicates, desc="Processing duplicates"):
            print(f"Found {count} duplicates for instagram_post_id: {instagram_post_id}")

            # Select rows with the duplicate instagram_post_id
            select_duplicates_sql = """
            SELECT id
            FROM instagram_post_sentiment
            WHERE instagram_post_id = %s
            """
            cursor.execute(select_duplicates_sql, (instagram_post_id,))
            duplicate_rows = cursor.fetchall()

            # Keep the first occurrence and remove the others
            ids_to_delete = [row[0] for row in duplicate_rows[1:]]

            if ids_to_delete:
                delete_duplicates_sql = """
                DELETE FROM instagram_post_sentiment
                WHERE id IN (%s)
                """ % ', '.join(map(str, ids_to_delete))
                cursor.execute(delete_duplicates_sql)
                print(f"Deleted {len(ids_to_delete)} duplicate rows for instagram_post_id: {instagram_post_id}")

        # Commit the changes
        connection.commit()

finally:
    connection.close()

# Now add the unique constraint
connection = psycopg2.connect(
    host='98.98.117.105',
    user='postgres',
    password='FEWcTB3JIX5gK4T06c1MdkM9N2S8w9pb',
    database='medols'
)

try:
    with connection.cursor() as cursor:
        add_constraint_sql = """
        ALTER TABLE instagram_post_sentiment
        ADD CONSTRAINT unique_instagram_post_id UNIQUE (instagram_post_id)
        """
        cursor.execute(add_constraint_sql)
        connection.commit()
        print("Unique constraint added to instagram_post_id")

finally:
    connection.close()
# Out:
# Processing duplicates:   1%|▋                                                        | 14/1085 [00:00<00:07, 138.68it/s]
# Found 2 duplicates for instagram_post_id: C6RXQBTy5si
# Deleted 1 duplicate rows for instagram_post_id: C6RXQBTy5si
# Found 2 duplicates for instagram_post_id: C7q0HL8Nyq7
# Deleted 1 duplicate rows for instagram_post_id: C7q0HL8Nyq7
# Found 2 duplicates for instagram_post_id: C7i_yRwS96q
# Deleted 1 duplicate rows for instagram_post_id: C7i_yRwS96q
# Found 2 duplicates for instagram_post_id: C7AXo0mvbPj
# Deleted 1 duplicate rows for instagram_post_id: C7AXo0mvbPj
# Found 2 duplicates for instagram_post_id: CWZ5pw3M8z6
# Deleted 1 duplicate rows for instagram_post_id: CWZ5pw3M8z6
# Found 2 duplicates for instagram_post_id: C6UriSfveBU
# Deleted 1 duplicate rows for instagram_post_id: C6UriSfveBU
# Found 2 duplicates for instagram_post_id: C6VQsvHSKxK
# Deleted 1 duplicate rows for instagram_post_id: C6VQsvHSKxK
# Found 2 duplicates for instagram_post_id: C6F-butP-rt
# Deleted 1 duplicate rows for instagram_post_id: C6F-butP-rt
# Found 2 duplicates for instagram_post_id: C6GOXjKSrT7
# Deleted 1 duplicate rows for instagram_post_id: C6GOXjKSrT7
# Found 2 duplicates for instagram_post_id: C6GMJ2Vy2fT
# Deleted 1 duplicate rows for instagram_post_id: C6GMJ2Vy2fT
# Found 2 duplicates for instagram_post_id: C6F-4ZFPKjX
# Deleted 1 duplicate rows for instagram_post_id: C6F-4ZFPKjX
# Found 2 duplicates for instagram_post_id: C6GRRRhRXwS
# Deleted 1 duplicate rows for instagram_post_id: C6GRRRhRXwS
# Found 2 duplicates for instagram_post_id: C6GDWZ1S-12
# Deleted 1 duplicate rows for instagram_post_id: C6GDWZ1S-12
# Found 2 duplicates for instagram_post_id: CVm7Uyvs4Iy
# Deleted 1 duplicate rows for instagram_post_id: CVm7Uyvs4Iy
# Found 2 duplicates for instagram_post_id: C7i6imcPRtP
# Deleted 1 duplicate rows for instagram_post_id: C7i6imcPRtP
# Found 2 duplicates for instagram_post_id: C6GBJYdSt2b
# Deleted 1 duplicate rows for instagram_post_id: C6GBJYdSt2b
# Found 2 duplicates for instagram_post_id: CIU5IYnhctD
# Deleted 1 duplicate rows for instagram_post_id: CIU5IYnhctD
# Found 2 duplicates for instagram_post_id: C6GAsNRBIv_
# Deleted 1 duplicate rows for instagram_post_id: C6GAsNRBIv_
# Found 2 duplicates for instagram_post_id: C7qarhoCB35
# Deleted 1 duplicate rows for instagram_post_id: C7qarhoCB35
# Found 2 duplicates for instagram_post_id: C7ZazGHvD9H
# Deleted 1 duplicate rows for instagram_post_id: C7ZazGHvD9H
# Found 2 duplicates for instagram_post_id: C6V8QRyIH_R
# Deleted 1 duplicate rows for instagram_post_id: C6V8QRyIH_R
# Found 2 duplicates for instagram_post_id: C5qeB9Rq_a8
# Deleted 1 duplicate rows for instagram_post_id: C5qeB9Rq_a8
# Found 2 duplicates for instagram_post_id: CzNU13vyfnH
# Deleted 1 duplicate rows for instagram_post_id: CzNU13vyfnH
# Found 2 duplicates for instagram_post_id: C6TawgbyTTY
# Deleted 1 duplicate rows for instagram_post_id: C6TawgbyTTY
# Found 2 duplicates for instagram_post_id: C6GEYT2v5_N
# Deleted 1 duplicate rows for instagram_post_id: C6GEYT2v5_N
# Found 2 duplicates for instagram_post_id: C6GJtoThPVh
# Deleted 1 duplicate rows for instagram_post_id: C6GJtoThPVh
# Found 2 duplicates for instagram_post_id: C6GIhcSuJ4j
# Deleted 1 duplicate rows for instagram_post_id: C6GIhcSuJ4j
# Found 2 duplicates for instagram_post_id: C6GVNKJypnq
# Deleted 1 duplicate rows for instagram_post_id: C6GVNKJypnq
# Found 2 duplicates for instagram_post_id: C7JdnAZAOC_
# Processing duplicates:   4%|██▎                                                      | 44/1085 [00:00<00:07, 142.02it/s]
# Deleted 1 duplicate rows for instagram_post_id: C7JdnAZAOC_
# Found 2 duplicates for instagram_post_id: C7e2bYRogCd
# Deleted 1 duplicate rows for instagram_post_id: C7e2bYRogCd
# Found 2 duplicates for instagram_post_id: C6F_rOAvrX_
# Deleted 1 duplicate rows for instagram_post_id: C6F_rOAvrX_
# Found 2 duplicates for instagram_post_id: C6ShBAuJiSB
# Deleted 1 duplicate rows for instagram_post_id: C6ShBAuJiSB
# Found 2 duplicates for instagram_post_id: C7fLi53I98N
# Deleted 1 duplicate rows for instagram_post_id: C7fLi53I98N
# Found 2 duplicates for instagram_post_id: C6GTttSPGt1
# Deleted 1 duplicate rows for instagram_post_id: C6GTttSPGt1
# Found 2 duplicates for instagram_post_id: C6GTVGNJgXf
# Deleted 1 duplicate rows for instagram_post_id: C6GTVGNJgXf
# Found 2 duplicates for instagram_post_id: C6WeUojPcoa
# Deleted 1 duplicate rows for instagram_post_id: C6WeUojPcoa
# Found 2 duplicates for instagram_post_id: C68GtI0qoV2
# Deleted 1 duplicate rows for instagram_post_id: C68GtI0qoV2
# Found 2 duplicates for instagram_post_id: C5qK8iloqgA
# Deleted 1 duplicate rows for instagram_post_id: C5qK8iloqgA
# Found 2 duplicates for instagram_post_id: C6VP3yVy_RF
# Deleted 1 duplicate rows for instagram_post_id: C6VP3yVy_RF
# Found 2 duplicates for instagram_post_id: C6GDlonvfpM
# Deleted 1 duplicate rows for instagram_post_id: C6GDlonvfpM
# Found 2 duplicates for instagram_post_id: C6GTsUkBhWk
# Deleted 1 duplicate rows for instagram_post_id: C6GTsUkBhWk
# Found 2 duplicates for instagram_post_id: C9rjz5FJtRP
# Deleted 1 duplicate rows for instagram_post_id: C9rjz5FJtRP
# Found 2 duplicates for instagram_post_id: C6GE5g0PIfy
# Deleted 1 duplicate rows for instagram_post_id: C6GE5g0PIfy
# Found 2 duplicates for instagram_post_id: C6F-PpXPIC_
# Deleted 1 duplicate rows for instagram_post_id: C6F-PpXPIC_
# Found 2 duplicates for instagram_post_id: C65sMpvyGVm
# Deleted 1 duplicate rows for instagram_post_id: C65sMpvyGVm
# Found 2 duplicates for instagram_post_id: C6GGeyHPxth
# Deleted 1 duplicate rows for instagram_post_id: C6GGeyHPxth
# Found 2 duplicates for instagram_post_id: C6GBdNuP6XF
# Deleted 1 duplicate rows for instagram_post_id: C6GBdNuP6XF
# Found 2 duplicates for instagram_post_id: C7q1GN7Sn52
# Deleted 1 duplicate rows for instagram_post_id: C7q1GN7Sn52
# Found 2 duplicates for instagram_post_id: C6GQWJzSpbL
# Deleted 1 duplicate rows for instagram_post_id: C6GQWJzSpbL
# Found 2 duplicates for instagram_post_id: CHNK_ZgJaY0
# Deleted 1 duplicate rows for instagram_post_id: CHNK_ZgJaY0
# Found 2 duplicates for instagram_post_id: C7kx3Y5hHlT
# Deleted 1 duplicate rows for instagram_post_id: C7kx3Y5hHlT
# Found 2 duplicates for instagram_post_id: C6GI24VLZzB
# Deleted 1 duplicate rows for instagram_post_id: C6GI24VLZzB
# Found 2 duplicates for instagram_post_id: CNUZQH7HWQq
# Deleted 1 duplicate rows for instagram_post_id: CNUZQH7HWQq
# Found 2 duplicates for instagram_post_id: C6QC-QnL-E6
# Deleted 1 duplicate rows for instagram_post_id: C6QC-QnL-E6
# Found 2 duplicates for instagram_post_id: C6F-GduRdkv
# Deleted 1 duplicate rows for instagram_post_id: C6F-GduRdkv
# Found 2 duplicates for instagram_post_id: C58e2cXr6Fm
# Deleted 1 duplicate rows for instagram_post_id: C58e2cXr6Fm
# Found 2 duplicates for instagram_post_id: C9kC0Rhpj1p
# Processing duplicates:   7%|███▊                                                     | 73/1085 [00:00<00:07, 139.29it/s]
# Deleted 1 duplicate rows for instagram_post_id: C9kC0Rhpj1p
# Found 2 duplicates for instagram_post_id: C6GArQuLqhm
# Deleted 1 duplicate rows for instagram_post_id: C6GArQuLqhm
# Found 2 duplicates for instagram_post_id: C5ittbnLBaI
# Deleted 1 duplicate rows for instagram_post_id: C5ittbnLBaI
# Found 2 duplicates for instagram_post_id: C6SmOJiShM5
# Deleted 1 duplicate rows for instagram_post_id: C6SmOJiShM5
# Found 2 duplicates for instagram_post_id: B4UoUyeHBw-
# Deleted 1 duplicate rows for instagram_post_id: B4UoUyeHBw-
# Found 2 duplicates for instagram_post_id: C48C7gNBJPh
# Deleted 1 duplicate rows for instagram_post_id: C48C7gNBJPh
# Found 2 duplicates for instagram_post_id: CcmSdq6rgIy
# Deleted 1 duplicate rows for instagram_post_id: CcmSdq6rgIy
# Found 2 duplicates for instagram_post_id: CNFDB6cH2m8
# Deleted 1 duplicate rows for instagram_post_id: CNFDB6cH2m8
# Found 2 duplicates for instagram_post_id: C8y6VFZIzOr
# Deleted 1 duplicate rows for instagram_post_id: C8y6VFZIzOr
# Found 2 duplicates for instagram_post_id: C6GJKeDh07V
# Deleted 1 duplicate rows for instagram_post_id: C6GJKeDh07V
# Found 2 duplicates for instagram_post_id: C6GB-g3y-cb
# Deleted 1 duplicate rows for instagram_post_id: C6GB-g3y-cb
# Found 2 duplicates for instagram_post_id: CyhIF24J9DT
# Deleted 1 duplicate rows for instagram_post_id: CyhIF24J9DT
# Found 2 duplicates for instagram_post_id: C6GNAe8uYeD
# Deleted 1 duplicate rows for instagram_post_id: C6GNAe8uYeD
# Found 2 duplicates for instagram_post_id: C69jgrJvpCB
# Deleted 1 duplicate rows for instagram_post_id: C69jgrJvpCB
# Found 2 duplicates for instagram_post_id: C6F_y-PPdlh
# Deleted 1 duplicate rows for instagram_post_id: C6F_y-PPdlh
# Found 2 duplicates for instagram_post_id: C6GAGB3Lz40
# Deleted 1 duplicate rows for instagram_post_id: C6GAGB3Lz40
# Found 2 duplicates for instagram_post_id: C6GH64LSHGL
# Deleted 1 duplicate rows for instagram_post_id: C6GH64LSHGL
# Found 2 duplicates for instagram_post_id: C7WmRpoNtvA
# Deleted 1 duplicate rows for instagram_post_id: C7WmRpoNtvA
# Found 2 duplicates for instagram_post_id: C6GKZx8yYXk
# Deleted 1 duplicate rows for instagram_post_id: C6GKZx8yYXk
# Found 2 duplicates for instagram_post_id: C5n2QDft06b
# Deleted 1 duplicate rows for instagram_post_id: C5n2QDft06b
# Found 2 duplicates for instagram_post_id: CIuKIMmBgW0
# Deleted 1 duplicate rows for instagram_post_id: CIuKIMmBgW0
# Found 2 duplicates for instagram_post_id: C6F_UqCSau6
# Deleted 1 duplicate rows for instagram_post_id: C6F_UqCSau6
# Found 2 duplicates for instagram_post_id: C6PYpDpt0FD
# Deleted 1 duplicate rows for instagram_post_id: C6PYpDpt0FD
# Found 2 duplicates for instagram_post_id: C7fSUeGt8k4
# Deleted 1 duplicate rows for instagram_post_id: C7fSUeGt8k4
# Found 2 duplicates for instagram_post_id: C68QjXFPfdo
# Deleted 1 duplicate rows for instagram_post_id: C68QjXFPfdo
# Found 2 duplicates for instagram_post_id: C6GCOuZPZaV
# Deleted 1 duplicate rows for instagram_post_id: C6GCOuZPZaV
# Found 2 duplicates for instagram_post_id: C6RNGKoyGlC
# Deleted 1 duplicate rows for instagram_post_id: C6RNGKoyGlC
# Found 2 duplicates for instagram_post_id: CNoSR3dnt0g
# Processing duplicates:   9%|█████▏                                                  | 101/1085 [00:00<00:07, 131.88it/s]
# Deleted 1 duplicate rows for instagram_post_id: CNoSR3dnt0g
# Found 2 duplicates for instagram_post_id: C6rPUeKgKyl
# Deleted 1 duplicate rows for instagram_post_id: C6rPUeKgKyl
# Found 2 duplicates for instagram_post_id: C6GH-SarLud
# Deleted 1 duplicate rows for instagram_post_id: C6GH-SarLud
# Found 2 duplicates for instagram_post_id: C6F-4ZErjMP
# Deleted 1 duplicate rows for instagram_post_id: C6F-4ZErjMP
# Found 2 duplicates for instagram_post_id: C6GJ1FzuxE8
# Deleted 1 duplicate rows for instagram_post_id: C6GJ1FzuxE8
# Found 2 duplicates for instagram_post_id: C68BrO-Lx00
# Deleted 1 duplicate rows for instagram_post_id: C68BrO-Lx00
# Found 2 duplicates for instagram_post_id: C6GJO7MyvfS
# Deleted 1 duplicate rows for instagram_post_id: C6GJO7MyvfS
# Found 2 duplicates for instagram_post_id: C6GDYd4S35s
# Deleted 1 duplicate rows for instagram_post_id: C6GDYd4S35s
# Found 2 duplicates for instagram_post_id: CIND3LmJ9ak
# Deleted 1 duplicate rows for instagram_post_id: CIND3LmJ9ak
# Found 2 duplicates for instagram_post_id: C4nKsC8oEKu
# Deleted 1 duplicate rows for instagram_post_id: C4nKsC8oEKu
# Found 2 duplicates for instagram_post_id: C6GBXunh1R5
# Deleted 1 duplicate rows for instagram_post_id: C6GBXunh1R5
# Found 2 duplicates for instagram_post_id: C6GEQ-QSye5
# Deleted 1 duplicate rows for instagram_post_id: C6GEQ-QSye5
# Found 2 duplicates for instagram_post_id: C6GAsWrydXd
# Deleted 1 duplicate rows for instagram_post_id: C6GAsWrydXd
# Found 2 duplicates for instagram_post_id: Cw_8mQRrreE
# Deleted 1 duplicate rows for instagram_post_id: Cw_8mQRrreE
# Found 2 duplicates for instagram_post_id: C6RaHx_odeI
# Deleted 1 duplicate rows for instagram_post_id: C6RaHx_odeI
# Found 2 duplicates for instagram_post_id: C6WZmUOyPim
# Deleted 1 duplicate rows for instagram_post_id: C6WZmUOyPim
# Found 2 duplicates for instagram_post_id: C6SwMqByoeK
# Deleted 1 duplicate rows for instagram_post_id: C6SwMqByoeK
# Found 2 duplicates for instagram_post_id: C6GAVR-vNA1
# Deleted 1 duplicate rows for instagram_post_id: C6GAVR-vNA1
# Found 2 duplicates for instagram_post_id: C5oOJBrOKCK
# Deleted 1 duplicate rows for instagram_post_id: C5oOJBrOKCK
# Found 2 duplicates for instagram_post_id: C5EqsPyOFrP
# Deleted 1 duplicate rows for instagram_post_id: C5EqsPyOFrP
# Found 2 duplicates for instagram_post_id: C6GBkUwxhFc
# Deleted 1 duplicate rows for instagram_post_id: C6GBkUwxhFc
# Found 2 duplicates for instagram_post_id: C6F-0l0S6eE
# Deleted 1 duplicate rows for instagram_post_id: C6F-0l0S6eE
# Found 2 duplicates for instagram_post_id: CNC2tjNs-rs
# Deleted 1 duplicate rows for instagram_post_id: CNC2tjNs-rs
# Found 2 duplicates for instagram_post_id: COcmlX3h5Xo
# Deleted 1 duplicate rows for instagram_post_id: COcmlX3h5Xo
# Found 2 duplicates for instagram_post_id: C5qEOK1Ilqo
# Deleted 1 duplicate rows for instagram_post_id: C5qEOK1Ilqo
# Found 2 duplicates for instagram_post_id: C6F-5pvv0Pc
# Deleted 1 duplicate rows for instagram_post_id: C6F-5pvv0Pc
# Found 2 duplicates for instagram_post_id: COe2uH3hv55
# Processing duplicates:  12%|██████▋                                                 | 129/1085 [00:00<00:07, 129.59it/s]
# Deleted 1 duplicate rows for instagram_post_id: COe2uH3hv55
# Found 2 duplicates for instagram_post_id: C6GS9marZJ5
# Deleted 1 duplicate rows for instagram_post_id: C6GS9marZJ5
# Found 2 duplicates for instagram_post_id: C68CkuVvstD
# Deleted 1 duplicate rows for instagram_post_id: C68CkuVvstD
# Found 2 duplicates for instagram_post_id: C6Vf0V_Ls-1
# Deleted 1 duplicate rows for instagram_post_id: C6Vf0V_Ls-1
# Found 2 duplicates for instagram_post_id: C6TaS_iSY6e
# Deleted 1 duplicate rows for instagram_post_id: C6TaS_iSY6e
# Found 2 duplicates for instagram_post_id: C4wYIgoAS7V
# Deleted 1 duplicate rows for instagram_post_id: C4wYIgoAS7V
# Found 2 duplicates for instagram_post_id: C6TYGlESGkg
# Deleted 1 duplicate rows for instagram_post_id: C6TYGlESGkg
# Found 2 duplicates for instagram_post_id: C6GERnch5Ws
# Deleted 1 duplicate rows for instagram_post_id: C6GERnch5Ws
# Found 2 duplicates for instagram_post_id: C6GBykav4EM
# Deleted 1 duplicate rows for instagram_post_id: C6GBykav4EM
# Found 2 duplicates for instagram_post_id: C6F-qoUS4Yx
# Deleted 1 duplicate rows for instagram_post_id: C6F-qoUS4Yx
# Found 2 duplicates for instagram_post_id: C6GIvD4POUQ
# Deleted 1 duplicate rows for instagram_post_id: C6GIvD4POUQ
# Found 2 duplicates for instagram_post_id: C6GLDQEyNw2
# Deleted 1 duplicate rows for instagram_post_id: C6GLDQEyNw2
# Found 2 duplicates for instagram_post_id: C4iY8oRgKqJ
# Deleted 1 duplicate rows for instagram_post_id: C4iY8oRgKqJ
# Found 2 duplicates for instagram_post_id: C68kTivPWuw
# Deleted 1 duplicate rows for instagram_post_id: C68kTivPWuw
# Found 2 duplicates for instagram_post_id: CLTxehOhZaO
# Deleted 1 duplicate rows for instagram_post_id: CLTxehOhZaO
# Found 2 duplicates for instagram_post_id: C7qvl0Jv8Zf
# Deleted 1 duplicate rows for instagram_post_id: C7qvl0Jv8Zf
# Found 2 duplicates for instagram_post_id: C6F-4PvvSww
# Deleted 1 duplicate rows for instagram_post_id: C6F-4PvvSww
# Found 2 duplicates for instagram_post_id: C4tEfukuW5e
# Deleted 1 duplicate rows for instagram_post_id: C4tEfukuW5e
# Found 2 duplicates for instagram_post_id: C6Va9BNSffu
# Deleted 1 duplicate rows for instagram_post_id: C6Va9BNSffu
# Found 2 duplicates for instagram_post_id: C6GBtF8SAIP
# Deleted 1 duplicate rows for instagram_post_id: C6GBtF8SAIP
# Found 2 duplicates for instagram_post_id: C6rsAjivwjO
# Deleted 1 duplicate rows for instagram_post_id: C6rsAjivwjO
# Found 2 duplicates for instagram_post_id: C7rLR0Dvno5
# Deleted 1 duplicate rows for instagram_post_id: C7rLR0Dvno5
# Found 2 duplicates for instagram_post_id: C6GHAIYPF6L
# Deleted 1 duplicate rows for instagram_post_id: C6GHAIYPF6L
# Found 2 duplicates for instagram_post_id: C6GTzAJBpNC
# Deleted 1 duplicate rows for instagram_post_id: C6GTzAJBpNC
# Found 2 duplicates for instagram_post_id: CY6S-FdoIvO
# Deleted 1 duplicate rows for instagram_post_id: CY6S-FdoIvO
# Found 2 duplicates for instagram_post_id: C7h1wItNigO
# Deleted 1 duplicate rows for instagram_post_id: C7h1wItNigO
# Found 2 duplicates for instagram_post_id: C9CDk3yS3l0
# Processing duplicates:  14%|████████                                                | 155/1085 [00:01<00:07, 125.65it/s]
# Deleted 1 duplicate rows for instagram_post_id: C9CDk3yS3l0
# Found 2 duplicates for instagram_post_id: C6GCX9QvCsg
# Deleted 1 duplicate rows for instagram_post_id: C6GCX9QvCsg
# Found 2 duplicates for instagram_post_id: C6GHw05y3np
# Deleted 1 duplicate rows for instagram_post_id: C6GHw05y3np
# Found 2 duplicates for instagram_post_id: C7hj_ZXIFA4
# Deleted 1 duplicate rows for instagram_post_id: C7hj_ZXIFA4
# Found 2 duplicates for instagram_post_id: C6GD_atPkV1
# Deleted 1 duplicate rows for instagram_post_id: C6GD_atPkV1
# Found 2 duplicates for instagram_post_id: C6M1GQfSgge
# Deleted 1 duplicate rows for instagram_post_id: C6M1GQfSgge
# Found 2 duplicates for instagram_post_id: C6TYRWIyHOw
# Deleted 1 duplicate rows for instagram_post_id: C6TYRWIyHOw
# Found 2 duplicates for instagram_post_id: C6GRyzWRnKp
# Deleted 1 duplicate rows for instagram_post_id: C6GRyzWRnKp
# Found 2 duplicates for instagram_post_id: C6GLULGt3j1
# Deleted 1 duplicate rows for instagram_post_id: C6GLULGt3j1
# Found 2 duplicates for instagram_post_id: C5RYw-FJid1
# Deleted 1 duplicate rows for instagram_post_id: C5RYw-FJid1
# Found 2 duplicates for instagram_post_id: C6GFBkgSwtQ
# Deleted 1 duplicate rows for instagram_post_id: C6GFBkgSwtQ
# Found 2 duplicates for instagram_post_id: C6GEHkRLzNL
# Deleted 1 duplicate rows for instagram_post_id: C6GEHkRLzNL
# Found 2 duplicates for instagram_post_id: C6Q3zphSkhk
# Deleted 1 duplicate rows for instagram_post_id: C6Q3zphSkhk
# Found 2 duplicates for instagram_post_id: C4ooGucOQnP
# Deleted 1 duplicate rows for instagram_post_id: C4ooGucOQnP
# Found 2 duplicates for instagram_post_id: C7bUJCzIBuh
# Deleted 1 duplicate rows for instagram_post_id: C7bUJCzIBuh
# Found 2 duplicates for instagram_post_id: C9ruUvCp7Tg
# Deleted 1 duplicate rows for instagram_post_id: C9ruUvCp7Tg
# Found 2 duplicates for instagram_post_id: C6TbJfCJf3f
# Deleted 1 duplicate rows for instagram_post_id: C6TbJfCJf3f
# Found 2 duplicates for instagram_post_id: C6GH2H7S0lA
# Deleted 1 duplicate rows for instagram_post_id: C6GH2H7S0lA
# Found 2 duplicates for instagram_post_id: C68FgEevJgD
# Deleted 1 duplicate rows for instagram_post_id: C68FgEevJgD
# Found 2 duplicates for instagram_post_id: C6SBZzVR4kN
# Deleted 1 duplicate rows for instagram_post_id: C6SBZzVR4kN
# Found 2 duplicates for instagram_post_id: C3-qebWLkYQ
# Deleted 1 duplicate rows for instagram_post_id: C3-qebWLkYQ
# Found 2 duplicates for instagram_post_id: C6F_uWSvvmy
# Deleted 1 duplicate rows for instagram_post_id: C6F_uWSvvmy
# Found 2 duplicates for instagram_post_id: C6GI7J8PRbD
# Deleted 1 duplicate rows for instagram_post_id: C6GI7J8PRbD
# Found 2 duplicates for instagram_post_id: C9eg8AoPh-Q
# Deleted 1 duplicate rows for instagram_post_id: C9eg8AoPh-Q
# Found 2 duplicates for instagram_post_id: C6QTDjKLTr2
# Deleted 1 duplicate rows for instagram_post_id: C6QTDjKLTr2
# Found 2 duplicates for instagram_post_id: C6RPuY5y7Yt
# Processing duplicates:  17%|█████████▍                                              | 182/1085 [00:01<00:07, 127.91it/s]
# Deleted 1 duplicate rows for instagram_post_id: C6RPuY5y7Yt
# Found 2 duplicates for instagram_post_id: C7VQZqIyT5e
# Deleted 1 duplicate rows for instagram_post_id: C7VQZqIyT5e
# Found 2 duplicates for instagram_post_id: C69seDBvUtj
# Deleted 1 duplicate rows for instagram_post_id: C69seDBvUtj
# Found 2 duplicates for instagram_post_id: C6Qd34JyBh_
# Deleted 1 duplicate rows for instagram_post_id: C6Qd34JyBh_
# Found 2 duplicates for instagram_post_id: C68FD41y0CA
# Deleted 1 duplicate rows for instagram_post_id: C68FD41y0CA
# Found 2 duplicates for instagram_post_id: C6GEgP8vD8i
# Deleted 1 duplicate rows for instagram_post_id: C6GEgP8vD8i
# Found 2 duplicates for instagram_post_id: C6GU44-rTXK
# Deleted 1 duplicate rows for instagram_post_id: C6GU44-rTXK
# Found 2 duplicates for instagram_post_id: C6GFT9uxoXq
# Deleted 1 duplicate rows for instagram_post_id: C6GFT9uxoXq
# Found 2 duplicates for instagram_post_id: C7csinCxlv4
# Deleted 1 duplicate rows for instagram_post_id: C7csinCxlv4
# Found 2 duplicates for instagram_post_id: C5vFhHKrOwQ
# Deleted 1 duplicate rows for instagram_post_id: C5vFhHKrOwQ
# Found 2 duplicates for instagram_post_id: C6GF1Gov3sK
# Deleted 1 duplicate rows for instagram_post_id: C6GF1Gov3sK
# Found 2 duplicates for instagram_post_id: C6F9_MWvQrv
# Deleted 1 duplicate rows for instagram_post_id: C6F9_MWvQrv
# Found 2 duplicates for instagram_post_id: C6GBn9kp9Mk
# Deleted 1 duplicate rows for instagram_post_id: C6GBn9kp9Mk
# Found 2 duplicates for instagram_post_id: C6Y1BlTg33T
# Deleted 1 duplicate rows for instagram_post_id: C6Y1BlTg33T
# Found 2 duplicates for instagram_post_id: C6GENXwPxcP
# Deleted 1 duplicate rows for instagram_post_id: C6GENXwPxcP
# Found 2 duplicates for instagram_post_id: C4sdmJTg9v5
# Deleted 1 duplicate rows for instagram_post_id: C4sdmJTg9v5
# Found 2 duplicates for instagram_post_id: CO5Y6Q3nbMi
# Deleted 1 duplicate rows for instagram_post_id: CO5Y6Q3nbMi
# Found 2 duplicates for instagram_post_id: C6GBP3nSm2l
# Deleted 1 duplicate rows for instagram_post_id: C6GBP3nSm2l
# Found 2 duplicates for instagram_post_id: CNTiBXWF7f5
# Deleted 1 duplicate rows for instagram_post_id: CNTiBXWF7f5
# Found 2 duplicates for instagram_post_id: C5Bc4edSieX
# Deleted 1 duplicate rows for instagram_post_id: C5Bc4edSieX
# Found 2 duplicates for instagram_post_id: C6GOvdjp0tT
# Deleted 1 duplicate rows for instagram_post_id: C6GOvdjp0tT
# Found 2 duplicates for instagram_post_id: C6GUFF8SDyZ
# Deleted 1 duplicate rows for instagram_post_id: C6GUFF8SDyZ
# Found 2 duplicates for instagram_post_id: C68EZ-0vOoP
# Deleted 1 duplicate rows for instagram_post_id: C68EZ-0vOoP
# Found 2 duplicates for instagram_post_id: C6F-J1bPAtb
# Deleted 1 duplicate rows for instagram_post_id: C6F-J1bPAtb
# Found 2 duplicates for instagram_post_id: C6GKCsSPZFw
# Deleted 1 duplicate rows for instagram_post_id: C6GKCsSPZFw
# Found 2 duplicates for instagram_post_id: C6GA7rJyi9S
# Deleted 1 duplicate rows for instagram_post_id: C6GA7rJyi9S
# Found 2 duplicates for instagram_post_id: COQNc_JsSmW
# Processing duplicates:  19%|██████████▋                                             | 208/1085 [00:01<00:06, 126.83it/s]
# Deleted 1 duplicate rows for instagram_post_id: COQNc_JsSmW
# Found 2 duplicates for instagram_post_id: C68JnD0Plb9
# Deleted 1 duplicate rows for instagram_post_id: C68JnD0Plb9
# Found 2 duplicates for instagram_post_id: C6F_HRuL4wO
# Deleted 1 duplicate rows for instagram_post_id: C6F_HRuL4wO
# Found 2 duplicates for instagram_post_id: C6F_D_5SHOf
# Deleted 1 duplicate rows for instagram_post_id: C6F_D_5SHOf
# Found 2 duplicates for instagram_post_id: C6Sitgpxmal
# Deleted 1 duplicate rows for instagram_post_id: C6Sitgpxmal
# Found 2 duplicates for instagram_post_id: B3D3hk4gfng
# Deleted 1 duplicate rows for instagram_post_id: B3D3hk4gfng
# Found 2 duplicates for instagram_post_id: Bi8Z-bWFHtP
# Deleted 1 duplicate rows for instagram_post_id: Bi8Z-bWFHtP
# Found 2 duplicates for instagram_post_id: C6GCmuQy1H_
# Deleted 1 duplicate rows for instagram_post_id: C6GCmuQy1H_
# Found 2 duplicates for instagram_post_id: C6GKjTILU-9
# Deleted 1 duplicate rows for instagram_post_id: C6GKjTILU-9
# Found 2 duplicates for instagram_post_id: C6V5sWxppsO
# Deleted 1 duplicate rows for instagram_post_id: C6V5sWxppsO
# Found 2 duplicates for instagram_post_id: C5c_QgnMxao
# Deleted 1 duplicate rows for instagram_post_id: C5c_QgnMxao
# Found 2 duplicates for instagram_post_id: C6GA4ZRS9c3
# Deleted 1 duplicate rows for instagram_post_id: C6GA4ZRS9c3
# Found 2 duplicates for instagram_post_id: C5mlJHmSMH1
# Deleted 1 duplicate rows for instagram_post_id: C5mlJHmSMH1
# Found 2 duplicates for instagram_post_id: C6N2yhfpc8Z
# Deleted 1 duplicate rows for instagram_post_id: C6N2yhfpc8Z
# Found 2 duplicates for instagram_post_id: C6TQH0st2bM
# Deleted 1 duplicate rows for instagram_post_id: C6TQH0st2bM
# Found 2 duplicates for instagram_post_id: C6GEmkJrxMI
# Deleted 1 duplicate rows for instagram_post_id: C6GEmkJrxMI
# Found 2 duplicates for instagram_post_id: C6GUO9LSYTE
# Deleted 1 duplicate rows for instagram_post_id: C6GUO9LSYTE
# Found 2 duplicates for instagram_post_id: CN6-MnrhYY3
# Deleted 1 duplicate rows for instagram_post_id: CN6-MnrhYY3
# Found 2 duplicates for instagram_post_id: C6GBfQASLKK
# Deleted 1 duplicate rows for instagram_post_id: C6GBfQASLKK
# Found 2 duplicates for instagram_post_id: C6S-netS-Op
# Deleted 1 duplicate rows for instagram_post_id: C6S-netS-Op
# Found 2 duplicates for instagram_post_id: C51J5H0Amyn
# Deleted 1 duplicate rows for instagram_post_id: C51J5H0Amyn
# Found 2 duplicates for instagram_post_id: C6QiWNJSq4_
# Deleted 1 duplicate rows for instagram_post_id: C6QiWNJSq4_
# Found 2 duplicates for instagram_post_id: C6GFQcCP4kx
# Deleted 1 duplicate rows for instagram_post_id: C6GFQcCP4kx
# Found 2 duplicates for instagram_post_id: C68D6FDvcvC
# Deleted 1 duplicate rows for instagram_post_id: C68D6FDvcvC
# Found 2 duplicates for instagram_post_id: C6Af1WCxtIe
# Deleted 1 duplicate rows for instagram_post_id: C6Af1WCxtIe
# Found 2 duplicates for instagram_post_id: CJV9lguhIQX
# Deleted 1 duplicate rows for instagram_post_id: CJV9lguhIQX
# Found 2 duplicates for instagram_post_id: C6GGZBFr8q7
# Deleted 1 duplicate rows for instagram_post_id: C6GGZBFr8q7
# Found 2 duplicates for instagram_post_id: C6SbFXfPmWK
# Processing duplicates:  22%|████████████▏                                           | 235/1085 [00:01<00:06, 128.75it/s]
# Deleted 1 duplicate rows for instagram_post_id: C6SbFXfPmWK
# Found 2 duplicates for instagram_post_id: C6GFWuHLelC
# Deleted 1 duplicate rows for instagram_post_id: C6GFWuHLelC
# Found 2 duplicates for instagram_post_id: C5FG2MWPM3_
# Deleted 1 duplicate rows for instagram_post_id: C5FG2MWPM3_
# Found 2 duplicates for instagram_post_id: C6Tk1PIvyIk
# Deleted 1 duplicate rows for instagram_post_id: C6Tk1PIvyIk
# Found 2 duplicates for instagram_post_id: C6F_FZiL6nm
# Deleted 1 duplicate rows for instagram_post_id: C6F_FZiL6nm
# Found 2 duplicates for instagram_post_id: Cn7lkpFuq2m
# Deleted 1 duplicate rows for instagram_post_id: Cn7lkpFuq2m
# Found 2 duplicates for instagram_post_id: C6GJu73v-sh
# Deleted 1 duplicate rows for instagram_post_id: C6GJu73v-sh
# Found 2 duplicates for instagram_post_id: C54fcJcSlKu
# Deleted 1 duplicate rows for instagram_post_id: C54fcJcSlKu
# Found 2 duplicates for instagram_post_id: C9rlYt2ShQ-
# Deleted 1 duplicate rows for instagram_post_id: C9rlYt2ShQ-
# Found 2 duplicates for instagram_post_id: C6GGpE0rMu8
# Deleted 1 duplicate rows for instagram_post_id: C6GGpE0rMu8
# Found 2 duplicates for instagram_post_id: C6NwDysSNTq
# Deleted 1 duplicate rows for instagram_post_id: C6NwDysSNTq
# Found 2 duplicates for instagram_post_id: CeIVsQzLDfS
# Deleted 1 duplicate rows for instagram_post_id: CeIVsQzLDfS
# Found 2 duplicates for instagram_post_id: C6GL8ZTr6ow
# Deleted 1 duplicate rows for instagram_post_id: C6GL8ZTr6ow
# Found 2 duplicates for instagram_post_id: Cz7LqwmBjTA
# Deleted 1 duplicate rows for instagram_post_id: Cz7LqwmBjTA
# Found 2 duplicates for instagram_post_id: C7hXpjdNqme
# Deleted 1 duplicate rows for instagram_post_id: C7hXpjdNqme
# Found 2 duplicates for instagram_post_id: C6GAs7Gt79n
# Deleted 1 duplicate rows for instagram_post_id: C6GAs7Gt79n
# Found 2 duplicates for instagram_post_id: C6GQ0I6LUPA
# Deleted 1 duplicate rows for instagram_post_id: C6GQ0I6LUPA
# Found 2 duplicates for instagram_post_id: C7feeLxgL-g
# Deleted 1 duplicate rows for instagram_post_id: C7feeLxgL-g
# Found 2 duplicates for instagram_post_id: C6GEuMark1r
# Deleted 1 duplicate rows for instagram_post_id: C6GEuMark1r
# Found 2 duplicates for instagram_post_id: C6F_dhUvsik
# Deleted 1 duplicate rows for instagram_post_id: C6F_dhUvsik
# Found 2 duplicates for instagram_post_id: CfHDZOUlzEr
# Deleted 1 duplicate rows for instagram_post_id: CfHDZOUlzEr
# Found 2 duplicates for instagram_post_id: C6GUyUhgs9Y
# Deleted 1 duplicate rows for instagram_post_id: C6GUyUhgs9Y
# Found 2 duplicates for instagram_post_id: C6F_CTCyY1K
# Deleted 1 duplicate rows for instagram_post_id: C6F_CTCyY1K
# Found 2 duplicates for instagram_post_id: C6GBq4LSENx
# Deleted 1 duplicate rows for instagram_post_id: C6GBq4LSENx
# Found 2 duplicates for instagram_post_id: CzqtvdVL3NG
# Deleted 1 duplicate rows for instagram_post_id: CzqtvdVL3NG
# Found 2 duplicates for instagram_post_id: C6RRADKNLRh
# Deleted 1 duplicate rows for instagram_post_id: C6RRADKNLRh
# Found 2 duplicates for instagram_post_id: C6GFCpgyY7r
# Deleted 1 duplicate rows for instagram_post_id: C6GFCpgyY7r
# Found 2 duplicates for instagram_post_id: C7bFN5YMZCs
# Processing duplicates:  24%|█████████████▌                                          | 262/1085 [00:02<00:06, 130.33it/s]
# Deleted 1 duplicate rows for instagram_post_id: C7bFN5YMZCs
# Found 2 duplicates for instagram_post_id: C6E5ZXcyTk9
# Deleted 1 duplicate rows for instagram_post_id: C6E5ZXcyTk9
# Found 2 duplicates for instagram_post_id: C6TsvE9p0MR
# Deleted 1 duplicate rows for instagram_post_id: C6TsvE9p0MR
# Found 2 duplicates for instagram_post_id: C7fn5wbvo09
# Deleted 1 duplicate rows for instagram_post_id: C7fn5wbvo09
# Found 2 duplicates for instagram_post_id: C6GLVrYJt-U
# Deleted 1 duplicate rows for instagram_post_id: C6GLVrYJt-U
# Found 2 duplicates for instagram_post_id: C6WfsMdyTdn
# Deleted 1 duplicate rows for instagram_post_id: C6WfsMdyTdn
# Found 2 duplicates for instagram_post_id: C6SmkH6Sw9V
# Deleted 1 duplicate rows for instagram_post_id: C6SmkH6Sw9V
# Found 2 duplicates for instagram_post_id: CT0sXXlhY6Q
# Deleted 1 duplicate rows for instagram_post_id: CT0sXXlhY6Q
# Found 2 duplicates for instagram_post_id: C68MFxfhi8M
# Deleted 1 duplicate rows for instagram_post_id: C68MFxfhi8M
# Found 2 duplicates for instagram_post_id: C6GLf9hyv6f
# Deleted 1 duplicate rows for instagram_post_id: C6GLf9hyv6f
# Found 2 duplicates for instagram_post_id: C9cbuc1Bg7w
# Deleted 1 duplicate rows for instagram_post_id: C9cbuc1Bg7w
# Found 2 duplicates for instagram_post_id: C6GDaVcpiCi
# Deleted 1 duplicate rows for instagram_post_id: C6GDaVcpiCi
# Found 2 duplicates for instagram_post_id: C6GD3NsSzNt
# Deleted 1 duplicate rows for instagram_post_id: C6GD3NsSzNt
# Found 2 duplicates for instagram_post_id: C1Mh58YrJ4H
# Deleted 1 duplicate rows for instagram_post_id: C1Mh58YrJ4H
# Found 2 duplicates for instagram_post_id: C6VbvKyLVnh
# Deleted 1 duplicate rows for instagram_post_id: C6VbvKyLVnh
# Found 2 duplicates for instagram_post_id: C6QVf0XL6dM
# Deleted 1 duplicate rows for instagram_post_id: C6QVf0XL6dM
# Found 2 duplicates for instagram_post_id: CIE9f59B-Fa
# Deleted 1 duplicate rows for instagram_post_id: CIE9f59B-Fa
# Found 2 duplicates for instagram_post_id: C6WjSI4vjgT
# Deleted 1 duplicate rows for instagram_post_id: C6WjSI4vjgT
# Found 2 duplicates for instagram_post_id: C6GG1u-yhHh
# Deleted 1 duplicate rows for instagram_post_id: C6GG1u-yhHh
# Found 2 duplicates for instagram_post_id: CM9oomiAZxW
# Deleted 1 duplicate rows for instagram_post_id: CM9oomiAZxW
# Found 2 duplicates for instagram_post_id: C6GKW1Lvfwo
# Deleted 1 duplicate rows for instagram_post_id: C6GKW1Lvfwo
# Found 2 duplicates for instagram_post_id: C6Ouw3yC7um
# Deleted 1 duplicate rows for instagram_post_id: C6Ouw3yC7um
# Found 2 duplicates for instagram_post_id: C6GCY0jPchQ
# Deleted 1 duplicate rows for instagram_post_id: C6GCY0jPchQ
# Found 2 duplicates for instagram_post_id: C6GJALXP9GM
# Deleted 1 duplicate rows for instagram_post_id: C6GJALXP9GM
# Found 2 duplicates for instagram_post_id: C6GLvIOvJZZ
# Deleted 1 duplicate rows for instagram_post_id: C6GLvIOvJZZ
# Found 2 duplicates for instagram_post_id: C6WGMcop-aT
# Deleted 1 duplicate rows for instagram_post_id: C6WGMcop-aT
# Found 2 duplicates for instagram_post_id: C6GScfryQ9T
# Deleted 1 duplicate rows for instagram_post_id: C6GScfryQ9T
# Found 2 duplicates for instagram_post_id: C6GH13Qrh2U
# Processing duplicates:  27%|██████████████▉                                         | 290/1085 [00:02<00:06, 127.04it/s]
# Deleted 1 duplicate rows for instagram_post_id: C6GH13Qrh2U
# Found 2 duplicates for instagram_post_id: C68E7CzSwkd
# Deleted 1 duplicate rows for instagram_post_id: C68E7CzSwkd
# Found 2 duplicates for instagram_post_id: C6GPZsxvZhx
# Deleted 1 duplicate rows for instagram_post_id: C6GPZsxvZhx
# Found 2 duplicates for instagram_post_id: C6GDMa4yDOT
# Deleted 1 duplicate rows for instagram_post_id: C6GDMa4yDOT
# Found 2 duplicates for instagram_post_id: C45TygcKkRh
# Deleted 1 duplicate rows for instagram_post_id: C45TygcKkRh
# Found 2 duplicates for instagram_post_id: C4qJFKut63e
# Deleted 1 duplicate rows for instagram_post_id: C4qJFKut63e
# Found 2 duplicates for instagram_post_id: C46R8bPOMWQ
# Deleted 1 duplicate rows for instagram_post_id: C46R8bPOMWQ
# Found 2 duplicates for instagram_post_id: C6SFjIqqpT3
# Deleted 1 duplicate rows for instagram_post_id: C6SFjIqqpT3
# Found 2 duplicates for instagram_post_id: C6GCq-lvZMV
# Deleted 1 duplicate rows for instagram_post_id: C6GCq-lvZMV
# Found 2 duplicates for instagram_post_id: C6VBx3IJSfb
# Deleted 1 duplicate rows for instagram_post_id: C6VBx3IJSfb
# Found 2 duplicates for instagram_post_id: C5yRsYTONWG
# Deleted 1 duplicate rows for instagram_post_id: C5yRsYTONWG
# Found 2 duplicates for instagram_post_id: C6F-jA9PzoR
# Deleted 1 duplicate rows for instagram_post_id: C6F-jA9PzoR
# Found 2 duplicates for instagram_post_id: C6F_mMfPmf9
# Deleted 1 duplicate rows for instagram_post_id: C6F_mMfPmf9
# Found 2 duplicates for instagram_post_id: C68FVH6LsjO
# Deleted 1 duplicate rows for instagram_post_id: C68FVH6LsjO
# Found 2 duplicates for instagram_post_id: CWDb7vFPGpK
# Deleted 1 duplicate rows for instagram_post_id: CWDb7vFPGpK
# Found 2 duplicates for instagram_post_id: C7hJaxytUU0
# Deleted 1 duplicate rows for instagram_post_id: C7hJaxytUU0
# Found 2 duplicates for instagram_post_id: C7nEgm0NNIo
# Deleted 1 duplicate rows for instagram_post_id: C7nEgm0NNIo
# Found 2 duplicates for instagram_post_id: C6GC6qIpram
# Deleted 1 duplicate rows for instagram_post_id: C6GC6qIpram
# Found 2 duplicates for instagram_post_id: CXgOkMwBfAO
# Deleted 1 duplicate rows for instagram_post_id: CXgOkMwBfAO
# Found 2 duplicates for instagram_post_id: C6PevbQSKkD
# Deleted 1 duplicate rows for instagram_post_id: C6PevbQSKkD
# Found 2 duplicates for instagram_post_id: C6F_Lt7SxX-
# Deleted 1 duplicate rows for instagram_post_id: C6F_Lt7SxX-
# Found 2 duplicates for instagram_post_id: C7hd0mSuAaC
# Deleted 1 duplicate rows for instagram_post_id: C7hd0mSuAaC
# Found 2 duplicates for instagram_post_id: C6GIvULvef4
# Deleted 1 duplicate rows for instagram_post_id: C6GIvULvef4
# Found 2 duplicates for instagram_post_id: C7rGIUGIzsv
# Deleted 1 duplicate rows for instagram_post_id: C7rGIUGIzsv
# Found 2 duplicates for instagram_post_id: C6GSXMjrrgt
# Deleted 1 duplicate rows for instagram_post_id: C6GSXMjrrgt
# Found 2 duplicates for instagram_post_id: C68OjA7PhIi
# Processing duplicates:  29%|████████████████▎                                       | 316/1085 [00:02<00:06, 125.13it/s]
# Deleted 1 duplicate rows for instagram_post_id: C68OjA7PhIi
# Found 2 duplicates for instagram_post_id: C5nNrQGrlFi
# Deleted 1 duplicate rows for instagram_post_id: C5nNrQGrlFi
# Found 2 duplicates for instagram_post_id: C68RPkWS-1u
# Deleted 1 duplicate rows for instagram_post_id: C68RPkWS-1u
# Found 2 duplicates for instagram_post_id: C6GE-vsSf_m
# Deleted 1 duplicate rows for instagram_post_id: C6GE-vsSf_m
# Found 2 duplicates for instagram_post_id: CZt5tbJMgfh
# Deleted 1 duplicate rows for instagram_post_id: CZt5tbJMgfh
# Found 2 duplicates for instagram_post_id: C6GE-3bP-nX
# Deleted 1 duplicate rows for instagram_post_id: C6GE-3bP-nX
# Found 2 duplicates for instagram_post_id: C6GAEuoPgw5
# Deleted 1 duplicate rows for instagram_post_id: C6GAEuoPgw5
# Found 2 duplicates for instagram_post_id: C68WO5gPrcD
# Deleted 1 duplicate rows for instagram_post_id: C68WO5gPrcD
# Found 2 duplicates for instagram_post_id: C6Y3pAaS3gU
# Deleted 1 duplicate rows for instagram_post_id: C6Y3pAaS3gU
# Found 2 duplicates for instagram_post_id: C6TAEkRyFpu
# Deleted 1 duplicate rows for instagram_post_id: C6TAEkRyFpu
# Found 2 duplicates for instagram_post_id: C9o6b9VJEKu
# Deleted 1 duplicate rows for instagram_post_id: C9o6b9VJEKu
# Found 2 duplicates for instagram_post_id: CNARb39AxQ6
# Deleted 1 duplicate rows for instagram_post_id: CNARb39AxQ6
# Found 2 duplicates for instagram_post_id: C6VFxAQJy_G
# Deleted 1 duplicate rows for instagram_post_id: C6VFxAQJy_G
# Found 2 duplicates for instagram_post_id: C6SLDVmSFsW
# Deleted 1 duplicate rows for instagram_post_id: C6SLDVmSFsW
# Found 2 duplicates for instagram_post_id: C6PfwZTSGn-
# Deleted 1 duplicate rows for instagram_post_id: C6PfwZTSGn-
# Found 2 duplicates for instagram_post_id: CT35DtqP9wY
# Deleted 1 duplicate rows for instagram_post_id: CT35DtqP9wY
# Found 2 duplicates for instagram_post_id: C6WmQFzBjrr
# Deleted 1 duplicate rows for instagram_post_id: C6WmQFzBjrr
# Found 2 duplicates for instagram_post_id: CR_TVR6Bc2K
# Deleted 1 duplicate rows for instagram_post_id: CR_TVR6Bc2K
# Found 2 duplicates for instagram_post_id: C6U3ZBqSeUk
# Deleted 1 duplicate rows for instagram_post_id: C6U3ZBqSeUk
# Found 2 duplicates for instagram_post_id: C6GI_N9LaDr
# Deleted 1 duplicate rows for instagram_post_id: C6GI_N9LaDr
# Found 2 duplicates for instagram_post_id: C4QiLwbrEEJ
# Deleted 1 duplicate rows for instagram_post_id: C4QiLwbrEEJ
# Found 2 duplicates for instagram_post_id: C4am91Nrb8U
# Deleted 1 duplicate rows for instagram_post_id: C4am91Nrb8U
# Found 2 duplicates for instagram_post_id: C6GGteTPbsh
# Deleted 1 duplicate rows for instagram_post_id: C6GGteTPbsh
# Found 2 duplicates for instagram_post_id: C6GA1W1PR6P
# Deleted 1 duplicate rows for instagram_post_id: C6GA1W1PR6P
# Found 2 duplicates for instagram_post_id: C4QXoFiuAWw
# Deleted 1 duplicate rows for instagram_post_id: C4QXoFiuAWw
# Found 2 duplicates for instagram_post_id: C6VCgChp4K1
# Processing duplicates:  32%|█████████████████▋                                      | 342/1085 [00:02<00:06, 123.18it/s]
# Deleted 1 duplicate rows for instagram_post_id: C6VCgChp4K1
# Found 2 duplicates for instagram_post_id: C5nRyiTiSk_
# Deleted 1 duplicate rows for instagram_post_id: C5nRyiTiSk_
# Found 2 duplicates for instagram_post_id: C6GAjI7LMwZ
# Deleted 1 duplicate rows for instagram_post_id: C6GAjI7LMwZ
# Found 2 duplicates for instagram_post_id: C6F_dk2vv_W
# Deleted 1 duplicate rows for instagram_post_id: C6F_dk2vv_W
# Found 2 duplicates for instagram_post_id: C6GDvMtvPS6
# Deleted 1 duplicate rows for instagram_post_id: C6GDvMtvPS6
# Found 2 duplicates for instagram_post_id: C5vvj5uvOa5
# Deleted 1 duplicate rows for instagram_post_id: C5vvj5uvOa5
# Found 2 duplicates for instagram_post_id: C9wtqxRyVls
# Deleted 1 duplicate rows for instagram_post_id: C9wtqxRyVls
# Found 2 duplicates for instagram_post_id: C6GHglxLnUN
# Deleted 1 duplicate rows for instagram_post_id: C6GHglxLnUN
# Found 2 duplicates for instagram_post_id: C6GNnD1hRsK
# Deleted 1 duplicate rows for instagram_post_id: C6GNnD1hRsK
# Found 2 duplicates for instagram_post_id: C68GAVLPU_E
# Deleted 1 duplicate rows for instagram_post_id: C68GAVLPU_E
# Found 2 duplicates for instagram_post_id: C44qxjRr3-p
# Deleted 1 duplicate rows for instagram_post_id: C44qxjRr3-p
# Found 2 duplicates for instagram_post_id: C54YpRntDvd
# Deleted 1 duplicate rows for instagram_post_id: C54YpRntDvd
# Found 2 duplicates for instagram_post_id: C6GDHvjvhy8
# Deleted 1 duplicate rows for instagram_post_id: C6GDHvjvhy8
# Found 2 duplicates for instagram_post_id: C7api6VPOUd
# Deleted 1 duplicate rows for instagram_post_id: C7api6VPOUd
# Found 2 duplicates for instagram_post_id: C6GKdWGpFnr
# Deleted 1 duplicate rows for instagram_post_id: C6GKdWGpFnr
# Found 2 duplicates for instagram_post_id: C7mV5yhpm2z
# Deleted 1 duplicate rows for instagram_post_id: C7mV5yhpm2z
# Found 2 duplicates for instagram_post_id: C7jIFdOvh6W
# Deleted 1 duplicate rows for instagram_post_id: C7jIFdOvh6W
# Found 2 duplicates for instagram_post_id: C6GH7i2rhwL
# Deleted 1 duplicate rows for instagram_post_id: C6GH7i2rhwL
# Found 2 duplicates for instagram_post_id: C68Qf41LiZw
# Deleted 1 duplicate rows for instagram_post_id: C68Qf41LiZw
# Found 2 duplicates for instagram_post_id: C6g1q6-p57D
# Deleted 1 duplicate rows for instagram_post_id: C6g1q6-p57D
# Found 2 duplicates for instagram_post_id: C6QPUlryB8J
# Deleted 1 duplicate rows for instagram_post_id: C6QPUlryB8J
# Found 2 duplicates for instagram_post_id: C6WLaGINcpU
# Deleted 1 duplicate rows for instagram_post_id: C6WLaGINcpU
# Found 2 duplicates for instagram_post_id: C6GDO4lgQd4
# Deleted 1 duplicate rows for instagram_post_id: C6GDO4lgQd4
# Found 2 duplicates for instagram_post_id: C6GL_LMrBYW
# Deleted 1 duplicate rows for instagram_post_id: C6GL_LMrBYW
# Found 2 duplicates for instagram_post_id: C6GFJcjvtZx
# Deleted 1 duplicate rows for instagram_post_id: C6GFJcjvtZx
# Found 2 duplicates for instagram_post_id: C6GFUh_rA1P
# Processing duplicates:  34%|███████████████████                                     | 370/1085 [00:02<00:05, 128.67it/s]
# Deleted 1 duplicate rows for instagram_post_id: C6GFUh_rA1P
# Found 2 duplicates for instagram_post_id: C6F_ZmmPd3H
# Deleted 1 duplicate rows for instagram_post_id: C6F_ZmmPd3H
# Found 2 duplicates for instagram_post_id: CTWNKuzBMSV
# Deleted 1 duplicate rows for instagram_post_id: CTWNKuzBMSV
# Found 2 duplicates for instagram_post_id: C6PrkW5yQMa
# Deleted 1 duplicate rows for instagram_post_id: C6PrkW5yQMa
# Found 2 duplicates for instagram_post_id: C6GDUMhuEbJ
# Deleted 1 duplicate rows for instagram_post_id: C6GDUMhuEbJ
# Found 2 duplicates for instagram_post_id: C6GTbfNJww0
# Deleted 1 duplicate rows for instagram_post_id: C6GTbfNJww0
# Found 2 duplicates for instagram_post_id: C7h0-9lxgtq
# Deleted 1 duplicate rows for instagram_post_id: C7h0-9lxgtq
# Found 2 duplicates for instagram_post_id: C6QTsiNyZ4a
# Deleted 1 duplicate rows for instagram_post_id: C6QTsiNyZ4a
# Found 2 duplicates for instagram_post_id: C6GHExDv3I7
# Deleted 1 duplicate rows for instagram_post_id: C6GHExDv3I7
# Found 2 duplicates for instagram_post_id: C6ytqGHA3rt
# Deleted 1 duplicate rows for instagram_post_id: C6ytqGHA3rt
# Found 2 duplicates for instagram_post_id: CPhWK0znT0r
# Deleted 1 duplicate rows for instagram_post_id: CPhWK0znT0r
# Found 2 duplicates for instagram_post_id: C6Q9TxbxOsD
# Deleted 1 duplicate rows for instagram_post_id: C6Q9TxbxOsD
# Found 2 duplicates for instagram_post_id: C7O4jCvuXkH
# Deleted 1 duplicate rows for instagram_post_id: C7O4jCvuXkH
# Found 2 duplicates for instagram_post_id: C54mEL6yDDU
# Deleted 1 duplicate rows for instagram_post_id: C54mEL6yDDU
# Found 2 duplicates for instagram_post_id: COakMALhfWe
# Deleted 1 duplicate rows for instagram_post_id: COakMALhfWe
# Found 2 duplicates for instagram_post_id: CtbxYJhSimG
# Deleted 1 duplicate rows for instagram_post_id: CtbxYJhSimG
# Found 2 duplicates for instagram_post_id: C6GE-9qJKgb
# Deleted 1 duplicate rows for instagram_post_id: C6GE-9qJKgb
# Found 2 duplicates for instagram_post_id: C6GDDv5r_ZS
# Deleted 1 duplicate rows for instagram_post_id: C6GDDv5r_ZS
# Found 2 duplicates for instagram_post_id: C6GSym7PoV8
# Deleted 1 duplicate rows for instagram_post_id: C6GSym7PoV8
# Found 2 duplicates for instagram_post_id: C6GGZ2uPwun
# Deleted 1 duplicate rows for instagram_post_id: C6GGZ2uPwun
# Found 2 duplicates for instagram_post_id: C6GIK4CvUC4
# Deleted 1 duplicate rows for instagram_post_id: C6GIK4CvUC4
# Found 2 duplicates for instagram_post_id: C6V9wKfrbk_
# Deleted 1 duplicate rows for instagram_post_id: C6V9wKfrbk_
# Found 2 duplicates for instagram_post_id: C68LT0Yr1dU
# Deleted 1 duplicate rows for instagram_post_id: C68LT0Yr1dU
# Found 2 duplicates for instagram_post_id: C6Vw4sQyL1c
# Deleted 1 duplicate rows for instagram_post_id: C6Vw4sQyL1c
# Found 2 duplicates for instagram_post_id: C6F_IWVSTei
# Deleted 1 duplicate rows for instagram_post_id: C6F_IWVSTei
# Found 2 duplicates for instagram_post_id: C6GB8rmPhM6
# Deleted 1 duplicate rows for instagram_post_id: C6GB8rmPhM6
# Found 2 duplicates for instagram_post_id: C68irOUy35J
# Deleted 1 duplicate rows for instagram_post_id: C68irOUy35J
# Found 2 duplicates for instagram_post_id: CPdIoMzHb2n
# Deleted 1 duplicate rows for instagram_post_id: CPdIoMzHb2n
# Found 2 duplicates for instagram_post_id: C6JTP_Uvlun
# Deleted 1 duplicate rows for instagram_post_id: C6JTP_Uvlun
# Found 2 duplicates for instagram_post_id: C6YTcMWLX7D
# Processing duplicates:  37%|████████████████████▌                                   | 398/1085 [00:03<00:05, 132.59it/s]
# Deleted 1 duplicate rows for instagram_post_id: C6YTcMWLX7D
# Found 2 duplicates for instagram_post_id: C6VTmNkyzUV
# Deleted 1 duplicate rows for instagram_post_id: C6VTmNkyzUV
# Found 2 duplicates for instagram_post_id: CNHGWmchpt_
# Deleted 1 duplicate rows for instagram_post_id: CNHGWmchpt_
# Found 2 duplicates for instagram_post_id: C6GBdxDrcYr
# Deleted 1 duplicate rows for instagram_post_id: C6GBdxDrcYr
# Found 2 duplicates for instagram_post_id: C2_3IM9vSHY
# Deleted 1 duplicate rows for instagram_post_id: C2_3IM9vSHY
# Found 2 duplicates for instagram_post_id: C7lCJXoNhM-
# Deleted 1 duplicate rows for instagram_post_id: C7lCJXoNhM-
# Found 2 duplicates for instagram_post_id: CLlznZFB8th
# Deleted 1 duplicate rows for instagram_post_id: CLlznZFB8th
# Found 2 duplicates for instagram_post_id: C6GL44VyBB9
# Deleted 1 duplicate rows for instagram_post_id: C6GL44VyBB9
# Found 2 duplicates for instagram_post_id: C5WtcczR5ex
# Deleted 1 duplicate rows for instagram_post_id: C5WtcczR5ex
# Found 2 duplicates for instagram_post_id: C6F-mYnJBxb
# Deleted 1 duplicate rows for instagram_post_id: C6F-mYnJBxb
# Found 2 duplicates for instagram_post_id: C654ywpS46w
# Deleted 1 duplicate rows for instagram_post_id: C654ywpS46w
# Found 2 duplicates for instagram_post_id: C6F_4mQPOgt
# Deleted 1 duplicate rows for instagram_post_id: C6F_4mQPOgt
# Found 2 duplicates for instagram_post_id: C6RI0pqSKiS
# Deleted 1 duplicate rows for instagram_post_id: C6RI0pqSKiS
# Found 2 duplicates for instagram_post_id: C6PvMgry7fK
# Deleted 1 duplicate rows for instagram_post_id: C6PvMgry7fK
# Found 2 duplicates for instagram_post_id: C6VH1TuSutB
# Deleted 1 duplicate rows for instagram_post_id: C6VH1TuSutB
# Found 2 duplicates for instagram_post_id: C7qc9kev9xE
# Deleted 1 duplicate rows for instagram_post_id: C7qc9kev9xE
# Found 2 duplicates for instagram_post_id: C6RRYpbSDi9
# Deleted 1 duplicate rows for instagram_post_id: C6RRYpbSDi9
# Found 2 duplicates for instagram_post_id: C6WlVxJSfOR
# Deleted 1 duplicate rows for instagram_post_id: C6WlVxJSfOR
# Found 2 duplicates for instagram_post_id: C5n5_qdgtzh
# Deleted 1 duplicate rows for instagram_post_id: C5n5_qdgtzh
# Found 2 duplicates for instagram_post_id: C6wJl1xuQGf
# Deleted 1 duplicate rows for instagram_post_id: C6wJl1xuQGf
# Found 2 duplicates for instagram_post_id: C6GAzAvLyWg
# Deleted 1 duplicate rows for instagram_post_id: C6GAzAvLyWg
# Found 2 duplicates for instagram_post_id: C84Fb9KPGt0
# Deleted 1 duplicate rows for instagram_post_id: C84Fb9KPGt0
# Found 2 duplicates for instagram_post_id: C6F8ajppY4s
# Deleted 1 duplicate rows for instagram_post_id: C6F8ajppY4s
# Found 2 duplicates for instagram_post_id: C6GLSowy-r6
# Deleted 1 duplicate rows for instagram_post_id: C6GLSowy-r6
# Found 2 duplicates for instagram_post_id: C6F_Hp_rMmp
# Deleted 1 duplicate rows for instagram_post_id: C6F_Hp_rMmp
# Found 2 duplicates for instagram_post_id: C6XfrtCSxmd
# Deleted 1 duplicate rows for instagram_post_id: C6XfrtCSxmd
# Found 2 duplicates for instagram_post_id: C5a3ASPP9jW
# Deleted 1 duplicate rows for instagram_post_id: C5a3ASPP9jW
# Found 2 duplicates for instagram_post_id: C68BDhLLLat
# Deleted 1 duplicate rows for instagram_post_id: C68BDhLLLat
# Found 2 duplicates for instagram_post_id: C6GV920rSNy
# Processing duplicates:  39%|██████████████████████                                  | 427/1085 [00:03<00:04, 135.62it/s]
# Deleted 1 duplicate rows for instagram_post_id: C6GV920rSNy
# Found 2 duplicates for instagram_post_id: C6GAmKMP9ZE
# Deleted 1 duplicate rows for instagram_post_id: C6GAmKMP9ZE
# Found 2 duplicates for instagram_post_id: C3zzjzfyWLz
# Deleted 1 duplicate rows for instagram_post_id: C3zzjzfyWLz
# Found 2 duplicates for instagram_post_id: C7TlxZpKqw4
# Deleted 1 duplicate rows for instagram_post_id: C7TlxZpKqw4
# Found 2 duplicates for instagram_post_id: C68HSUevZ0e
# Deleted 1 duplicate rows for instagram_post_id: C68HSUevZ0e
# ...
# Deleted 1 duplicate rows for instagram_post_id: C7CYFlWII1I
# Found 2 duplicates for instagram_post_id: CNFJaTQHlIY
# Deleted 1 duplicate rows for instagram_post_id: CNFJaTQHlIY
# Found 2 duplicates for instagram_post_id: C6M2v_TyEbM
# Deleted 1 duplicate rows for instagram_post_id: C6M2v_TyEbM
# Found 2 duplicates for instagram_post_id: C6Px9InSmE-
# Deleted 1 duplicate rows for instagram_post_id: C6Px9InSmE-
# Found 2 duplicates for instagram_post_id: C48IRewu3u6
# Deleted 1 duplicate rows for instagram_post_id: C48IRewu3u6
# Found 2 duplicates for instagram_post_id: C68HkJdPtzx
# Deleted 1 duplicate rows for instagram_post_id: C68HkJdPtzx
# Found 2 duplicates for instagram_post_id: C6RKcrdPMLM
# Deleted 1 duplicate rows for instagram_post_id: C6RKcrdPMLM
# Found 2 duplicates for instagram_post_id: C6Y5rsDSP9I
# Processing duplicates:  91%|██████████████████████████████████████████████████▊     | 984/1085 [00:07<00:00, 132.73it/s]
# Deleted 1 duplicate rows for instagram_post_id: C6Y5rsDSP9I
# Found 2 duplicates for instagram_post_id: C6U1T47ya1e
# Deleted 1 duplicate rows for instagram_post_id: C6U1T47ya1e
# Found 2 duplicates for instagram_post_id: Ctb3wj6JphV
# Deleted 1 duplicate rows for instagram_post_id: Ctb3wj6JphV
# Found 2 duplicates for instagram_post_id: C6GGtj_vFev
# Deleted 1 duplicate rows for instagram_post_id: C6GGtj_vFev
# Found 2 duplicates for instagram_post_id: C6GFRF3vQwS
# Deleted 1 duplicate rows for instagram_post_id: C6GFRF3vQwS
# Found 2 duplicates for instagram_post_id: CbMCmsQvml9
# Deleted 1 duplicate rows for instagram_post_id: CbMCmsQvml9
# Found 2 duplicates for instagram_post_id: BL3O3CDDDec
# Deleted 1 duplicate rows for instagram_post_id: BL3O3CDDDec
# Found 2 duplicates for instagram_post_id: C68EL_9Lsw-
# Deleted 1 duplicate rows for instagram_post_id: C68EL_9Lsw-
# Found 2 duplicates for instagram_post_id: C6GER0hPRhF
# Deleted 1 duplicate rows for instagram_post_id: C6GER0hPRhF
# Found 2 duplicates for instagram_post_id: C6MEbZvrbw9
# Deleted 1 duplicate rows for instagram_post_id: C6MEbZvrbw9
# Found 2 duplicates for instagram_post_id: C7rBANJIBs9
# Deleted 1 duplicate rows for instagram_post_id: C7rBANJIBs9
# Found 2 duplicates for instagram_post_id: C6-AQbVhDSI
# Deleted 1 duplicate rows for instagram_post_id: C6-AQbVhDSI
# Found 2 duplicates for instagram_post_id: C6GIbM3ym5o
# Deleted 1 duplicate rows for instagram_post_id: C6GIbM3ym5o
# Found 2 duplicates for instagram_post_id: C6GJQCCBEVI
# Deleted 1 duplicate rows for instagram_post_id: C6GJQCCBEVI
# Found 2 duplicates for instagram_post_id: C6XY6HwPsip
# Deleted 1 duplicate rows for instagram_post_id: C6XY6HwPsip
# Found 2 duplicates for instagram_post_id: C6F-h6aoFXX
# Deleted 1 duplicate rows for instagram_post_id: C6F-h6aoFXX
# Found 2 duplicates for instagram_post_id: C6GR9vUP7mb
# Deleted 1 duplicate rows for instagram_post_id: C6GR9vUP7mb
# Found 2 duplicates for instagram_post_id: C6F_3ByPslZ
# Deleted 1 duplicate rows for instagram_post_id: C6F_3ByPslZ
# Found 2 duplicates for instagram_post_id: C6UstrWShQ1
# Deleted 1 duplicate rows for instagram_post_id: C6UstrWShQ1
# Found 2 duplicates for instagram_post_id: C6WXSMpyRsk
# Deleted 1 duplicate rows for instagram_post_id: C6WXSMpyRsk
# Found 2 duplicates for instagram_post_id: CU9QcCihn3h
# Deleted 1 duplicate rows for instagram_post_id: CU9QcCihn3h
# Found 2 duplicates for instagram_post_id: C6GIXYiPQum
# Deleted 1 duplicate rows for instagram_post_id: C6GIXYiPQum
# Found 2 duplicates for instagram_post_id: C6F-_oFyNON
# Deleted 1 duplicate rows for instagram_post_id: C6F-_oFyNON
# Found 2 duplicates for instagram_post_id: C68GCVFp6zC
# Deleted 1 duplicate rows for instagram_post_id: C68GCVFp6zC
# Found 2 duplicates for instagram_post_id: C6GAzOkBzPh
# Deleted 1 duplicate rows for instagram_post_id: C6GAzOkBzPh
# Found 2 duplicates for instagram_post_id: C6GCgVZvi21
# Deleted 1 duplicate rows for instagram_post_id: C6GCgVZvi21
# Found 2 duplicates for instagram_post_id: C6F-MlRv7VZ
# Deleted 1 duplicate rows for instagram_post_id: C6F-MlRv7VZ
# Found 2 duplicates for instagram_post_id: C6VE_ATSRXH
# Deleted 1 duplicate rows for instagram_post_id: C6VE_ATSRXH
# Found 2 duplicates for instagram_post_id: C4i2xRbtVoD
# Processing duplicates:  93%|███████████████████████████████████████████████████▍   | 1014/1085 [00:07<00:00, 137.54it/s]
# Deleted 1 duplicate rows for instagram_post_id: C4i2xRbtVoD
# Found 2 duplicates for instagram_post_id: C6GDTniBsw-
# Deleted 1 duplicate rows for instagram_post_id: C6GDTniBsw-
# Found 2 duplicates for instagram_post_id: C6GG0oiPLRi
# Deleted 1 duplicate rows for instagram_post_id: C6GG0oiPLRi
# Found 2 duplicates for instagram_post_id: C6GMOMMrABs
# Deleted 1 duplicate rows for instagram_post_id: C6GMOMMrABs
# Found 2 duplicates for instagram_post_id: CPrrIEBMTBb
# Deleted 1 duplicate rows for instagram_post_id: CPrrIEBMTBb
# Found 2 duplicates for instagram_post_id: C6GAbcKy8VS
# Deleted 1 duplicate rows for instagram_post_id: C6GAbcKy8VS
# Found 2 duplicates for instagram_post_id: Bh1I-RyA7I4
# Deleted 1 duplicate rows for instagram_post_id: Bh1I-RyA7I4
# Found 2 duplicates for instagram_post_id: C6GBJQIPnxd
# Deleted 1 duplicate rows for instagram_post_id: C6GBJQIPnxd
# Found 2 duplicates for instagram_post_id: C6GDs0DSDDe
# Deleted 1 duplicate rows for instagram_post_id: C6GDs0DSDDe
# Found 2 duplicates for instagram_post_id: C6GBGHnJPF8
# Deleted 1 duplicate rows for instagram_post_id: C6GBGHnJPF8
# Found 2 duplicates for instagram_post_id: C7rGa4gNVdb
# Deleted 1 duplicate rows for instagram_post_id: C7rGa4gNVdb
# Found 2 duplicates for instagram_post_id: C6F_MLJhrOe
# Deleted 1 duplicate rows for instagram_post_id: C6F_MLJhrOe
# Found 2 duplicates for instagram_post_id: C6P9DZ-pF1Q
# Deleted 1 duplicate rows for instagram_post_id: C6P9DZ-pF1Q
# Found 2 duplicates for instagram_post_id: C6GQcParKMu
# Deleted 1 duplicate rows for instagram_post_id: C6GQcParKMu
# Found 2 duplicates for instagram_post_id: CNCPjEajw0u
# Deleted 1 duplicate rows for instagram_post_id: CNCPjEajw0u
# Found 2 duplicates for instagram_post_id: C68SwgdLWTF
# Deleted 1 duplicate rows for instagram_post_id: C68SwgdLWTF
# Found 2 duplicates for instagram_post_id: C6GKgcxywL8
# Deleted 1 duplicate rows for instagram_post_id: C6GKgcxywL8
# Found 2 duplicates for instagram_post_id: C6GCkcVx5AW
# Deleted 1 duplicate rows for instagram_post_id: C6GCkcVx5AW
# Found 2 duplicates for instagram_post_id: CNUoeNoB0HY
# Deleted 1 duplicate rows for instagram_post_id: CNUoeNoB0HY
# Found 2 duplicates for instagram_post_id: C6VOHIypaBY
# Deleted 1 duplicate rows for instagram_post_id: C6VOHIypaBY
# Found 2 duplicates for instagram_post_id: C6ykS4JAecY
# Deleted 1 duplicate rows for instagram_post_id: C6ykS4JAecY
# Found 2 duplicates for instagram_post_id: C6GDSgdvGAS
# Deleted 1 duplicate rows for instagram_post_id: C6GDSgdvGAS
# Found 2 duplicates for instagram_post_id: C6TFzdRLGoD
# Deleted 1 duplicate rows for instagram_post_id: C6TFzdRLGoD
# Found 2 duplicates for instagram_post_id: C6GDilHriP5
# Deleted 1 duplicate rows for instagram_post_id: C6GDilHriP5
# Found 2 duplicates for instagram_post_id: Cl2g-bHhqnc
# Deleted 1 duplicate rows for instagram_post_id: Cl2g-bHhqnc
# Found 2 duplicates for instagram_post_id: C6Oe6GCyaQf
# Deleted 1 duplicate rows for instagram_post_id: C6Oe6GCyaQf
# Found 2 duplicates for instagram_post_id: C6S1BW4yk-T
# Deleted 1 duplicate rows for instagram_post_id: C6S1BW4yk-T
# Found 2 duplicates for instagram_post_id: C6GGtf5Lm6y
# Deleted 1 duplicate rows for instagram_post_id: C6GGtf5Lm6y
# Found 2 duplicates for instagram_post_id: C68EvwyPLY1
# Deleted 1 duplicate rows for instagram_post_id: C68EvwyPLY1
# Found 2 duplicates for instagram_post_id: C6GO_LOLxfR
# Processing duplicates:  95%|████████████████████████████████████████████████████▏  | 1029/1085 [00:07<00:00, 140.72it/s]
# Deleted 1 duplicate rows for instagram_post_id: C6GO_LOLxfR
# Found 2 duplicates for instagram_post_id: CM9o4qrJdMm
# Deleted 1 duplicate rows for instagram_post_id: CM9o4qrJdMm
# Found 2 duplicates for instagram_post_id: C68ju_ZSxic
# Deleted 1 duplicate rows for instagram_post_id: C68ju_ZSxic
# Found 2 duplicates for instagram_post_id: C68LWluB-Od
# Deleted 1 duplicate rows for instagram_post_id: C68LWluB-Od
# Found 2 duplicates for instagram_post_id: C6GCrsZvDvE
# Deleted 1 duplicate rows for instagram_post_id: C6GCrsZvDvE
# Found 2 duplicates for instagram_post_id: C6ep9x5vOe-
# Deleted 1 duplicate rows for instagram_post_id: C6ep9x5vOe-
# Found 2 duplicates for instagram_post_id: C6GJDMwPWoy
# Deleted 1 duplicate rows for instagram_post_id: C6GJDMwPWoy
# Found 2 duplicates for instagram_post_id: C6QJqnFyoFw
# Deleted 1 duplicate rows for instagram_post_id: C6QJqnFyoFw
# Found 2 duplicates for instagram_post_id: C6Q0sTfPfBA
# Deleted 1 duplicate rows for instagram_post_id: C6Q0sTfPfBA
# Found 2 duplicates for instagram_post_id: CUAMRZxhxto
# Deleted 1 duplicate rows for instagram_post_id: CUAMRZxhxto
# Found 2 duplicates for instagram_post_id: C5RSJFnMvYg
# Deleted 1 duplicate rows for instagram_post_id: C5RSJFnMvYg
# Found 2 duplicates for instagram_post_id: C6GFxw6hih5
# Deleted 1 duplicate rows for instagram_post_id: C6GFxw6hih5
# Found 2 duplicates for instagram_post_id: CUtzmw5sZC-
# Deleted 1 duplicate rows for instagram_post_id: CUtzmw5sZC-
# Found 2 duplicates for instagram_post_id: CZWbr6lMoIx
# Deleted 1 duplicate rows for instagram_post_id: CZWbr6lMoIx
# Found 2 duplicates for instagram_post_id: C6F_V7yvy1-
# Deleted 1 duplicate rows for instagram_post_id: C6F_V7yvy1-
# Found 2 duplicates for instagram_post_id: C6P8MvupfNy
# Deleted 1 duplicate rows for instagram_post_id: C6P8MvupfNy
# Found 2 duplicates for instagram_post_id: C6F_78qPhY0
# Deleted 1 duplicate rows for instagram_post_id: C6F_78qPhY0
# Found 2 duplicates for instagram_post_id: C6GBL7CvG2M
# Deleted 1 duplicate rows for instagram_post_id: C6GBL7CvG2M
# Found 2 duplicates for instagram_post_id: C5TNf1fPAiH
# Deleted 1 duplicate rows for instagram_post_id: C5TNf1fPAiH
# Found 2 duplicates for instagram_post_id: C68PjhzvFrq
# Deleted 1 duplicate rows for instagram_post_id: C68PjhzvFrq
# Found 2 duplicates for instagram_post_id: C6WhIlUPz_P
# Deleted 1 duplicate rows for instagram_post_id: C6WhIlUPz_P
# Found 2 duplicates for instagram_post_id: C6GEb_eRiad
# Deleted 1 duplicate rows for instagram_post_id: C6GEb_eRiad
# Found 2 duplicates for instagram_post_id: C6GUMRGLUJm
# Deleted 1 duplicate rows for instagram_post_id: C6GUMRGLUJm
# Found 2 duplicates for instagram_post_id: C6SY0nMpvPG
# Deleted 1 duplicate rows for instagram_post_id: C6SY0nMpvPG
# Found 2 duplicates for instagram_post_id: C7cLdANoP_x
# Deleted 1 duplicate rows for instagram_post_id: C7cLdANoP_x
# Found 2 duplicates for instagram_post_id: C7cjfLuvI7m
# Deleted 1 duplicate rows for instagram_post_id: C7cjfLuvI7m
# Found 2 duplicates for instagram_post_id: C4j9eQUv0M_
# Deleted 1 duplicate rows for instagram_post_id: C4j9eQUv0M_
# Found 2 duplicates for instagram_post_id: CWYlgGOhUKU
# Deleted 1 duplicate rows for instagram_post_id: CWYlgGOhUKU
# Found 2 duplicates for instagram_post_id: C6V6pMFPbPN
# Deleted 1 duplicate rows for instagram_post_id: C6V6pMFPbPN
# Found 2 duplicates for instagram_post_id: C6F-RNwSBOz
# Processing duplicates:  98%|█████████████████████████████████████████████████████▋ | 1059/1085 [00:08<00:00, 140.88it/s]
# Deleted 1 duplicate rows for instagram_post_id: C6F-RNwSBOz
# Found 2 duplicates for instagram_post_id: CS3t8o0hxIb
# Deleted 1 duplicate rows for instagram_post_id: CS3t8o0hxIb
# Found 2 duplicates for instagram_post_id: C6GUB-WJo8j
# Deleted 1 duplicate rows for instagram_post_id: C6GUB-WJo8j
# Found 2 duplicates for instagram_post_id: C6GB2E3ymw0
# Deleted 1 duplicate rows for instagram_post_id: C6GB2E3ymw0
# Found 2 duplicates for instagram_post_id: BvBEQDbAcOh
# Deleted 1 duplicate rows for instagram_post_id: BvBEQDbAcOh
# Found 2 duplicates for instagram_post_id: C6GB4ugxJ0r
# Deleted 1 duplicate rows for instagram_post_id: C6GB4ugxJ0r
# Found 2 duplicates for instagram_post_id: C53WeeqPNMQ
# Deleted 1 duplicate rows for instagram_post_id: C53WeeqPNMQ
# Found 2 duplicates for instagram_post_id: C6GLpmKSGnL
# Deleted 1 duplicate rows for instagram_post_id: C6GLpmKSGnL
# Found 2 duplicates for instagram_post_id: C9lzoucBrJl
# Deleted 1 duplicate rows for instagram_post_id: C9lzoucBrJl
# Found 2 duplicates for instagram_post_id: C6GBTRavHkD
# Deleted 1 duplicate rows for instagram_post_id: C6GBTRavHkD
# Found 2 duplicates for instagram_post_id: C6GAyEQy8PT
# Deleted 1 duplicate rows for instagram_post_id: C6GAyEQy8PT
# Found 2 duplicates for instagram_post_id: C6GIZSFO5tv
# Deleted 1 duplicate rows for instagram_post_id: C6GIZSFO5tv
# Found 2 duplicates for instagram_post_id: C6GOqnCOf4U
# Deleted 1 duplicate rows for instagram_post_id: C6GOqnCOf4U
# Found 2 duplicates for instagram_post_id: C6TUnOCJ_F-
# Deleted 1 duplicate rows for instagram_post_id: C6TUnOCJ_F-
# Found 2 duplicates for instagram_post_id: CNMkMyvgd63
# Deleted 1 duplicate rows for instagram_post_id: CNMkMyvgd63
# Found 2 duplicates for instagram_post_id: C6F_EBQJxO6
# Deleted 1 duplicate rows for instagram_post_id: C6F_EBQJxO6
# Found 2 duplicates for instagram_post_id: C6F_1SxypnI
# Deleted 1 duplicate rows for instagram_post_id: C6F_1SxypnI
# Found 2 duplicates for instagram_post_id: C6GG1HhSnn3
# Deleted 1 duplicate rows for instagram_post_id: C6GG1HhSnn3
# Found 2 duplicates for instagram_post_id: C9McHRQRM1r
# Deleted 1 duplicate rows for instagram_post_id: C9McHRQRM1r
# Found 2 duplicates for instagram_post_id: C6BczB9C40_
# Deleted 1 duplicate rows for instagram_post_id: C6BczB9C40_
# Found 2 duplicates for instagram_post_id: C68J_UiSAqJ
# Deleted 1 duplicate rows for instagram_post_id: C68J_UiSAqJ
# Found 2 duplicates for instagram_post_id: CNPv42VnvbG
# Deleted 1 duplicate rows for instagram_post_id: CNPv42VnvbG
# Found 2 duplicates for instagram_post_id: C6GFfsHL_S1
# Deleted 1 duplicate rows for instagram_post_id: C6GFfsHL_S1
# Found 2 duplicates for instagram_post_id: C6F8ZXTvzvj
# Deleted 1 duplicate rows for instagram_post_id: C6F8ZXTvzvj
# Found 2 duplicates for instagram_post_id: C6GH5UmL6lP
# Deleted 1 duplicate rows for instagram_post_id: C6GH5UmL6lP
# Found 2 duplicates for instagram_post_id: C6QZrtuShJo
# Deleted 1 duplicate rows for instagram_post_id: C6QZrtuShJo
# Found 2 duplicates for instagram_post_id: C68F7MbB4iq
# Deleted 1 duplicate rows for instagram_post_id: C68F7MbB4iq
# Found 2 duplicates for instagram_post_id: C6GLCM5SzM9
# Deleted 1 duplicate rows for instagram_post_id: C6GLCM5SzM9
# Found 2 duplicates for instagram_post_id: C5Q4pOHAOZR
# Deleted 1 duplicate rows for instagram_post_id: C5Q4pOHAOZR
# Found 2 duplicates for instagram_post_id: C7kVHx1owm2
# Processing duplicates: 100%|███████████████████████████████████████████████████████| 1085/1085 [00:08<00:00, 131.04it/s]
# Deleted 1 duplicate rows for instagram_post_id: C7kVHx1owm2
# Found 2 duplicates for instagram_post_id: C6F-Mi3Rvlu
# Deleted 1 duplicate rows for instagram_post_id: C6F-Mi3Rvlu
# Found 2 duplicates for instagram_post_id: CPaAA0uBXFO
# Deleted 1 duplicate rows for instagram_post_id: CPaAA0uBXFO
# Found 2 duplicates for instagram_post_id: CpnG-0CvtGM
# Deleted 1 duplicate rows for instagram_post_id: CpnG-0CvtGM
# Found 2 duplicates for instagram_post_id: C9KQ19XPmgU
# Deleted 1 duplicate rows for instagram_post_id: C9KQ19XPmgU
# Found 2 duplicates for instagram_post_id: C68Qhk5yx15
# Deleted 1 duplicate rows for instagram_post_id: C68Qhk5yx15
# Found 2 duplicates for instagram_post_id: C6GDivPRRAO
# Deleted 1 duplicate rows for instagram_post_id: C6GDivPRRAO
# Found 2 duplicates for instagram_post_id: C6VSrUDSRdm
# Deleted 1 duplicate rows for instagram_post_id: C6VSrUDSRdm
# Found 2 duplicates for instagram_post_id: CrF17gRhbxY
# Deleted 1 duplicate rows for instagram_post_id: CrF17gRhbxY
# Found 2 duplicates for instagram_post_id: C6GFXLYOLRm
# Deleted 1 duplicate rows for instagram_post_id: C6GFXLYOLRm
# Found 2 duplicates for instagram_post_id: C6F_CVMv7Sj
# Deleted 1 duplicate rows for instagram_post_id: C6F_CVMv7Sj
# Found 2 duplicates for instagram_post_id: C5qWe9SOYtH
# Deleted 1 duplicate rows for instagram_post_id: C5qWe9SOYtH
# Found 2 duplicates for instagram_post_id: C6GOMa-Ofdg
# Deleted 1 duplicate rows for instagram_post_id: C6GOMa-Ofdg
# Unique constraint added to instagram_post_id
