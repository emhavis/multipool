# %%
import requests

def run_curl_command(prompt):
    url = "http://108.137.109.168:11434/api/generate"

    data = {
        "model": "mistral",
        "prompt": "Generate a 10 line poetry of darkness",
        "stream": False
    }

    # Sending a POST request
    response = requests.post(url, json=data)

    # Checking the response
    if response.status_code == 200:
        # Return the JSON response
        return response.json()
    else:
        print(f"Error! Status code: {response.status_code}, Response: {response.text}")
        # Return None or raise an exception, depending on your preference
        return None

# %%
run_curl_command("make me a poetry about sadness")
# Out:
# {'model': 'mistral',
#  'created_at': '2024-02-07T07:50:37.873394918Z',
#  'response': " In the heart of night, where shadows play,\n\nA tapestry of darkness weaves its way.\nMoonless void, a canvas blank and bare,\nSilence cloaks us in its gentle lair.\nGlimmers of starlight fade into oblivion's grasp,\nNight's symphony plays on, an endless clasp.\n\nWhispers of the dark, a siren's call,\nEchoes through the stillness, beckoning all.\nIn this abyss, secrets hide and dwell,\nA realm untouched by day's harsh tell.",
#  'done': True,
#  'context': [733,
#   16289,
#   28793,
#   28705,
#   26075,
#   264,
#   28705,
#   28740,
#   28734,
#   1407,
#   15891,
#   302,
#   11691,
#   733,
#   28748,
#   16289,
#   28793,
#   560,
#   272,
#   3031,
#   302,
#   2125,
#   28725,
#   970,
#   17207,
#   1156,
#   28725,
#   13,
#   13,
#   28741,
#   12857,
#   374,
#   643,
#   302,
#   11691,
#   478,
#   3410,
#   871,
#   1069,
#   28723,
#   13,
#   28755,
#   4973,
#   1503,
# ...

# %%
prompt = """
Consider the following text separated by comma

"meadow,practical,ribbon,clothes,amber,crosswalk,appetite,referee,youth,secure,fast,precede,criminal,wilderness,fill,suitcase,extent,fluctuation,econobox,berry,government,hot,new,ask,cap,drawing,shape,experiment,place,color-blind,bottle,governor,pure,exceed,market,lounge,chew,manager,time,leaf,shareholder,switch,auditor,dictate,aquarium,can,horoscope,apology,emergency,hypothesize"

Please categorize each word into one of the following :noun,verb,adjective,adverb

Please respond in a valid JSON format, group them by category and show the confidence level of each categorization example format:
{"noun":[{

  "word": "meadow",
  "category": noun,
  "confidence level": 1.0

},{

  "word": "practical",
  "category": adjective,
  "confidence level": 0.9

},]}
"""
# Print or use the 'prompt' variable as needed
print(prompt)
# Out:
# Consider the following text separated by comma
#
# "meadow,practical,ribbon,clothes,amber,crosswalk,appetite,referee,youth,secure,fast,precede,criminal,wilderness,fill,suitcase,extent,fluctuation,econobox,berry,government,hot,new,ask,cap,drawing,shape,experiment,place,color-blind,bottle,governor,pure,exceed,market,lounge,chew,manager,time,leaf,shareholder,switch,auditor,dictate,aquarium,can,horoscope,apology,emergency,hypothesize"
#
# Please categorize each word into one of the following :noun,verb,adjective,adverb
#
# Please respond in a valid JSON format, group them by category and show the confidence level of each categorization example format:
# {"noun":[{
#
#   "word": "meadow",
#   "category": noun,
#   "confidence level": 1.0
#
# },{
#
#   "word": "practical",
#   "category": adjective,
#   "confidence level": 0.9
#
# },]}

# %%
run_curl_command(prompt)
# Out:
# {'model': 'mistral',
#  'created_at': '2024-02-07T08:03:30.417536162Z',
# ...

# %%
prompt = """
Consider the following text separated by comma

"meadow,practical,ribbon,clothes,amber,crosswalk,appetite,referee,youth,secure,fast,precede,criminal,wilderness,fill,suitcase,extent,fluctuation,econobox,berry,government,hot,new,ask,cap,drawing,shape,experiment,place,color-blind,bottle,governor,pure,exceed,market,lounge,chew,manager,time,leaf,shareholder,switch,auditor,dictate,aquarium,can,horoscope,apology,emergency,hypothesize"

Please categorize each word into one of the following :noun,verb,adjective,adverb

Please respond in a valid JSON format, group them by category and show the confidence level of each categorization example format:
{"noun":[{

  "word": "meadow",
  "category": noun,
  "confidence level": 1.0

},{

  "word": "practical",
  "category": adjective,
  "confidence level": 0.9

},]}
"""

run_curl_command(prompt)
# Out:
# {'model': 'mistral',
#  'created_at': '2024-02-07T08:03:57.942567919Z',
# ...

# %%
def run_curl_command(prompt):
    url = "http://108.137.109.168:11434/api/generate"

    data = {
        "model": "mistral",
        "prompt": prompt,
        "stream": False
    }

    # Sending a POST request
    response = requests.post(url, json=data)

    # Checking the response
    if response.status_code == 200:
        # Return the JSON response
        return response.json()
    else:
        print(f"Error! Status code: {response.status_code}, Response: {response.text}")
        # Return None or raise an exception, depending on your preference
        return None
